# %%
import os
os.chdir('/home/cosysoft/Documents/autostat/autostat/')
os.getcwd()
# Out:
# '/home/cosysoft/Documents/autostat/autostat'

# %%
import pandas as pd
import numpy as np

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 1.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10
# WARNING: There was an error checking the latest version of pip.

# %%
df = pd.read_excel('data/raw/synonim.xlsx')
# Out:
# /home/cosysoft/Documents/autostat/autostat/venv/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df
# Out:
#             id                           text_brandmodel Brand_AS  \
# 0           11                            DАF ХF 105.460      DAF
# 1           12                             DАЕWОО ЕSРЕRО   DAEWOO
# 2           13                           DАЕWОО МАТIZ МХ   DAEWOO
# 3           14                              DАТSUN ОN-DО   DATSUN
# 4           15                               FIАТ DUСАТО     FIAT
# ...        ...                                       ...      ...
# 662548  745401           ЯНГАНГ РАТRОN-УINGАNG ТАКЕR 250   PATRON
# 662549  745402  ЯНГАНГ УG150-2FС РАТRОN-УINGАNG РАRТIZАN   PATRON
# 662550  745403  ЯНГАНГ УG150-2FС РАТRОN-УАNGАNG РАRТIZАN   PATRON
# 662551  745404                                      ЯРИС    OTHER
# 662552  745405                                      ЯРИС   TOYOTA
#
#                 Model_AS  Modelkey_AS
# 0       TRUCKS XF SERIES         1880
# 1                 ESPERO          747
# 2                  MATIZ          756
# 3                  ON-DO         8731
# 4                 DUCATO         1620
# ...                  ...          ...
# 662548             TAKER        11917
# 662549          PARTIZAN        11912
# 662550          PARTIZAN        11912
# 662551             OTHER          122
# 662552             YARIS          457
#
# [662553 rows x 5 columns]

# %%
import re
brands = list(set(df['Brand_AS'].values))

dictionary = {}

for brand in sorted(brands):
    models = list(set(df[df['Brand_AS'] == brand]['Model_AS'].values))
    models = map(lambda x: re.sub(r'-'," ", x), models)
    dictionary[brand] = {
        "name": brand,
        "models": sorted(models),
    }

# %%
dictionary
# Out:
# {'ABM': {'name': 'ABM',
#   'models': ['ALFA', 'FAVORIT', 'FLASH', 'HELPER', 'PEGAS', 'VOLCAN']},
#  'ACERBI': {'name': 'ACERBI', 'models': ['21L2.39']},
#  'ACKERMANN': {'name': 'ACKERMANN', 'models': ['FRUEHAUF', 'Z PA']},
#  'ACURA': {'name': 'ACURA',
#   'models': ['CL',
#    'EL',
#    'INTEGRA',
#    'LEGEND',
#    'MDX',
#    'NSX',
#    'RDX',
#    'RL',
#    'RSX',
#    'SLX',
#    'TL',
#    'TLX',
#    'TSX',
#    'ZDX']},
#  'ADEPT-LES-HOLDING': {'name': 'ADEPT-LES-HOLDING',
#   'models': ['9053', '905310']},
#  'AKU-TRAILER': {'name': 'AKU-TRAILER',
#   'models': ['275L', '300LP', '350LP', '450K', '600VL']},
#  'ALASKA': {'name': 'ALASKA', 'models': ['7143', '71432', '71433']},
#  'ALFA': {'name': 'ALFA', 'models': ['WJ50']},
#  'ALFA ROMEO': {'name': 'ALFA ROMEO',
#   'models': ['145',
#    '146',
#    '147',
#    '155',
#    '156',
#    '159',
#    '164',
#    '166',
#    '33',
#    '4C',
#    '75',
#    '90',
#    'ALFETTA',
#    'BRERA',
#    'GIULIETTA',
#    'GT',
#    'GTV',
#    'MITO',
#    'SPIDER']},
#  'ALI RIZA USTA': {'name': 'ALI RIZA USTA',
#   'models': ['A3TY', 'A3YY', 'ARU MB']},
#  'ALLOY': {'name': 'ALLOY', 'models': ['ATVT 53 3']},
#  'ALTAVIR': {'name': 'ALTAVIR', 'models': ['906100', '906110']},
#  'AMS': {'name': 'AMS', 'models': ['500', '550', '650', '750']},
#  'AMUR': {'name': 'AMUR', 'models': ['4346', '5312', '5313', '633100']},
#  'ASHOK LEYLAND': {'name': 'ASHOK LEYLAND', 'models': ['OTHER']},
#  'ASIA': {'name': 'ASIA',
#   'models': ['COMBI', 'COSMOS', 'OTHER', 'ROCSTA', 'TOPIC', 'TOWNER']},
#  'ASP': {'name': 'ASP', 'models': ['25']},
#  'AST-KANASH': {'name': 'AST-KANASH',
#   'models': ['949120', '949122', '949124', '949131', '949171', '949173']},
#  'ASTAIS': {'name': 'ASTAIS', 'models': ['900900', '900910', '900912']},
#  'ASTON MARTIN': {'name': 'ASTON MARTIN',
#   'models': ['DB11',
#    'DB7',
#    'DB9',
#    'DBS',
#    'DBX',
#    'RAPIDE',
#    'V12',
#    'V8',
#    'VANTAGE']},
#  'ATLANT': {'name': 'ATLANT', 'models': ['CXM150']},
#  'ATLAS COPCO': {'name': 'ATLAS COPCO',
#   'models': ['XAHS186DD',
#    'XAS47DD',
#    'XAS48KD',
#    'XAS87KD',
#    'XAS88KD',
#    'XAS97DD',
#    'XATS156DD']},
#  'ATLETIC': {'name': 'ATLETIC',
#   'models': ['520', '712012', '712018', '712022']},
#  'AUDI': {'name': 'AUDI',
#   'models': ['100',
#    '200',
#    '4000',
#    '5000',
#    '80',
#    '90',
#    'A1',
#    'A2',
#    'A3',
#    'A4',
#    'A4 ALLROAD QUATTRO',
#    'A5',
#    'A6',
#    'A6 ALLROAD QUATTRO',
#    'A7',
#    'A8',
#    'ALLROAD',
#    'CABRIOLET',
#    'COUPE',
#    'E TRON',
#    'Q3',
#    'Q3 SPORTBACK',
#    'Q5',
#    'Q7',
#    'Q8',
#    'QUATTRO',
#    'R8',
#    'RS Q3',
#    'RS2',
#    'RS3',
#    'RS4',
#    'RS5',
#    'RS6',
#    'RS7',
#    'S2',
#    'S3',
#    'S4',
#    'S5',
#    'S6',
#    'S7',
#    'S8',
#    'SQ5',
#    'SQ7',
#    'SQ8',
#    'TT',
#    'TT RS',
#    'TTS',
#    'V8']},
#  'AVENTO': {'name': 'AVENTO', 'models': ['OTHER']},
#  'AVIA': {'name': 'AVIA', 'models': ['A20', 'A21', 'A31', 'D120']},
#  'AVIATEHNOLOGIA': {'name': 'AVIATEHNOLOGIA', 'models': ['OTHER']},
#  'AVTO-STEN': {'name': 'AVTO-STEN', 'models': ['PGMF 83021', 'PGMF 83022']},
#  'AVTOMASTER': {'name': 'AVTOMASTER',
#   'models': ['8447 03',
#    '85651',
#    '85651 01',
#    '85651 01A',
#    '85651 20',
#    '85651 30',
#    '85651 40',
#    '9083']},
#  'AVTOS': {'name': 'AVTOS',
#   'models': ['A20M1B',
#    'A25M1B',
#    'A25M2B',
#    'A25P1B',
#    'A25P2B',
#    'A28P1B',
#    'A28P2B',
#    'A30M1B',
#    'A30M2B',
#    'A30P1B',
#    'A30P2B',
#    'A35P1B',
#    'A35P2B',
#    'A35U1B',
#    'A35U2B',
#    'A35U2C',
#    'A40P1B',
#    'A40P2B',
#    'A40U1B',
#    'A40U2B',
#    'AC11AB',
#    'AC15AB',
#    'AC19AB',
#    'AC23AB',
#    'AF23AB',
#    'AF23NB',
#    'AF27AB',
#    'AF27NB',
#    'AF31AB',
#    'AF31NB',
#    'AF34AB',
#    'AF34NB',
#    'AF38AB',
#    'AF38NB',
#    'AL31AB',
#    'AL31NB',
#    'AL34AB',
#    'AL34NB',
#    'AL38NB',
#    'B40M1B',
#    'B65P2B',
#    'HB38AA',
#    'HB48AA',
#    'HF53AA']},
#  'AYATS': {'name': 'AYATS', 'models': ['ATLANTIS', 'BRAVO 1', 'OLIMPIA']},
#  'AZHM': {'name': 'AZHM',
#   'models': ['CTA 10',
#    'CTA 15',
#    'CTA 20',
#    'CZHU 17.5 2.0',
#    'CZHU 22 2.0',
#    'CZHY 10 1.8',
#    'PC 11',
#    'PC 16',
#    'PC 7',
#    'PPC 18',
#    'PPC 20',
#    'PPC 20 9397',
#    'PPC 22',
#    'PPC 24',
#    'PPC 24 93866',
#    'PPC 26',
#    'PPC 28',
#    'PPC 30',
#    'PPC 33',
#    'PPC 33 93892',
#    'PPC 37',
#    'PPC 40',
#    'PPC 45',
#    'PPCT 10.5',
#    'PPCT 17.6',
#    'PPCT 22',
#    'PPCT 27',
#    'PPCT 36',
#    'PPCT 46.5']},
#  'BAGEM': {'name': 'BAGEM', 'models': ['OTHER']},
#  'BAJAJ': {'name': 'BAJAJ',
#   'models': ['AVENGER', 'BOXER BM 125X', 'BOXER BM 150', 'DOMINAR', 'PULSAR']},
#  'BALTMOTORS': {'name': 'BALTMOTORS',
#   'models': ['A1',
#    'BM500 EFI',
#    'CLASSIC',
#    'DAKAR',
#    'ENDURO',
#    'GALACTICA',
#    'HIKER',
#    'MOTARD',
#    'S1',
#    'STREET']},
#  'BALTSPECMASCH': {'name': 'BALTSPECMASCH',
#   'models': ['9445 10',
#    '94451 10',
#    '9453 10 01',
#    '9453 10 02',
#    '9453 10 30',
#    '94531 10',
#    '94532 10']},
#  'BATYR': {'name': 'BATYR', 'models': ['712501', '712502']},
#  'BAW': {'name': 'BAW',
#   'models': ['1044',
#    '1065',
#    '2245',
#    '3346',
#    '33462',
#    '33463',
#    '33468',
#    'OTHER']},
#  'BAZ': {'name': 'BAZ', 'models': ['2215', '8142', 'A079.14', 'OTHER']},
#  'BECEMA': {'name': 'BECEMA',
#   'models': ['96042',
#    'BCM 104',
#    'BCM 108',
#    'BCM 110',
#    'BCM 110.1',
#    'BCM 111',
#    'BCM 123',
#    'BCM 137',
#    'BCM 14',
#    'BCM 14.1',
#    'BCM 14.3',
#    'BCM 14.5',
#    'BCM 140',
#    'BCM 150',
#    'BCM 150.1',
#    'BCM 170',
#    'BCM 175',
#    'BCM 176',
#    'BCM 180',
#    'BCM 180.1',
#    'BCM 180.3',
#    'BCM 190',
#    'BCM 195',
#    'BCM 195.4',
#    'BCM 197',
#    'BCM 21.1',
#    'BCM 230',
#    'BCM 24.1',
#    'BCM 24.3',
#    'BCM 24.5',
#    'BCM 35',
#    'BCM 42',
#    'BCM 42.1',
#    'BCM 42.3',
#    'BCM 44',
#    'BCM 48',
#    'BCM 58.1',
#    'BCM 74',
#    'BCM 75',
#    'BCM 75.1A',
#    'BCM 75A',
#    'BCM 83.6',
#    'BCM 84',
#    'OTHER',
#    'PPC 21',
#    'TC 12',
#    'TC 14.1',
#    'TC 15',
#    'TC 20',
#    'TC 21',
#    'TC 21.1',
#    'TC 21.2',
#    'TC 21.3',
#    'TC 21.5',
#    'TC 21.6',
#    'TC 21.9',
#    'TC 25.5']},
#  'BELAZ': {'name': 'BELAZ', 'models': ['81201', 'LUBLIN']},
#  'BENALU': {'name': 'BENALU', 'models': ['OTHER']},
#  'BENELLI': {'name': 'BENELLI', 'models': ['CAFFENERO']},
#  'BENTLEY': {'name': 'BENTLEY',
#   'models': ['ARNAGE',
#    'AZURE',
#    'BENTAYGA',
#    'BROOKLANDS',
#    'CONTINENTAL',
#    'CONTINENTAL FLYING SPUR',
#    'CONTINENTAL GT',
#    'MULSANNE',
#    'TURBO R']},
#  'BEST': {'name': 'BEST',
#   'models': ['718716',
#    '718717',
#    '71871B',
#    '718720',
#    '718723',
#    '718725',
#    '718730',
#    '718740']},
#  'BMW': {'name': 'BMW',
#   'models': ['1 SERIES',
#    '2 SERIES',
#    '2 SERIES ACTIVE TOURER',
#    '3 GT',
#    '3 SERIES',
#    '4 SERIES',
#    '5 GT',
#    '5 SERIES',
#    '6 GT',
#    '6 SERIES',
#    '7 SERIES',
#    '8 SERIES',
#    'C 1',
#    'C EVOLUTION',
#    'C600 SPORT',
#    'C650 SPORT',
#    'C650GT',
#    'F650',
#    'F650CS',
#    'F650GS',
#    'F700GS',
#    'F750GS',
#    'F800GS',
#    'F800GT',
#    'F800R',
#    'F800S',
#    'F800ST',
#    'F850GS',
#    'G450X',
#    'G650',
#    'G650GS',
#    'G650X',
#    'HP2',
#    'HP4',
#    'I3',
#    'I8',
#    'K100',
#    'K1100',
#    'K1200GT',
#    'K1200LT',
#    'K1200R',
#    'K1200RS',
#    'K1200S',
#    'K1300GT',
#    'K1300R',
#    'K1300S',
#    'K1600',
#    'K1600GTL',
#    'M1',
#    'M2',
#    'M3',
#    'M4',
#    'M5',
#    'M6',
#    'M8',
#    'OTHER',
#    'R NINE T',
#    'R1100GS',
#    'R1100R',
#    'R1100RS',
#    'R1100RT',
#    'R1100S',
#    'R1150GS',
#    'R1150R',
#    'R1150RS',
#    'R1150RT',
#    'R12',
#    'R1200C',
#    'R1200CL',
#    'R1200GS',
#    'R1200R',
#    'R1200RS',
#    'R1200RT',
#    'R1200S',
#    'R1200ST',
#    'R1250GS',
#    'R1250R',
#    'R1250RS',
#    'R1250RT',
#    'R80',
#    'R850R',
#    'R90',
#    'S1000RR',
#    'X1',
#    'X2',
#    'X3',
#    'X4',
#    'X5',
#    'X6',
#    'X7',
#    'Z1',
#    'Z3',
#    'Z4',
#    'Z8']},
#  'BODEX': {'name': 'BODEX', 'models': ['KIS 3WS']},
#  'BOGDAN': {'name': 'BOGDAN',
#   'models': ['2110',
#    '2111',
#    '2310',
#    '2312',
#    'A069',
#    'A092',
#    'A201',
#    'A202',
#    'DF25',
#    'DF30',
#    'DF47']},
#  'BONUM': {'name': 'BONUM',
#   'models': ['914210', '914211', '914220', '914221', '914230', '914231']},
#  'BOVA': {'name': 'BOVA', 'models': ['FUTURA', 'MAGIQ']},
#  'BRILLIANCE': {'name': 'BRILLIANCE',
#   'models': ['H230', 'H530', 'M1', 'M2', 'V3', 'V5']},
#  'BRP': {'name': 'BRP', 'models': ['CAN AM RD SPYDER']},
#  'BUICK': {'name': 'BUICK',
#   'models': ['CENTURY',
#    'ELECTRA',
#    'ENCLAVE',
#    'LESABRE',
#    'PARK AVENUE',
#    'REGAL',
#    'RENDEZVOUS',
#    'RIVIERA',
#    'ROADMASTER',
#    'SKYLARK']},
#  'BYD': {'name': 'BYD',
#   'models': ['F0', 'F3', 'F6', 'FLYER', 'G3', 'G6', 'OTHER', 'S6']},
#  'CADILLAC': {'name': 'CADILLAC',
#   'models': ['ATS',
#    'BLS',
#    'BROUGHAM',
#    'CATERA',
#    'CT6',
#    'CTS',
#    'DEVILLE',
#    'DTS',
#    'ELDORADO',
#    'ESCALADE',
#    'FLEETWOOD',
#    'SEVILLE',
#    'SRX',
#    'STS',
#    'XT4',
#    'XT5',
#    'XT6']},
#  'CARSAN': {'name': 'CARSAN', 'models': ['CTS1']},
#  'CHAIKA-SERVIS': {'name': 'CHAIKA-SERVIS', 'models': ['3784R0', 'OTHER']},
#  'CHANGAN': {'name': 'CHANGAN',
#   'models': ['CS35',
#    'CS55',
#    'CS75',
#    'EADO',
#    'RAETON',
#    'SC1021',
#    'SC1030',
#    'SC6380',
#    'SC6601',
#    'SC7133']},
#  'CHDM': {'name': 'CHDM',
#   'models': ['943813 10', '943822 10', '943824 10', '943834 10', '943835 10']},
#  'CHEETA': {'name': 'CHEETA', 'models': ['PHANTOM', 'VOLCAN']},
#  'CHERY': {'name': 'CHERY',
#   'models': ['A13/BONUS/VERY',
#    'AMULET',
#    'ARRIZO 7',
#    'BONUS 3 A19',
#    'CROSSEASTAR',
#    'EASTAR',
#    'FORA',
#    'INDIS',
#    'KIMO',
#    'M11',
#    'QQ6',
#    'SWEET QQ',
#    'TIGGO',
#    'TIGGO 2',
#    'TIGGO 3',
#    'TIGGO 4',
#    'TIGGO 5',
#    'TIGGO 7',
#    'TIGGO 8']},
#  'CHERYEXEED': {'name': 'CHERYEXEED', 'models': ['TXL']},
#  'CHEVROLET': {'name': 'CHEVROLET',
#   'models': ['ALERO',
#    'ASTRA',
#    'ASTRO',
#    'AVALANCHE',
#    'AVEO',
#    'BEAUVILLE',
#    'BERETTA',
#    'BLAZER',
#    'BOLT',
#    'CAMARO',
#    'CAPRICE',
#    'CAPTIVA',
#    'CAVALIER',
#    'CELEBRITY',
#    'CHEVETTE',
#    'CHEVY VAN',
#    'CLASSIC',
#    'COBALT',
#    'COLORADO',
#    'CORSICA',
#    'CORVETTE',
#    'CRUZE',
#    'CRUZE/YGM1',
#    'EPICA',
#    'EQUINOX',
#    'EVANDA',
#    'EXPRESS',
#    'G SERIES',
#    'GEO METRO',
#    'GEO PRIZM',
#    'GEO STORM',
#    'GEO TRACKER',
#    'HHR',
#    'IMPALA',
#    'KALOS',
#    'LACETTI',
#    'LANOS',
#    'LOVA',
#    'LUMINA',
#    'MALIBU',
#    'MARK',
#    'MATIZ',
#    'MONTE CARLO',
#    'NEXIA',
#    'NIVA',
#    'NOVA',
#    'NUBIRA',
#    'OPTRA',
#    'ORLANDO',
#    'OTHER',
#    'PRISMA',
#    'REZZO',
#    'S10',
#    'SILVERADO',
#    'SPARK',
#    'SPECTRUM',
#    'SPORT VAN',
#    'SPRINT',
#    'SSR',
#    'STARCRAFT',
#    'SUBURBAN',
#    'TACUMA',
#    'TAHOE',
#    'TRACKER',
#    'TRAILBLAZER',
#    'TRANS SPORT',
#    'TRAVERSE',
#    'UPLANDER',
#    'VAN',
#    'VENTURE',
#    'VIVA',
#    'VOLT']},
#  'CHITUMA': {'name': 'CHITUMA',
#   'models': ['BRIAR STREETFIRE', 'FALCON SPEEDFIRE']},
#  'CHMZAP': {'name': 'CHMZAP',
#   'models': ['304',
#    '401',
#    '402',
#    '5208',
#    '5523',
#    '5524',
#    '8001',
#    '804',
#    '8124',
#    '81241',
#    '81243',
#    '8328',
#    '8335',
#    '8358',
#    '8398',
#    '83981',
#    '8399',
#    '83991',
#    '83992',
#    '8554',
#    '85541',
#    '8951',
#    '9012',
#    '93262',
#    '9337',
#    '93371',
#    '938530',
#    '938530 040',
#    '9386',
#    '9520',
#    '95201',
#    '9906',
#    '99063',
#    '99064',
#    '99065',
#    '9907',
#    '99072',
#    '9910',
#    '9911',
#    '9985',
#    '99858',
#    '99865',
#    '99874',
#    '9990',
#    '99902',
#    '99903',
#    '999039',
#    '99904',
#    '99905',
#    '99908',
#    '9991']},
#  'CHONGQING': {'name': 'CHONGQING', 'models': ['KN250GY']},
#  'CHRYSLER': {'name': 'CHRYSLER',
#   'models': ['300',
#    '300C',
#    '300M',
#    'ASPEN',
#    'CARAVAN',
#    'CIRRUS',
#    'CONCORDE',
#    'CROSSFIRE',
#    'DAYTONA',
#    'ES',
#    'FIFTH AVENUE',
#    'GRAND VOYAGER',
#    'GTS',
#    'IMPERIAL',
#    'INTREPID',
#    'LEBARON',
#    'LHS',
#    'NEON',
#    'NEW YORKER',
#    'OTHER',
#    'PACIFICA',
#    'PROWLER',
#    'PT CRUISER',
#    'SARATOGA',
#    'SEBRING',
#    'STRATUS',
#    'TOWN&COUNTRY',
#    'VIPER',
#    'VISION',
#    'VOYAGER']},
#  'CITROEN': {'name': 'CITROEN',
#   'models': ['2CV',
#    'AX',
#    'BERLINGO VP',
#    'BERLINGO VU',
#    'BX',
#    'C CROSSER',
#    'C ELYSEE',
#    'C1',
#    'C15',
#    'C2',
#    'C25',
#    'C3',
#    'C3 AIRCROSS',
#    'C3 PICASSO',
#    'C3 PLURIEL',
#    'C4',
#    'C4 AIRCROSS',
#    'C4 GRAND PICASSO',
#    'C4 PICASSO',
#    'C5',
#    'C5 AIRCROSS',
#    'C6',
#    'C8',
#    'CX',
#    'DS3',
#    'DS4',
#    'DS5',
#    'EVASION',
#    'GS/GSA',
#    'JUMPER',
#    'JUMPY',
#    'NEMO',
#    'SAXO',
#    'SPACETOURER',
#    'VISA',
#    'XANTIA',
#    'XM',
#    'XSARA',
#    'XSARA PICASSO',
#    'ZX']},
#  'CTTM': {'name': 'CTTM',
#   'models': ['86121A',
#    '871210',
#    '87121A',
#    '871220',
#    '87122B',
#    '87130D',
#    '87140B',
#    '871430',
#    '87151E',
#    '87160A',
#    '932200',
#    '972200',
#    '97221A']},
#  'DACIA': {'name': 'DACIA',
#   'models': ['1300', 'DUSTER', 'LOGAN', 'NOVA', 'SANDERO', 'SOLENZA']},
#  'DADYW': {'name': 'DADYW', 'models': ['DD 125', 'DD 150', 'DD 250']},
#  'DAEWOO': {'name': 'DAEWOO',
#   'models': ['BC SERIES',
#    'BF SERIES',
#    'BH SERIES',
#    'BM SERIES',
#    'BS SERIES',
#    'BV SERIES',
#    'BX SERIES',
#    'CIELO',
#    'DAMAS',
#    'ESPERO',
#    'EVANDA',
#    'GENTRA',
#    'KALOS',
#    'KORANDO',
#    'LABO',
#    'LACETTI',
#    'LANOS',
#    'LE MANS',
#    'LEGANZA',
#    'LESTAR',
#    'LUBLIN',
#    'MAGNUS',
#    'MATIZ',
#    'MUSSO',
#    'NEXIA',
#    'NOVUS',
#    'NUBIRA',
#    'OTHER',
#    'PRINCE',
#    'RACER',
#    'REZZO',
#    'TACUMA',
#    'TICO',
#    'WINSTORM']},
#  'DAF': {'name': 'DAF',
#   'models': ['TRUCKS 105 SERIES',
#    'TRUCKS 1700',
#    'TRUCKS 1900',
#    'TRUCKS 200',
#    'TRUCKS 2100',
#    'TRUCKS 2300',
#    'TRUCKS 2500',
#    'TRUCKS 3300',
#    'TRUCKS 400',
#    'TRUCKS 45 SERIES',
#    'TRUCKS 50 SERIES',
#    'TRUCKS 55 SERIES',
#    'TRUCKS 60 SERIES',
#    'TRUCKS 65 SERIES',
#    'TRUCKS 70 SERIES',
#    'TRUCKS 75 SERIES',
#    'TRUCKS 85 SERIES',
#    'TRUCKS 95 SERIES',
#    'TRUCKS CF SERIES',
#    'TRUCKS LF SERIES',
#    'TRUCKS XF SERIES']},
#  'DAIHATSU': {'name': 'DAIHATSU',
#   'models': ['APPLAUSE',
#    'ATRAI',
#    'CHARADE',
#    'CHARMANT',
#    'COPEN',
#    'CUORE',
#    'DELTA',
#    'FEROZA',
#    'GRAN MOVE',
#    'HIJET',
#    'MATERIA',
#    'MAX',
#    'MOVE',
#    'ROCKY',
#    'SIRION',
#    'TERIOS',
#    'TREVIS',
#    'YRV']},
#  'DATSUN': {'name': 'DATSUN', 'models': ['MI DO', 'ON DO']},
#  'DERBI': {'name': 'DERBI', 'models': ['GP 1', 'MULHACEN']},
#  'DERWAYS': {'name': 'DERWAYS',
#   'models': ['AURORA',
#    'COWBOY',
#    'HOWER H3',
#    'HOWER H3/H5',
#    'HOWER H5',
#    'LAND CROWN',
#    'PLUTUS',
#    'SALADIN',
#    'SHUTTLE']},
#  'DESERT RAVEN': {'name': 'DESERT RAVEN',
#   'models': ['ARIZONA', 'NEVADA', 'VEGAS']},
#  'DIZEL-S': {'name': 'DIZEL-S',
#   'models': ['600220', '600320', '600832', '600845', '906606', '906610']},
#  'DIZEL-TS': {'name': 'DIZEL-TS', 'models': ['9668', '966810', 'PPC 96781']},
#  'DNESTR': {'name': 'DNESTR', 'models': ['8523 10', '935702']},
#  'DODGE': {'name': 'DODGE',
#   'models': ['ARIES',
#    'AVENGER',
#    'CALIBER',
#    'CARAVAN',
#    'CHALLENGER',
#    'CHARGER',
#    'COLT',
#    'DAKOTA',
#    'DAYTONA',
#    'DURANGO',
#    'DYNASTY',
#    'INTREPID',
#    'JOURNEY',
#    'MAGNUM',
#    'NEON',
#    'NITRO',
#    'RAIDER',
#    'RAM',
#    'RAM VAN',
#    'SHADOW',
#    'SPIRIT',
#    'SPRINTER',
#    'STEALTH',
#    'STRATUS',
#    'VIPER']},
#  'DONG FENG': {'name': 'DONG FENG',
#   'models': ['1020',
#    '1030',
#    '1044',
#    '1045',
#    '1063',
#    '1074',
#    '3251',
#    '3257',
#    '3261',
#    '3310',
#    '4181',
#    '4251',
#    '5251',
#    '6600',
#    '6720',
#    'AX7',
#    'H30 CROSS',
#    'MPV',
#    'S30']},
#  'DONINVEST': {'name': 'DONINVEST', 'models': ['ASSOL', 'KONDOR', 'ORION']},
#  'DROGMOLLER': {'name': 'DROGMOLLER',
#   'models': ['E310', 'E320', 'E330', 'E430']},
#  'DUCATI': {'name': 'DUCATI',
#   'models': ['DESMOSEDICI RR',
#    'DIAVEL',
#    'HYPERMOTARD',
#    'MH990E',
#    'MONSTER',
#    'MULTISTRADA',
#    'PANIGALE',
#    'SCRAMBLER',
#    'SPORTCLASSIC',
#    'SPORTTOURING',
#    'STREETFIGHTER',
#    'SUPERBIKE',
#    'SUPERSPORT']},
#  'EKSMASH': {'name': 'EKSMASH',
#   'models': ['83360A', '90180C', '90180D', '90185D']},
#  'ELAZ': {'name': 'ELAZ', 'models': ['AC 32']},
#  'ELIS': {'name': 'ELIS', 'models': ['711510', '711511', '711521']},
#  'EPK': {'name': 'EPK', 'models': ['9484 10']},
#  'ERMZ': {'name': 'ERMZ', 'models': ['OTHER']},
#  'EUROTEX': {'name': 'EUROTEX', 'models': ['GW125', 'GW150', 'GW200']},
#  'EXPEDICIYA': {'name': 'EXPEDICIYA',
#   'models': ['BIZNES',
#    'FERMER',
#    'RECHNIK',
#    'STANDART',
#    'STANDART+',
#    'UNIVERSAL']},
#  'EZSA': {'name': 'EZSA', 'models': ['OTHER']},
#  'FAW': {'name': 'FAW',
#   'models': ['BESTURN B50',
#    'BESTURN X40',
#    'BESTURN X80',
#    'CA1010/1011',
#    'CA1020',
#    'CA1031',
#    'CA1041',
#    'CA1047',
#    'CA1051',
#    'CA1061',
#    'CA1083',
#    'CA3250',
#    'CA3252',
#    'CA3253',
#    'CA3310',
#    'CA3312',
#    'CA3318',
#    'CA4180',
#    'CA4250',
#    'CA4252',
#    'CA5031',
#    'CA5040',
#    'CA5051',
#    'CA5250',
#    'CA6350',
#    'CA6371',
#    'CA6420',
#    'CA7110',
#    'OLEY',
#    'TIGER V',
#    'V2',
#    'V5',
#    'VITA']},
#  'FEKON': {'name': 'FEKON', 'models': ['FK150', 'FK200']},
#  'FERRARI': {'name': 'FERRARI',
#   'models': ['328',
#    '348',
#    '360',
#    '456',
#    '458',
#    '488',
#    '512',
#    '550',
#    '575',
#    '599',
#    '612',
#    '812 SUPERFAST',
#    'CALIFORNIA',
#    'F12 BERLINETTA',
#    'F355',
#    'F40',
#    'F430',
#    'F8 SPIDER',
#    'F8 TRIBUTO',
#    'FF',
#    'GTC 4LUSSO',
#    'PORTOFINO']},
#  'FGUP PRIBOROSTROITELNYJ ZAVOD': {'name': 'FGUP PRIBOROSTROITELNYJ ZAVOD',
#   'models': ['8296']},
#  'FIAT': {'name': 'FIAT',
#   'models': ['124',
#    '126',
#    '127',
#    '128',
#    '131',
#    '132',
#    '147',
#    '1500',
#    '242',
#    '500',
#    'ALBEA',
#    'BARCHETTA',
#    'BRAVA',
#    'BRAVO',
#    'CINQUECENTO',
#    'COUPE',
#    'CROMA',
#    'DOBLO',
#    'DOBLO CARGO',
#    'DUCATO',
#    'DUNA',
#    'FIORINO',
#    'FREEMONT',
#    'FULLBACK',
#    'GRANDE PUNTO',
#    'IDEA',
#    'LINEA',
#    'MAREA',
#    'MULTIPLA',
#    'PALIO',
#    'PANDA',
#    'PUNTO',
#    'QUBO',
#    'REGATA',
#    'RITMO',
#    'SCUDO',
#    'SEDICI',
#    'SEICENTO',
#    'SIENA',
#    'STILO',
#    'TALENTO',
#    'TEMPRA',
#    'TIPO',
#    'ULYSSE',
#    'UNO']},
#  'FKM': {'name': 'FKM', 'models': ['PUNCHER']},
#  'FLIEGL': {'name': 'FLIEGL',
#   'models': ['DHKS 350', 'SDS 350', 'SDS 390', 'SDS 400']},
#  'FORD': {'name': 'FORD',
#   'models': ['AEROSTAR',
#    'BRONCO',
#    'C MAX',
#    'CAPRI',
#    'CARGO',
#    'CLUB WAGON',
#    'CONTOUR',
#    'COUGAR',
#    'COURIER',
#    'CROWN VICTORIA',
#    'E 350',
#    'E SERIES',
#    'ECONOLINE',
#    'ECONOVAN',
#    'ECOSPORT',
#    'EDGE',
#    'ESCAPE',
#    'ESCORT',
#    'EXCURSION',
#    'EXPEDITION',
#    'EXPLORER',
#    'F 100',
#    'F 150',
#    'F 250',
#    'F 350',
#    'F 450',
#    'F 550',
#    'F 600',
#    'F 650',
#    'F 750',
#    'F MAX',
#    'FESTIVA',
#    'FIESTA',
#    'FIVE HUNDRED',
#    'FLEX',
#    'FOCUS',
#    'FREESTYLE',
#    'FUSION',
#    'GALAXY',
#    'GRANADA',
#    'GT',
#    'KA',
#    'KUGA',
#    'LASER',
#    'LTD',
#    'MAVERIC',
#    'MONDEO',
#    'MUSTANG',
#    'ORION',
#    'P 100',
#    'PROBE',
#    'PUMA',
#    'RANGER',
#    'S MAX',
#    'SCORPIO',
#    'SIERRA',
#    'TAUNUS',
#    'TAURUS',
#    'TEMPO',
#    'THUNDERBIRD',
#    'TOURNEO',
#    'TOURNEO CONNECT',
#    'TOURNEO CUSTOM',
#    'TRANSIT',
#    'TRANSIT CONNECT',
#    'TRANSIT CUSTOM',
#    'WINDSTAR']},
#  'FORSAGE': {'name': 'FORSAGE', 'models': ['450']},
#  'FORTUNE': {'name': 'FORTUNE', 'models': ['DF150']},
#  'FOTON': {'name': 'FOTON',
#   'models': ['BJ 1039',
#    'BJ 1041',
#    'BJ 1051',
#    'BJ 1061',
#    'BJ 1069',
#    'BJ 1093',
#    'BJ 1099',
#    'BJ 1121',
#    'BJ 1138',
#    'BJ 1151',
#    'BJ 1251',
#    'BJ 3251',
#    'BJ 3313',
#    'BJ 4181',
#    'BJ 4251',
#    'BJ 5369',
#    'S120',
#    'SAUVANA',
#    'TUNLAND',
#    'VIEW']},
#  'FOXTANK': {'name': 'FOXTANK', 'models': ['966611']},
#  'FREIGHTLINER': {'name': 'FREIGHTLINER',
#   'models': ['ARGOSY',
#    'BUSINESS',
#    'CENTURY',
#    'CLASSIC',
#    'COLUMBIA',
#    'CORONADO',
#    'FL70',
#    'FLD',
#    'SPRINTER']},
#  'FRUEHAUF': {'name': 'FRUEHAUF',
#   'models': ['BENALU',
#    'ET34A1',
#    'RC19C1',
#    'RC19C3',
#    'REC24C',
#    'S136P3S',
#    'T34CGN',
#    'TBPD35',
#    'TBPD36',
#    'TCPC34',
#    'TD34C1',
#    'TE34CC',
#    'TESD39',
#    'TF31C1',
#    'TF34C1',
#    'TF34V1',
#    'TF38C1',
#    'TVMD39',
#    'TX34C5',
#    'TX34CC',
#    'TX34CW',
#    'XXD32C',
#    'XXD33C',
#    'XXED32',
#    'XXT34C',
#    'XXT34T']},
#  'G-MAX': {'name': 'G-MAX', 'models': ['RACER']},
#  'GAZ': {'name': 'GAZ',
#   'models': ['14',
#    '1731',
#    '2217',
#    '2310',
#    '2330',
#    '24',
#    '2705',
#    '2752',
#    '3102',
#    '3110',
#    '3111',
#    '3221',
#    '3302',
#    '3306',
#    '3307',
#    '3308',
#    '3309',
#    '3310',
#    '4301',
#    '51',
#    '52',
#    '53',
#    '63',
#    '66',
#    '69',
#    'GAZELLE NEXT',
#    'GAZON NEXT',
#    'M21',
#    'MARSHAL',
#    'OTHER',
#    'SADKO NEXT',
#    'VALDAI NEXT',
#    'VOLGA SIBER']},
#  'GEELY': {'name': 'GEELY',
#   'models': ['ATLAS',
#    'ATLAS PRO',
#    'CK (OTAKA)',
#    'COOLRAY',
#    'EMGRAND',
#    'EMGRAND 7',
#    'EMGRAND EC7',
#    'EMGRAND GT',
#    'EMGRAND X7',
#    'FC (VISION)',
#    'GC6',
#    'GC7',
#    'GS',
#    'LC',
#    'MAPLE',
#    'MK',
#    'MK CROSS',
#    'SC7',
#    'TUGELLA']},
#  'GENESIS': {'name': 'GENESIS', 'models': ['G70', 'G80', 'G90', 'GV80']},
#  'GEON': {'name': 'GEON', 'models': ['INVADER', 'PANTERA']},
#  'GILERA': {'name': 'GILERA', 'models': ['FUOCO', 'GP800', 'NEXUS', 'RUNNER']},
#  'GKB': {'name': 'GKB',
#   'models': ['8118',
#    '817',
#    '8183',
#    '819',
#    '8328',
#    '83412',
#    '83418',
#    '8350',
#    '8352',
#    '8527',
#    '8535',
#    '8551',
#    'OTHER']},
#  'GMC': {'name': 'GMC',
#   'models': ['ACADIA',
#    'CANYON',
#    'ENVOY',
#    'JIMMY',
#    'OTHER',
#    'SAFARI',
#    'SAVANA',
#    'SIERRA',
#    'TERRAIN',
#    'VANDURA',
#    'YUKON']},
#  'GOLAZ': {'name': 'GOLAZ', 'models': ['4244', '5251', '5291', '6228']},
#  'GOLDEN DRAGON': {'name': 'GOLDEN DRAGON',
#   'models': ['XML6106E',
#    'XML6112UE',
#    'XML6126JR',
#    'XML6127',
#    'XML6127CN',
#    'XML6127JR',
#    'XML6129E',
#    'XML6482E',
#    'XML6483E',
#    'XML6601C',
#    'XML6720C',
#    'XML6796E',
#    'XML6840UE',
#    'XML6896E',
#    'XML6957JR']},
#  'GONOW': {'name': 'GONOW',
#   'models': ['AOOSED G5', 'TROY 100', 'WAY M1', 'WAY M2', 'WAY V1']},
#  'GORA-HOLDING': {'name': 'GORA-HOLDING', 'models': ['8290', '82901']},
#  'GRAZ': {'name': 'GRAZ',
#   'models': ['PC 8638 12 01',
#    'PC 8638 12 02',
#    'PC 86391',
#    'PC 86391 10 01',
#    'PC 86531',
#    'PPC 912502',
#    'PPC 912503',
#    'PPC 912504',
#    'PPC 912505',
#    'PPC 912506',
#    'PPC 912507',
#    'PPC 91315',
#    'PPC 91323A 10',
#    'PPC 91374',
#    'PPC 91375',
#    'PPC 91381',
#    'PPC 91386',
#    'PPC 91389',
#    'PPC 9138C',
#    'PPC 91391',
#    'PPC 91392',
#    'PPC 91394 10',
#    'PPC 91399',
#    'PPC 91399C',
#    'PPC 92399 10',
#    'PPC 96221',
#    'PPC 96221 03',
#    'PPC 96221 04',
#    'PPC 96221 06',
#    'PPC 96221 07',
#    'PPC 96222',
#    'PPC 96222 02',
#    'PPC 96223',
#    'PPC 96226',
#    'PPC 96226 03',
#    'PPC 96226 04',
#    'PPC 96227',
#    'PPC 96227 03',
#    'PPC 96227 04',
#    'PPC 96231',
#    'PPC 96231 03',
#    'PPC 96231 05',
#    'PPC 96232 10']},
#  'GREAT WALL': {'name': 'GREAT WALL',
#   'models': ['COOLBEAR',
#    'COWRY',
#    'DEER',
#    'FLORID',
#    'HOVER H3',
#    'HOVER H5',
#    'HOVER H6',
#    'HOVER M2',
#    'HOVER M4',
#    'OTHER',
#    'PEGASUS',
#    'PERI',
#    'RUV SING',
#    'SAILOR',
#    'SOCOOL',
#    'SUV G5 SAFE',
#    'VOLEEX C10',
#    'VOLEEX C30',
#    'WINGLE']},
#  'GRUNWALD': {'name': 'GRUNWALD',
#   'models': ['9453 10',
#    '9453 10 01',
#    '9453 10 10',
#    '9453 10 30',
#    '9453 10 40',
#    '9453 10 41',
#    '9453 10 50',
#    '9453 10 60',
#    '9453 12 60',
#    '945430 10',
#    '9539 10',
#    '9539 10 50',
#    '9539 10 60',
#    '9539 70 10']},
#  'GRYPHON': {'name': 'GRYPHON', 'models': ['ORION', 'ROCKET']},
#  'GT7': {'name': 'GT7',
#   'models': ['C 34',
#    'C 34M',
#    'PPC 28',
#    'PPC 30',
#    'PPC 45',
#    'PPCT 20',
#    'PPCT 31',
#    'PPCT 36',
#    'PPCT 44',
#    'PPCZ 12 885M',
#    'PPCZ 20',
#    'PPCZ 31']},
#  'GTS TRAILER': {'name': 'GTS TRAILER',
#   'models': ['7149 10',
#    '7149 10 01',
#    '7149 10 02',
#    '714901 10 02',
#    '71491 10 01']},
#  'GUVEN GUTEWOLF': {'name': 'GUVEN GUTEWOLF', 'models': ['GMS']},
#  'HAFEI': {'name': 'HAFEI', 'models': ['BRIO', 'SAIBAO', 'SIMBO']},
#  'HAIMA': {'name': 'HAIMA', 'models': ['3', '7']},
#  'HAOBON': {'name': 'HAOBON', 'models': ['HB150T']},
#  'HAOJIN': {'name': 'HAOJIN', 'models': ['HJ110', 'HJ125', 'HJ150']},
#  'HARLEY-DAVIDSON': {'name': 'HARLEY-DAVIDSON',
#   'models': ['1200 SPORTSTER',
#    '883 SPORTSTER',
#    'BLACKLINE',
#    'BREAKOUT',
#    'CROSS BONES',
#    'CVO LIMITED',
#    'CVO SOFTAIL',
#    'DYNA',
#    'DYNA CVO',
#    'DYNA FAT BOB',
#    'DYNA LOW RIDER',
#    'DYNA STREET BOB',
#    'DYNA SUPER GLIDE',
#    'DYNA SWITCHBACK',
#    'DYNA WIDE GLIDE',
#    'ELECTRA GLIDE',
#    'FAT BOY',
#    'FREEWHEELER',
#    'FXDR 114',
#    'HERITAGE',
#    'NIGHT TRAIN',
#    'OTHER',
#    'ROAD GLIDE',
#    'ROAD KING',
#    'ROCKER',
#    'SOFTAIL',
#    'SOFTAIL CUSTOM',
#    'SOFTAIL DELUXE',
#    'SOFTAIL DEUCE',
#    'SOFTAIL FAT BOB',
#    'SOFTAIL LOW RIDER',
#    'SOFTAIL SLIM',
#    'SOFTAIL SPORT GLIDE',
#    'SOFTAIL SPRINGER',
#    'SOFTAIL STANDARD',
#    'SOFTAIL STREET BOB',
#    'STREET GLIDE',
#    'TRI GLIDE',
#    'ULTRA LIMITED',
#    'V ROD',
#    'V ROD MUSCLE',
#    'VRSC',
#    'VRSCA',
#    'VRSCB',
#    'XG500',
#    'XG750',
#    'XR1200']},
#  'HARTUNG': {'name': 'HARTUNG',
#   'models': ['8319',
#    '832000',
#    '8426 10',
#    '9013',
#    '9025',
#    '9027',
#    '942700',
#    '943000',
#    '94302 10',
#    '94303 10',
#    '943100',
#    '943220',
#    '9433 10',
#    '943310',
#    '943311 10',
#    '94332 10',
#    '943322 10',
#    '943323 10',
#    '943331 10',
#    '94337 10',
#    '9438 10',
#    '944000',
#    '9460',
#    '9889']},
#  'HAVAL': {'name': 'HAVAL',
#   'models': ['F7', 'F7X', 'H2', 'H5', 'H6', 'H6 COUPE', 'H8', 'H9', 'JOLION']},
#  'HAWTAI': {'name': 'HAWTAI', 'models': ['BOLIGER']},
#  'HAZ': {'name': 'HAZ', 'models': ['3250']},
#  'HIGER': {'name': 'HIGER',
#   'models': ['KLQ6109Q',
#    'KLQ6118G',
#    'KLQ6118GL',
#    'KLQ6118GS',
#    'KLQ6119TQ',
#    'KLQ6122B',
#    'KLQ6128LQ',
#    'KLQ6129Q',
#    'KLQ6720B1G',
#    'KLQ6720B1L',
#    'KLQ6728G',
#    'KLQ6826Q',
#    'KLQ6840',
#    'KLQ6885',
#    'KLQ6891GA',
#    'KLQ6928Q']},
#  'HINO': {'name': 'HINO', 'models': ['300', '500', '700', 'DUTRO', 'RANGER']},
#  'HONDA': {'name': 'HONDA',
#   'models': ['ACCORD',
#    'ACCORD CROSSTOUR',
#    'ACTY',
#    'AIRWAVE',
#    'APE',
#    'AVANCIER',
#    'CB',
#    'CBF',
#    'CBR',
#    'CBX',
#    'CITY',
#    'CIVIC',
#    'CL',
#    'CLICK',
#    'CMX',
#    'CONCERTO',
#    'CR',
#    'CR V',
#    'CR Z',
#    'CRF',
#    'CRX',
#    'CTX',
#    'DN',
#    'EDIX',
#    'ELEMENT',
#    'FIT',
#    'FMX',
#    'FORESIGHT',
#    'FORZA',
#    'FR V',
#    'GB',
#    'GL',
#    'HR V',
#    'INSIGHT',
#    'INSPIRE',
#    'INTEGRA',
#    'JAZZ',
#    'LEGEND',
#    'LOGO',
#    'MOBILIO',
#    'MSX',
#    'NC',
#    'NR',
#    'NRX',
#    'NS',
#    'NSR',
#    'NSX',
#    'NT',
#    'NV',
#    'NX',
#    'ODYSSEY',
#    'OTHER',
#    'PASSPORT',
#    'PC',
#    'PCX',
#    'PILOT',
#    'PRELUDE',
#    'REBEL',
#    'RIDGELINE',
#    'S 2000',
#    'SABER',
#    'SCOOPY',
#    'SES',
#    'SHUTTLE',
#    'SILVER WING',
#    'SL',
#    'SLR',
#    'SPACY',
#    'ST',
#    'STEED',
#    'STREAM',
#    'TORNEO',
#    'VF',
#    'VFR',
#    'VIGOR',
#    'VT',
#    'VTR',
#    'VTX',
#    'XL',
#    'XLR',
#    'XLV',
#    'XR',
#    'XRV',
#    'ZOOMER']},
#  'HOWO': {'name': 'HOWO',
#   'models': ['1167',
#    '1257',
#    '1317',
#    '2167',
#    '3167',
#    '3252',
#    '3257',
#    '3267',
#    '3315',
#    '3317',
#    '3327',
#    '3407',
#    '3537',
#    '4187',
#    '4257',
#    '4327',
#    '5141',
#    '5167',
#    '5257',
#    '5317',
#    '5327',
#    '5407']},
#  'HUATIAN': {'name': 'HUATIAN', 'models': ['HT125T', 'HT150T']},
#  'HUMBAUR': {'name': 'HUMBAUR',
#   'models': ['BALIOS',
#    'BIG ONE',
#    'CARRUS',
#    'H',
#    'HA',
#    'HF',
#    'HM',
#    'HP',
#    'HSA',
#    'HSA 2006',
#    'HT',
#    'HU',
#    'L',
#    'MAXIMUS',
#    'PEGASUS',
#    'RAPID',
#    'REXUS',
#    'SPIRIT',
#    'XANTHOS']},
#  'HUMMER': {'name': 'HUMMER', 'models': ['H1', 'H2', 'H3']},
#  'HUSQVARNA': {'name': 'HUSQVARNA', 'models': ['SM', 'TE']},
#  'HYOSUNG': {'name': 'HYOSUNG', 'models': ['GV']},
#  'HYUNDAI': {'name': 'HYUNDAI',
#   'models': ['ACCENT',
#    'AERO',
#    'AERO CITY',
#    'AERO EXPRESS',
#    'AERO QUEEN',
#    'AERO SPACE',
#    'AERO TOWN',
#    'ATOS',
#    'AVANTE',
#    'CHORUS',
#    'COUNTY',
#    'COUPE',
#    'COUPE/TIBURON/TUSCANI',
#    'CRETA',
#    'DINASTY',
#    'ELANTRA',
#    'EQUUS',
#    'EXCEL',
#    'GALLOPER',
#    'GENESIS',
#    'GENESIS COUPE',
#    'GETZ',
#    'GOLD',
#    'GRACE',
#    'GRAND SANTA FE',
#    'GRANDEUR',
#    'H 1',
#    'H 200',
#    'HD 120',
#    'HD 170',
#    'HD 250',
#    'HD 260',
#    'HD 270',
#    'HD 35',
#    'HD 370',
#    'HD 450',
#    'HD 500',
#    'HD 65',
#    'HD 700',
#    'HD 72',
#    'HD 78',
#    'I10',
#    'I20',
#    'I30',
#    'I40',
#    'IONIQ',
#    'IX35',
#    'IX55',
#    'KONA',
#    'LANTRA',
#    'LAVITA',
#    'MARCIA',
#    'MATRIX',
#    'MEGATRUCK',
#    'MIGHTY',
#    'OTHER',
#    'PALISADE',
#    'PONY',
#    'PORTER/H 100',
#    'SANTA FE',
#    'SANTAMO',
#    'SCOUPE',
#    'SOLARIS',
#    'SONATA',
#    'STAREX',
#    'STELLAR',
#    'TERRACAN',
#    'TIBURON',
#    'TRAJET',
#    'TUCSON',
#    'TUSCANI',
#    'UNIVERSE',
#    'VELOSTER',
#    'VERACRUZ',
#    'VERNA',
#    'XCIENT',
#    'XG']},
#  'IKARUS': {'name': 'IKARUS',
#   'models': ['250', '253', '256', '260', '263', '280', '415', '435']},
#  'INFINITI': {'name': 'INFINITI',
#   'models': ['EX',
#    'EX/QX50',
#    'FX',
#    'FX/QX70',
#    'G',
#    'G/Q50/Q60',
#    'I',
#    'J',
#    'JX',
#    'JX/QX60',
#    'M',
#    'M/Q70',
#    'Q',
#    'Q30',
#    'Q50',
#    'Q60',
#    'Q70',
#    'QX/QX80',
#    'QX30',
#    'QX4',
#    'QX50',
#    'QX56',
#    'QX60',
#    'QX70',
#    'QX80']},
#  'IPV': {'name': 'IPV',
#   'models': ['8590FK', '8590FS', '9487SN', '9487SR', '9487ST']},
#  'IRBIS': {'name': 'IRBIS',
#   'models': ['ALPHA',
#    'BWS',
#    'GARPIA',
#    'GR',
#    'GRACE',
#    'GS',
#    'GS200',
#    'IROKEZ',
#    'LX GTR',
#    'NIRVANA',
#    'PROMETEY',
#    'RZR',
#    'TTR250',
#    'TTR250R',
#    'VIRAGO',
#    'VJ',
#    'VR 1',
#    'XR250R']},
#  'ISTRAIL': {'name': 'ISTRAIL', 'models': ['PL03']},
#  'ISUZU': {'name': 'ISUZU',
#   'models': ['AMIGO',
#    'AXIOM',
#    'BIGHORN',
#    'C SERIES',
#    'D MAX',
#    'E SERIES',
#    'ELF',
#    'FARGO',
#    'FORWARD',
#    'GEMINI',
#    'GIGA',
#    'MIDI',
#    'NKR',
#    'NLR',
#    'NMR',
#    'NPR',
#    'NPS',
#    'NQR',
#    'RODEO',
#    'TROOPER',
#    'VEHICROSS']},
#  'IVECO': {'name': 'IVECO',
#   'models': ['DAILY',
#    'EUROCARGO',
#    'EUROSTAR',
#    'EUROTECH',
#    'EUROTRAKKER',
#    'OTHER',
#    'PEGASO',
#    'SFR 160',
#    'SFR 210',
#    'STRALIS',
#    'TRAKKER']},
#  'IZH': {'name': 'IZH',
#   'models': ['2125', '2126', '2715', '2717', 'JUNKER', 'PLANETA', 'UPITER']},
#  'IZH-AVTOPRICEP': {'name': 'IZH-AVTOPRICEP',
#   'models': ['719010', '719011', '719012', '719013', '719014', '719015']},
#  'JAC': {'name': 'JAC',
#   'models': ['HFC1020',
#    'HFC1040',
#    'HFC1045',
#    'HFC1062',
#    'HFC1083',
#    'HFC3252',
#    'HFC6100',
#    'IEV7S',
#    'J5',
#    'J7',
#    'N75',
#    'REFINE',
#    'REIN',
#    'S3',
#    'S5',
#    'S7']},
#  'JAGUAR': {'name': 'JAGUAR',
#   'models': ['E PACE',
#    'E TYPE',
#    'F PACE',
#    'F TYPE',
#    'I PACE',
#    'S TYPE',
#    'X TYPE',
#    'XE',
#    'XF',
#    'XJ',
#    'XK']},
#  'JAWA': {'name': 'JAWA', 'models': ['125', '250', '350', '640', '650']},
#  'JEEP': {'name': 'JEEP',
#   'models': ['CHEROKEE',
#    'CJ',
#    'COMMANCHE',
#    'COMMANDER',
#    'COMPASS',
#    'GRAND CHEROKEE',
#    'LIBERTY',
#    'PATRIOT',
#    'RENEGADE',
#    'WAGONEER',
#    'WRANGLER']},
#  'JMC': {'name': 'JMC', 'models': ['1032', '1043', '1051', '1052', 'BAODIAN']},
#  'JONWAY': {'name': 'JONWAY', 'models': ['CJ', 'JS']},
#  'JYKI': {'name': 'JYKI',
#   'models': ['P31 TO 136',
#    'V31 TO 82',
#    'V42 TJ 102',
#    'V42 TJ 110',
#    'V42 TO 110',
#    'V42 TO 118',
#    'V42 TO 82']},
#  'KAESSBOHRER': {'name': 'KAESSBOHRER',
#   'models': ['CS',
#    'DL',
#    'FL',
#    'LB3E',
#    'LB4E',
#    'LB5E',
#    'LB6E',
#    'OTHER',
#    'RUSLAN',
#    'SSL',
#    'STB',
#    'STS',
#    'XS']},
#  'KAITONG': {'name': 'KAITONG', 'models': ['1', '2', '3', '4', '6']},
#  'KAMA': {'name': 'KAMA',
#   'models': ['870600', '870612', '870651', '9423A0', '9423B0', '981120']},
#  'KAMAZ': {'name': 'KAMAZ',
#   'models': ['4237',
#    '4308',
#    '4310',
#    '43101',
#    '43105',
#    '43106',
#    '4311',
#    '43114',
#    '43118',
#    '4325',
#    '43253',
#    '43255',
#    '4326',
#    '43265',
#    '43269',
#    '4350',
#    '43501',
#    '43502',
#    '4410',
#    '44108',
#    '4425',
#    '4510',
#    '4514',
#    '4925',
#    '5308',
#    '5320',
#    '5321',
#    '53211',
#    '53212',
#    '53213',
#    '53215',
#    '5322',
#    '53228',
#    '53229',
#    '5325',
#    '53253',
#    '5350',
#    '53501',
#    '53504',
#    '5360',
#    '53605',
#    '5387',
#    '5410',
#    '5411',
#    '54112',
#    '54115',
#    '54118',
#    '5460',
#    '5490',
#    '5510',
#    '55102',
#    '5511',
#    '55111',
#    '6282',
#    '6350',
#    '63501',
#    '63505',
#    '6360',
#    '6426',
#    '6460',
#    '6511',
#    '65111',
#    '65115',
#    '65116',
#    '65117',
#    '6520',
#    '65201',
#    '65207',
#    '6522',
#    '65221',
#    '65222',
#    '65224',
#    '65225',
#    '65226',
#    '6540',
#    '6560',
#    '65659',
#    '6580',
#    '65806',
#    '6595',
#    '7330',
#    '8120',
#    '8125',
#    'OTHER']},
#  'KANSAS': {'name': 'KANSAS', 'models': ['DF150']},
#  'KAPRI': {'name': 'KAPRI',
#   'models': ['96398',
#    '9639A',
#    '9639B',
#    '9639H',
#    '9639L',
#    'PC 15',
#    'PPC 25',
#    'PPC 25T',
#    'PPC 30',
#    'PPC 30T',
#    'PPC 33',
#    'PPC 33T',
#    'PPC 37']},
#  'KAROSA': {'name': 'KAROSA',
#   'models': ['734', 'B731', 'C934', 'C954', 'C956', 'LC735']},
#  'KARZ': {'name': 'KARZ', 'models': ['PF 01 FERMER']},
#  'KAVZ': {'name': 'KAVZ',
#   'models': ['324400',
#    '324410',
#    '3270',
#    '3271',
#    '3976',
#    '4224',
#    '4235',
#    '4238',
#    '4270',
#    '685',
#    'OTHER']},
#  'KAWASAKI': {'name': 'KAWASAKI',
#   'models': ['1000 GTR',
#    '1400 GTR',
#    'D TRACKER',
#    'ELIMINATOR EL',
#    'ELIMINATOR ZL 1000',
#    'ELIMINATOR ZL 600',
#    'ELIMINATOR ZL 900',
#    'ER 5',
#    'ER 6',
#    'KLE',
#    'KLR650',
#    'KLX',
#    'KZ',
#    'NINJA 250',
#    'NINJA 250R',
#    'NINJA 300',
#    'NINJA 400R',
#    'NINJA 500R',
#    'NINJA 650',
#    'NINJA 650R',
#    'NINJA H2',
#    'NINJA ZX 1000',
#    'NINJA ZX 1100',
#    'NINJA ZX 1200',
#    'NINJA ZX 1400',
#    'NINJA ZX 6R',
#    'NINJA ZX 7R',
#    'NINJA ZX 9R',
#    'SUPER SHERPA',
#    'VERSYS 1000',
#    'VERSYS 650',
#    'VERSYS X 300',
#    'VULCAN EN',
#    'VULCAN VN 1500',
#    'VULCAN VN 1600',
#    'VULCAN VN 1700',
#    'VULCAN VN 2000',
#    'VULCAN VN 750',
#    'VULCAN VN 800',
#    'VULCAN VN 900',
#    'W800',
#    'Z 1000',
#    'Z 250',
#    'Z 300',
#    'Z 400',
#    'Z 750',
#    'Z 800',
#    'Z 900',
#    'ZEPHYR ZR 1000',
#    'ZEPHYR ZR 1100',
#    'ZEPHYR ZR 550',
#    'ZEPHYR ZR 750',
#    'ZR900B',
#    'ZRX 1100',
#    'ZRX 1200']},
#  'KEEWAY': {'name': 'KEEWAY',
#   'models': ['CRUISER', 'LANDCRUISER', 'SPEED', 'SUPERLIGHT', 'SUPERSHADOW']},
#  'KIA': {'name': 'KIA',
#   'models': ['AVELLA',
#    'BESTA',
#    'BONGO',
#    'CARENS',
#    'CARNIVAL',
#    'CARNIVAL/SEDONA',
#    'CEED',
#    'CERATO',
#    'CLARUS',
#    'GRANBIRD',
#    'GRANTO',
#    'JOICE',
#    'K SERIES',
#    'K5',
#    'K900',
#    'MAGENTIS',
#    'MAGENTIS/OPTIMA',
#    'MOHAVE',
#    'NIRO',
#    'OPIRUS',
#    'OPTIMA',
#    'OTHER',
#    'PICANTO',
#    'PREGIO',
#    'PRIDE',
#    'PROCEED',
#    'QUORIS',
#    'RETONA',
#    'RHINO',
#    'RIO',
#    'SEDONA',
#    'SELTOS',
#    'SEPHIA',
#    'SHUMA',
#    'SORENTO',
#    'SOUL',
#    'SPECTRA',
#    'SPECTRA/SEPHIA/SHUMA',
#    'SPORTAGE',
#    'SPORTAGE 1',
#    'SPORTAGE 2',
#    'SPORTAGE 3',
#    'SPORTAGE 4',
#    'STINGER',
#    'VENGA',
#    'XCEED']},
#  'KINFAN': {'name': 'KINFAN', 'models': ['KF110ZH B']},
#  'KMZ': {'name': 'KMZ',
#   'models': ['719400',
#    '7194B0',
#    '7194B1',
#    '7194C1',
#    '7194C2',
#    '7194F2',
#    '7194F5',
#    '8129',
#    '8136',
#    '8268',
#    '8284',
#    '828420',
#    '828421',
#    '828430',
#    '828431',
#    '828441',
#    '828451',
#    '8377',
#    'POLO PRAKTIK',
#    'POLO PROFI']},
#  'KOEGEL': {'name': 'KOEGEL',
#   'models': ['AN18',
#    'AN24',
#    'ANBS18',
#    'ANCO18',
#    'AVKA18',
#    'AVKA24',
#    'AVKF18',
#    'AVKF24',
#    'AVKT18',
#    'AW18',
#    'AWE18',
#    'GN20',
#    'GN24',
#    'JN18',
#    'JN24',
#    'JWE18',
#    'S24',
#    'S24 1',
#    'S24 2',
#    'S24 3',
#    'S24 4',
#    'S26',
#    'SF24',
#    'SF27',
#    'SFCM27',
#    'SFHB24',
#    'SFHB27',
#    'SFSB24',
#    'SKHK24',
#    'SKHL24',
#    'SKHS18',
#    'SKHS24',
#    'SKMP18',
#    'SKMP24',
#    'SKMS18',
#    'SN18',
#    'SN24',
#    'SN27',
#    'SNBS24',
#    'SNC18',
#    'SNC24',
#    'SNC27',
#    'SNCC24',
#    'SNCM24',
#    'SNCO24',
#    'SP24',
#    'SPKH18',
#    'SPKH24',
#    'SV24',
#    'SVKA24',
#    'SVKA27',
#    'SVKT24',
#    'SVKT27',
#    'SW24',
#    'SWCT24',
#    'YF18',
#    'YFHB18',
#    'YN18',
#    'YNC18',
#    'YWE18',
#    'ZVKA18',
#    'ZVKT18']},
#  'KOLUMAN': {'name': 'KOLUMAN', 'models': ['P400 HUCKEPACK']},
#  'KOME': {'name': 'KOME', 'models': ['JPPV 4', 'PPV 4', 'TPV 3KPK']},
#  'KORIDA-TECH': {'name': 'KORIDA-TECH',
#   'models': ['50100',
#    '50101',
#    '50104',
#    '50105',
#    '50106',
#    '50108',
#    '50110',
#    '50122',
#    '50125',
#    '50130']},
#  'KRAKER': {'name': 'KRAKER', 'models': ['CF Z']},
#  'KRAZ': {'name': 'KRAZ',
#   'models': ['250',
#    '255',
#    '256',
#    '257',
#    '258',
#    '260',
#    '6233',
#    '6320, 6322',
#    '6437',
#    '6443, 6444',
#    '6446',
#    '6503',
#    '6505',
#    '6510',
#    '8138']},
#  'KREON': {'name': 'KREON',
#   'models': ['PY TD 1600',
#    'PY TD 1800',
#    'PY TD 2000',
#    'PY TD 2200',
#    'PY TD 2500']},
#  'KRKZ': {'name': 'KRKZ', 'models': ['100', '150']},
#  'KROMHOUT': {'name': 'KROMHOUT',
#   'models': ['3APCC 12 27', '3COM 12 27', '3ZOH 12 27']},
#  'KRONE': {'name': 'KRONE',
#   'models': ['SD',
#    'SDC24',
#    'SDC27',
#    'SDF27',
#    'SDK24',
#    'SDK27',
#    'SDP24',
#    'SDP27',
#    'SDR24',
#    'SDR27',
#    'ZZ',
#    'ZZF18',
#    'ZZP18',
#    'ZZP20',
#    'ZZW18']},
#  'KTM': {'name': 'KTM',
#   'models': ['990 ADVENTURE',
#    'ADVENTURE',
#    'DESERT RACING',
#    'DUKE',
#    'ENDURO',
#    'EXC',
#    'RC390',
#    'SM',
#    'SMC',
#    'SMC R',
#    'SMR',
#    'SMT',
#    'SUPER COMPETITION',
#    'SUPERDUKE']},
#  'KUPAVA': {'name': 'KUPAVA',
#   'models': ['811000',
#    '813210',
#    '813211',
#    '813216',
#    '813220',
#    '813221',
#    '813222',
#    '813223',
#    '813226',
#    '813230',
#    '813251',
#    '813253',
#    '813260',
#    '813270',
#    '813280',
#    '813290',
#    '813300',
#    '813310',
#    '821000',
#    '822000',
#    '822001',
#    '822002',
#    '822004',
#    '822006',
#    '828100',
#    '871100',
#    '871110',
#    '873400',
#    '930011',
#    '930012',
#    '9300C0',
#    '9300T0',
#    '9300W0',
#    '93W000',
#    'OTHER']},
#  'KYMCO': {'name': 'KYMCO', 'models': ['AGILITY']},
#  'KZAP': {'name': 'KZAP',
#   'models': ['81021',
#    '8140',
#    '85241',
#    '8527',
#    '8994',
#    '9020',
#    '9324',
#    '9370',
#    '9385',
#    '9385 20',
#    '9385 30',
#    '9514',
#    '9516',
#    '9772',
#    '9982']},
#  'LADA': {'name': 'LADA',
#   'models': ['1117 KALINA WAGON',
#    '1118 KALINA SEDAN',
#    '1119 KALINA HATCHBACK',
#    '2101 CLASSIC',
#    '2102 CLASSIC',
#    '2103 CLASSIC',
#    '2104 CLASSIC',
#    '2105 CLASSIC',
#    '2106 CLASSIC',
#    '2107 CLASSIC',
#    '2108 SAMARA',
#    '2109 SAMARA',
#    '21099 SAMARA',
#    '2110 SEDAN',
#    '2111 WAGON',
#    '2112 HATCHBACK',
#    '2113 SAMARA 2',
#    '2114 SAMARA 2',
#    '2115 SAMARA 2',
#    '2120 NADEZHDA',
#    '2170 PRIORA SEDAN',
#    '2171 PRIORA WAGON',
#    '2172 PRIORA HATCHBACK',
#    '2190 GRANTA 2 SEDAN',
#    '2190 GRANTA SEDAN',
#    '2191 GRANTA 2 LIFTBACK',
#    '2191 GRANTA LIFTBACK',
#    '2192 GRANTA 2 HATCHBACK',
#    '2192 KALINA 2 HATCHBACK',
#    '2194 GRANTA 2 WAGON',
#    '2194 KALINA 2 WAGON',
#    '4X4',
#    '4X4 5 DOOR',
#    '4X4 VU',
#    'EL LADA',
#    'GRANTA VU',
#    'LARGUS VP',
#    'LARGUS VU',
#    'NIVA',
#    'OTHER',
#    'SAMARA VU',
#    'VESTA SEDAN',
#    'VESTA SW',
#    'XRAY']},
#  'LAG': {'name': 'LAG', 'models': ['O 3 CC']},
#  'LAKER': {'name': 'LAKER',
#   'models': ['HEAVY DUTY 300',
#    'HEAVY DUTY 400',
#    'HEAVY DUTY 500',
#    'SMART TRAILER 300',
#    'SMART TRAILER 750']},
#  'LAMBORGHINI': {'name': 'LAMBORGHINI',
#   'models': ['AVENTADOR', 'GALLARDO', 'HURACAN', 'MURCIELAGO', 'URUS']},
#  'LANCIA': {'name': 'LANCIA', 'models': ['OTHER']},
#  'LAND ROVER': {'name': 'LAND ROVER',
#   'models': ['DEFENDER',
#    'DISCOVERY',
#    'DISCOVERY SPORT',
#    'FREELANDER',
#    'LR2',
#    'LR3',
#    'RANGE ROVER',
#    'RANGE ROVER EVOQUE',
#    'RANGE ROVER SPORT',
#    'RANGE ROVER VELAR']},
#  'LANGENDORF': {'name': 'LANGENDORF', 'models': ['SAT', 'SKA', 'SKS']},
#  'LAV': {'name': 'LAV',
#   'models': ['81011',
#    '81011A',
#    '81011B',
#    '81011C',
#    '81012',
#    '81012A',
#    '81012B',
#    '81012C',
#    '81012D',
#    '81013',
#    '81013A',
#    '81013B',
#    '81013C',
#    '81013D',
#    '81013E',
#    '81014',
#    '81014A',
#    '81014B',
#    '81015',
#    '81015A',
#    '81015B',
#    '81016',
#    '81016A',
#    '81017',
#    '81018',
#    '81018A',
#    '81019',
#    '81019A',
#    '81020',
#    '81021',
#    '81022',
#    '81022A',
#    '81023',
#    '81025A']},
#  'LAZ': {'name': 'LAZ',
#   'models': ['4207',
#    '5207',
#    '5208',
#    '5252',
#    '695',
#    '697',
#    '699',
#    'A1414',
#    'A141JN']},
#  'LEGEND': {'name': 'LEGEND', 'models': ['XY400GY']},
#  'LEIKE': {'name': 'LEIKE', 'models': ['LK150T 7', 'LK180GY 2']},
#  'LESHOZMASH': {'name': 'LESHOZMASH', 'models': ['9039']},
#  'LEXUS': {'name': 'LEXUS',
#   'models': ['CT',
#    'ES',
#    'GS',
#    'GX',
#    'IS',
#    'LS',
#    'LX',
#    'NX',
#    'RC',
#    'RX',
#    'SC',
#    'UX']},
#  'LIAZ': {'name': 'LIAZ',
#   'models': ['4292',
#    '5250',
#    '5251',
#    '5256',
#    '5290',
#    '5291',
#    '5292',
#    '5293',
#    '6212',
#    '6213',
#    '6274',
#    '677']},
#  'LIAZ HCV': {'name': 'LIAZ HCV', 'models': ['100', '110', 'OTHER']},
#  'LIFAN': {'name': 'LIFAN',
#   'models': ['BREEZ',
#    'CEBRIUM',
#    'CELLIYA',
#    'LF 125',
#    'LF 150',
#    'LF 200',
#    'LF 400',
#    'MURMAN',
#    'MYWAY',
#    'SMILY',
#    'SOLANO',
#    'X50',
#    'X60',
#    'X70']},
#  'LINCOLN': {'name': 'LINCOLN',
#   'models': ['AVIATOR',
#    'CONTINENTAL',
#    'CONTINENTAL MARK SERIES',
#    'LS',
#    'MARK LT',
#    'MKS',
#    'MKT',
#    'MKX',
#    'NAVIGATOR',
#    'TOWN CAR',
#    'ZEPHYR']},
#  'LINGBEN': {'name': 'LINGBEN', 'models': ['LB125', 'LB150']},
#  'LIZZARD': {'name': 'LIZZARD', 'models': ['OTHER']},
#  'LOHR': {'name': 'LOHR', 'models': ['C2H99M', 'EUROLOHR 100', 'S2M52X']},
#  'LONCIN': {'name': 'LONCIN',
#   'models': ['LX150',
#    'LX250',
#    'SAGITTA ORSO',
#    'SAGITTA SBR 150',
#    'SAGITTA SNS 250 JEDI']},
#  'LOTOS': {'name': 'LOTOS', 'models': ['206']},
#  'LUXGEN': {'name': 'LUXGEN', 'models': ['5', '7 SUV']},
#  'MAN': {'name': 'MAN',
#   'models': ['A03',
#    'A13',
#    'A32',
#    'A51',
#    'BERKHOF EXCELLENCE 3000HD',
#    'BUSES',
#    'CAETANO',
#    'F SERIES',
#    'L SERIES',
#    'LIONS CITY',
#    'LIONS COACH',
#    'LIONS COACH L',
#    'LIONS INTERCITY',
#    'LIONS REGIO',
#    'LIONS REGIO C',
#    'LIONS STAR',
#    'M SERIES',
#    'MAN VOLKSWAGEN',
#    'SR 280',
#    'TGA',
#    'TGE',
#    'TGL',
#    'TGM',
#    'TGS',
#    'TGX']},
#  'MANAC AUTO': {'name': 'MANAC AUTO',
#   'models': ['946831', '946832', '946833']},
#  'MARCOPOLO': {'name': 'MARCOPOLO',
#   'models': ['ANDARE 1000', 'ANDARE 850', 'KAMAZ 3297', 'REAL']},
#  'MARS': {'name': 'MARS', 'models': ['DF150']},
#  'MARZ': {'name': 'MARZ',
#   'models': ['42191', '42191 01', '4251 01', '5266', '5277', '5277 01']},
#  'MASERATI': {'name': 'MASERATI',
#   'models': ['3200 GT',
#    'BITURBO',
#    'COUPE',
#    'GHIBLI',
#    'GRANCABRIO',
#    'GRANSPORT',
#    'GRANTURISMO',
#    'LEVANTE',
#    'QUATTROPORTE',
#    'SPYDER']},
#  'MAZ': {'name': 'MAZ',
#   'models': ['103',
#    '104',
#    '105',
#    '107',
#    '152',
#    '163',
#    '203',
#    '206',
#    '215',
#    '216',
#    '226',
#    '231',
#    '232',
#    '241',
#    '251',
#    '256',
#    '303',
#    '4370',
#    '4371',
#    '4380',
#    '4381',
#    '4570',
#    '4571',
#    '4581',
#    '500',
#    '504',
#    '509',
#    '5207',
#    '5224',
#    '5302',
#    '5334',
#    '5335',
#    '5336',
#    '5337',
#    '5340',
#    '5429',
#    '5430',
#    '5432',
#    '5433',
#    '5434',
#    '5440',
#    '5516',
#    '5549',
#    '5550',
#    '5551',
#    '6302',
#    '6303',
#    '6310',
#    '6312',
#    '6317',
#    '6417',
#    '6422',
#    '6425',
#    '6430',
#    '6432',
#    '64A028',
#    '6501',
#    '6514',
#    '6516',
#    '6517',
#    '8111',
#    '8114',
#    '8132',
#    '8162',
#    '837300 3010',
#    '83781',
#    '837810 014',
#    '837810 042',
#    '837810 20',
#    '856100',
#    '856102',
#    '856102 010',
#    '856103',
#    '857100 010',
#    '870100',
#    '870100 1010',
#    '870100 1012',
#    '870100 2010',
#    '870100 2012',
#    '870100 3010',
#    '870100 3012',
#    '870110 3010',
#    '870110 3012',
#    '892500 1015',
#    '892600 017',
#    '892620 010',
#    '931010 3010/3011',
#    '931010 3020',
#    '9330',
#    '933060',
#    '938020',
#    '938020 016',
#    '938660',
#    '938660 026',
#    '938660 044',
#    '938662',
#    '938920 011',
#    '9397',
#    '9398',
#    '950600 020',
#    '953000 031',
#    '953000 6010 000P1',
#    '953001 010',
#    '9758',
#    '975800 2012',
#    '975830',
#    '975830 2010P',
#    '975830 3025',
#    '991900 010',
#    '998500',
#    '998640 010',
#    '998640 015',
#    'MAN',
#    'MZKT',
#    'OTHER',
#    'PKM 20.69',
#    'TRAILERS']},
#  'MAZDA': {'name': 'MAZDA',
#   'models': ['121',
#    '2',
#    '3',
#    '323',
#    '5',
#    '6',
#    '626',
#    '929',
#    'ATENZA',
#    'AXELA',
#    'B SERIES',
#    'BONGO',
#    'BT 50',
#    'CAPELLA',
#    'CX 3',
#    'CX 30',
#    'CX 5',
#    'CX 7',
#    'CX 9',
#    'DEMIO',
#    'E SERIES',
#    'ECONOVAN',
#    'FAMILIA',
#    'LANTIS',
#    'LUCE',
#    'MIATA',
#    'MILLENIA',
#    'MPV',
#    'MX 3',
#    'MX 5',
#    'MX 6',
#    'NAVAJO',
#    'PREMACY',
#    'PROTEGE',
#    'REVUE',
#    'RX 7',
#    'RX 8',
#    'TRIBUTE',
#    'XEDOS',
#    'XEDOS 6',
#    'XEDOS 9']},
#  'MEGA': {'name': 'MEGA',
#   'models': ['MNW2', 'MNW3', 'MNW4', 'MNW5', 'MPT003', 'MPT013']},
#  'MEILLER': {'name': 'MEILLER', 'models': ['KIPPER MHKS', 'KIPPER MHPS']},
#  'MENCI': {'name': 'MENCI', 'models': ['SA105', 'SA955']},
#  'MERCEDES-BENZ': {'name': 'MERCEDES-BENZ',
#   'models': ['A CLASS',
#    'ACTROS',
#    'AMG GT',
#    'AROCS',
#    'ATEGO',
#    'AXOR',
#    'B CLASS',
#    'BUSES',
#    'C CLASS',
#    'CITAN',
#    'CL CLASS',
#    'CLA CLASS',
#    'CLK CLASS',
#    'CLS CLASS',
#    'CONECTO',
#    'E CLASS',
#    'E CLASS COUPE',
#    'ECONIC',
#    'EQC',
#    'G CLASS',
#    'GL CLASS',
#    'GLA CLASS',
#    'GLB CLASS',
#    'GLC CLASS',
#    'GLC CLASS COUPE',
#    'GLE CLASS',
#    'GLE CLASS COUPE',
#    'GLK CLASS',
#    'GLS CLASS',
#    'INTOURO',
#    'LK',
#    'M CLASS',
#    'MAYBACH',
#    'MAYBACH S CLASS',
#    'MB 100',
#    'MK',
#    'O302',
#    'O303',
#    'O305',
#    'O340',
#    'O403',
#    'O404',
#    'O580',
#    'OHL',
#    'OTHER',
#    'R CLASS',
#    'S CLASS',
#    'S CLASS COUPE',
#    'SK',
#    'SL CLASS',
#    'SLC CLASS',
#    'SLK CLASS',
#    'SLR CLASS',
#    'SLS CLASS',
#    'SPRINTER',
#    'SPRINTER CLASSIC',
#    'T1',
#    'T2',
#    'TOURISMO',
#    'TRAVEGO',
#    'UNIMOG',
#    'V CLASS',
#    'VANEO',
#    'VARIO',
#    'VIANO',
#    'VITO',
#    'X CLASS']},
#  'METKOMPLEKS': {'name': 'METKOMPLEKS', 'models': ['PRF114', 'PRM111']},
#  'MEUSBURGER NOVTRACK': {'name': 'MEUSBURGER NOVTRACK',
#   'models': ['AH 342',
#    'AH 448',
#    'AK 27',
#    'AW 27',
#    'AW 48H',
#    'MSH 368',
#    'OTHER',
#    'SG 345ST',
#    'SG 360ST',
#    'SG 368ST',
#    'SH 345',
#    'SH 368',
#    'SH 454',
#    'SH 468',
#    'SK 24',
#    'SK 345',
#    'SK 352',
#    'SK 360',
#    'SK 368',
#    'SP 345PR',
#    'SP 360PR',
#    'SP 368AZ',
#    'SP 454',
#    'SW 240H',
#    'SW 24H',
#    'SW 345',
#    'SW 345G',
#    'SW 360',
#    'SW 360G',
#    'SW 454',
#    'ZH 224DS']},
#  'MG': {'name': 'MG', 'models': ['3', '350', '5', '6']},
#  'MINI': {'name': 'MINI',
#   'models': ['CABRIO',
#    'CABRIO JCW',
#    'CLUBMAN',
#    'CLUBMAN JCW',
#    'COUNTRYMAN',
#    'COUNTRYMAN JCW',
#    'COUPE',
#    'COUPE JCW',
#    'MINI',
#    'MINI JCW',
#    'PACEMAN',
#    'PACEMAN JCW',
#    'ROADSTER',
#    'ROADSTER JCW']},
#  'MINSK': {'name': 'MINSK',
#   'models': ['125 MOTARD', '3,112', '3,113', '3,115', 'C4 200', 'M4 200']},
#  'MITSUBISHI': {'name': 'MITSUBISHI',
#   'models': ['3000 GT',
#    'AIRTREK',
#    'ASPIRE',
#    'ASX',
#    'CARISMA',
#    'CHARIOT',
#    'COLT',
#    'DELICA',
#    'DELICA SPACE GEAR',
#    'DIAMANTE',
#    'DION',
#    'ECLIPSE',
#    'ECLIPSE CROSS',
#    'EK',
#    'ENDEAVOR',
#    'EXPO',
#    'GALANT',
#    'GRANDIS',
#    'GTO',
#    'I',
#    'I MIEV',
#    'L200',
#    'L300',
#    'L400',
#    'LANCER',
#    'LANCER EVOLUTION',
#    'LEGNUM',
#    'MIGHTY MAX',
#    'MIRAGE',
#    'MIRAGE DINGO',
#    'MONTERO',
#    'MONTERO IO',
#    'MONTERO SPORT',
#    'NATIVA',
#    'OUTLANDER',
#    'PAJERO',
#    'PAJERO IO',
#    'PAJERO JR',
#    'PAJERO PININ',
#    'PAJERO SPORT',
#    'RVR',
#    'SAPPORO',
#    'SHOGUN',
#    'SIGMA',
#    'SPACE RUNNER',
#    'SPACE STAR',
#    'SPACE WAGON',
#    'STARION']},
#  'MITSUBISHI FUSO': {'name': 'MITSUBISHI FUSO',
#   'models': ['CANTER', 'CANTER MINI', 'FIGHTER', 'ROSA']},
#  'MMZ': {'name': 'MMZ', 'models': ['81021', '81024', '8113', '8176', 'OTHER']},
#  'MOSKVICH': {'name': 'MOSKVICH', 'models': ['OTHER']},
#  'MOTOLAND': {'name': 'MOTOLAND', 'models': ['XV250']},
#  'MRMZ': {'name': 'MRMZ', 'models': ['K 1', 'K 2', 'K 4', 'PS6']},
#  'MTM': {'name': 'MTM', 'models': ['9330', '939740', 'OTHER']},
#  'MUDAN': {'name': 'MUDAN',
#   'models': ['MD6106', 'MD6122', 'MD6740', 'MD6750']},
#  'MZKT': {'name': 'MZKT', 'models': ['OTHER']},
#  'MZSA': {'name': 'MZSA',
#   'models': ['804321',
# ...
#    '7132 14',
#    '7132 16',
#    '7132 2K',
#    '7132 30',
#    '7132 6K',
#    '7132 8K',
#    '7132 9K']},
#  'ST-AVTO': {'name': 'ST-AVTO', 'models': ['984344', '994344']},
#  'STAVPRICEP': {'name': 'STAVPRICEP', 'models': ['849901']},
#  'STEELBEAR': {'name': 'STEELBEAR',
#   'models': ['PB 24A',
#    'PC 24T',
#    'PF 41B',
#    'PF 41L',
#    'PF 41N',
#    'PK 18P',
#    'PK 24N',
#    'PK 24P',
#    'PR 27L',
#    'PT 18B',
#    'PT 24B',
#    'PT 24K',
#    'PT 24L',
#    'PU 24T',
#    'PZ 18K',
#    'TP 12F',
#    'TP 12P',
#    'TR 21',
#    'TR 31',
#    'TR 41',
#    'TR 51']},
#  'STELS': {'name': 'STELS',
#   'models': ['BENELLI',
#    'DELTA',
#    'DESNA',
#    'ENDURO',
#    'FLAME',
#    'FLEX',
#    'OUTLANDER',
#    'SB200',
#    'VORTEX',
#    'XY400',
#    'ZION']},
#  'STROIMASHSERVIS': {'name': 'STROIMASHSERVIS', 'models': ['899030', 'OTHER']},
#  'STROITECHNIKA (KANASH)': {'name': 'STROITECHNIKA (KANASH)',
#   'models': ['855800',
#    '88182',
#    '9344',
#    '934410',
#    '934420',
#    '934600',
#    '934620',
#    '934630',
#    '974400',
#    '993200',
#    '993270',
#    '993300',
#    '993630',
#    'PTN 4007']},
#  'STS': {'name': 'STS',
#   'models': ['8489 10',
#    '9447 10',
#    '94471 10 01',
#    '94471 10 02',
#    '94472 10',
#    '94473 10',
#    '94473 10 01',
#    '94475 10',
#    '9447A 10']},
#  'SUBARU': {'name': 'SUBARU',
#   'models': ['BRZ',
#    'FORESTER',
#    'IMPREZA',
#    'IMPREZA WRX/STI',
#    'IMPREZA XV',
#    'LEGACY',
#    'OUTBACK',
#    'TRIBECA',
#    'XV']},
#  'SUNLONG': {'name': 'SUNLONG',
#   'models': ['SLK6122', 'SLK6126', 'SLK6790F1G', 'SLK6798', 'SLK6931']},
#  'SUZUKI': {'name': 'SUZUKI',
#   'models': ['AERIO',
#    'ALTO',
#    'AN',
#    'BALENO',
#    'BOULEVARD',
#    'BURGMAN',
#    'CULTUS',
#    'DL V STROM',
#    'DR',
#    'DR Z',
#    'EN',
#    'ESCUDO',
#    'GN',
#    'GRAND VITARA',
#    'GS',
#    'GSF',
#    'GSR',
#    'GSX',
#    'GV',
#    'GW',
#    'GZ',
#    'HAYABUSA',
#    'IGNIS',
#    'INTRUDER',
#    'JIMNY',
#    'KIZASHI',
#    'LIANA',
#    'OTHER',
#    'RF',
#    'RM',
#    'RV',
#    'SFV 650',
#    'SPLASH',
#    'SV',
#    'SWIFT',
#    'SX4',
#    'TL 1000',
#    'TR 50 SD',
#    'TU 250',
#    'VITARA',
#    'VITARA/GRAND VITARA',
#    'VL',
#    'VS',
#    'VX 800',
#    'VZ',
#    'VZR',
#    'WAGON R',
#    'XF 650',
#    'XL 7']},
#  'SW': {'name': 'SW', 'models': ['OTHER']},
#  'SYM': {'name': 'SYM',
#   'models': ['CITYCOM',
#    'G 100P',
#    'GTS 250',
#    'GTS 300',
#    'GTS 330',
#    'JOYRIDE',
#    'MAXSYM',
#    'ORBIT',
#    'VS 150',
#    'WOLF']},
#  'SZAP': {'name': 'SZAP',
#   'models': ['8195',
#    '8305',
#    '83053',
#    '83062',
#    '830622',
#    '8350',
#    '8352',
#    '8355',
#    '83561',
#    '8357',
#    '8357 02',
#    '8527',
#    '8538 01',
#    '8543',
#    '8543 01',
#    '85431 01',
#    '8551',
#    '85514',
#    '8582',
#    '9327',
#    '93271',
#    '93271 01',
#    '93272',
#    '93272A',
#    '9328',
#    '93282',
#    '9340',
#    '9515',
#    '95151',
#    '9517',
#    '95171',
#    '9905',
#    '99051',
#    '9908',
#    '99081',
#    '9915',
#    'A349',
#    'OTHER']},
#  'TACHILLA': {'name': 'TACHILLA', 'models': ['BETA', 'EAGLE', 'SPACE']},
#  'TAGANAI-AVTO': {'name': 'TAGANAI-AVTO', 'models': ['OTHER']},
#  'TAGAZ': {'name': 'TAGAZ',
#   'models': ['AQUILA',
#    'C10',
#    'C190',
#    'C30',
#    'HARDY',
#    'MASTER',
#    'ROAD PARTNER',
#    'TAGER',
#    'VEGA']},
#  'TAM': {'name': 'TAM', 'models': ['190', '222', '260', '80']},
#  'TATA': {'name': 'TATA', 'models': ['407', 'LPT 613']},
#  'TATRA': {'name': 'TATRA', 'models': ['T158', 'T163', 'T613', 'T815']},
#  'TAVMZ': {'name': 'TAVMZ',
#   'models': ['802',
#    '8803 10',
#    '8966 10',
#    '8966 12',
#    '89661',
#    '89662',
#    '9005 10',
#    '930702 10',
#    '93622 10',
#    '93623 10',
#    '93624 10',
#    '9383 10',
#    '9383 11',
#    '9383 12',
#    '9851 12 01']},
#  'TD KURGANSKIE PRICEPI': {'name': 'TD KURGANSKIE PRICEPI',
#   'models': ['821300',
#    '82130000000',
#    '821301',
#    '821303',
#    '821305',
#    '821307',
#    '82132E',
#    '8213A5',
#    '8213A7',
#    '8213B5',
#    '8213B7',
#    'KP2213',
#    'KP2221',
#    'KP2231',
#    'KP2232',
#    'KP2233']},
#  'TEMSA': {'name': 'TEMSA', 'models': ['OPALIN', 'PRESTIJ', 'SAFARI']},
#  'TEREX-DEMAG': {'name': 'TEREX-DEMAG',
#   'models': ['AC 100',
#    'AC 100 4L',
#    'AC 120 1',
#    'AC 140',
#    'AC 155',
#    'AC 160 2',
#    'AC 200 1',
#    'AC 265',
#    'AC 40 CITY',
#    'AC 50 1',
#    'AC 80 2']},
#  'TESLA': {'name': 'TESLA',
#   'models': ['MODEL 3', 'MODEL S', 'MODEL X', 'MODEL Y']},
#  'TITAN': {'name': 'TITAN', 'models': ['7171 10']},
#  'TOLJATTINSKIE PRICEPI': {'name': 'TOLJATTINSKIE PRICEPI',
#   'models': ['710861', '710862', '710864']},
#  'TOM': {'name': 'TOM', 'models': ['OTHER']},
#  'TONAR': {'name': 'TONAR',
#   'models': ['6428',
#    '6552',
#    '8168',
#    '8188',
#    '8310',
#    '83101',
#    '83102',
#    '8579',
#    '85791',
#    '85792',
#    '85793',
#    '85795',
#    '857971',
#    '86101',
#    '86101M',
#    '86102',
#    '86103',
#    '86104',
#    '8707',
#    '8742',
#    '87421',
#    '8745',
#    '8953',
#    '9385',
#    '9386',
#    '9388',
#    '9442',
#    '94424',
#    '9443',
#    '9445',
#    '9523',
#    '952301',
#    '952302',
#    '95231',
#    '95232',
#    '95233',
#    '95234',
#    '952341',
#    '952342',
#    '952344',
#    '95235',
#    '95236',
#    '95239',
#    '9540',
#    '95403',
#    '9585',
#    '9586',
#    '9589',
#    '95892',
#    '95893',
#    '95894',
#    '9594',
#    '9595',
#    '9598',
#    '9746',
#    '974601',
#    '974603',
#    '97461',
#    '974611',
#    '974612',
#    '974613',
#    '974614',
#    '97462',
#    '974623',
#    '974624',
#    '974625',
#    '974627',
#    '974628',
#    '974629',
#    '97463',
#    '97464',
#    '97854',
#    '9786',
#    '97861',
#    '97863',
#    '97882',
#    '97883',
#    '98261',
#    '98262',
#    '9827',
#    '9886',
#    '9888',
#    '98881',
#    '98882',
#    '9988',
#    '99882',
#    '99883',
#    '9989',
#    '99891']},
#  'TOR': {'name': 'TOR', 'models': ['84381 10 05', '8438M1']},
#  'TOYOTA': {'name': 'TOYOTA',
#   'models': ['4RUNNER',
#    'ALLION',
#    'ALPHARD',
#    'ALTEZZA',
#    'ARISTO',
#    'AURIS',
#    'AVALON',
#    'AVENSIS',
#    'AYGO',
#    'C HR',
#    'CALDINA',
#    'CAMI',
#    'CAMRY',
#    'CARINA',
#    'CAVALIER',
#    'CELICA',
#    'CELSIOR',
#    'CHASER',
#    'COASTER',
#    'COROLLA',
#    'COROLLA SPACIO',
#    'CORONA',
#    'CORSA',
#    'CRESSIDA',
#    'CROWN',
#    'DYNA',
#    'ECHO',
#    'FJ CRUISER',
#    'FORTUNER',
#    'FUNCARGO',
#    'GRANVIA',
#    'GT86',
#    'HARRIER',
#    'HIACE',
#    'HIGHLANDER',
#    'HILUX',
#    'IPSUM',
#    'IQ',
#    'IST',
#    'LAND CRUISER',
#    'LAND CRUISER 100',
#    'LAND CRUISER 105',
#    'LAND CRUISER 200',
#    'LAND CRUISER 40',
#    'LAND CRUISER 60',
#    'LAND CRUISER 70',
#    'LAND CRUISER 80',
#    'LAND CRUISER PRADO',
#    'LAND CRUISER PRADO 120',
#    'LAND CRUISER PRADO 150',
#    'LAND CRUISER PRADO 70',
#    'LAND CRUISER PRADO 90',
#    'LITEACE',
#    'MARK',
#    'MATRIX',
#    'MODEL F',
#    'MR',
#    'MR2',
#    'MRS',
#    'NADIA',
#    'OPA',
#    'OTHER',
#    'PASEO',
#    'PASSO',
#    'PICNIC',
#    'PLATZ',
#    'PREMIO',
#    'PREVIA',
#    'PRIUS',
#    'RAV4',
#    'RUSH',
#    'SEQUOIA',
#    'SIENNA',
#    'SIENTA',
#    'SOLUNA',
#    'SPRINTER',
#    'SPRINTER CARIB',
#    'STARLET',
#    'SUCCEED',
#    'SUPRA',
#    'TACOMA',
#    'TERCEL',
#    'TOWNACE',
#    'TOYOACE',
#    'TUNDRA',
#    'URBAN CRUISER',
#    'VENZA',
#    'VERSO',
#    'VIOS',
#    'VITZ',
#    'YARIS']},
#  'TRAILER': {'name': 'TRAILER',
#   'models': ['329440',
#    '82940T',
#    '82942K',
#    '82942T',
#    '829430',
#    '829431',
#    '829440',
#    '82944C',
#    '829450',
#    '829470',
#    '829800',
#    '82980C',
#    '829810']},
#  'TRAILER TECHNOLOGY': {'name': 'TRAILER TECHNOLOGY',
#   'models': ['TT102L', 'TT103L', 'TT107B', 'TT209B 05']},
#  'TRAILOR': {'name': 'TRAILOR', 'models': ['S383EL', 'SYY3CX']},
#  'TRANS-ABSOLUT': {'name': 'TRANS-ABSOLUT',
#   'models': ['843111', '843112', '843113']},
#  'TRANS-MOBIL': {'name': 'TRANS-MOBIL',
#   'models': ['905800', '905801', '905809', '905814']},
#  'TREK': {'name': 'TREK', 'models': ['8218 10', '82181 10']},
#  'TROLZA': {'name': 'TROLZA', 'models': ['9321 10 01', '9321.02 10']},
#  'TROTTER': {'name': 'TROTTER', 'models': ['9541 10', '9660 10']},
#  'TSM': {'name': 'TSM',
#   'models': ['83402T',
#    '83403T',
#    '993910',
#    '993920',
#    '993930',
#    '99393B',
#    '99393E',
#    '99393F',
#    '99393H',
#    '99393T',
#    '993940',
#    '99394E',
#    '99394F',
#    '993950',
#    '99395E',
#    '993960',
#    '99396E']},
#  'TSP': {'name': 'TSP',
#   'models': ['8428 20',
#    '8428 30',
#    '84283 20 01',
#    '84284 20',
#    '84286 10',
#    '9416 10',
#    '9416 11',
#    '9416 11 01',
#    '9416 12',
#    '9416 12 02',
#    '9416 20',
#    '9416 30',
#    '9416 40',
#    '9416 50',
#    '9416 51',
#    '9416 52',
#    '94161 10',
#    '94161 20',
#    '94161 40',
#    '94161 41',
#    '94161 50',
#    '94162 10',
#    '94162 12',
#    '94162 30',
#    '94162 40',
#    '94163 10',
#    '94163 20',
#    '94163 30',
#    '94163 31',
#    '94163 40',
#    '94163 50',
#    '94163 60',
#    '94164',
#    '94165 10',
#    '94165 13',
#    '94166 10',
#    '9417 10',
#    '9417 10 01',
#    '9417 11',
#    '9417 20',
#    '9417 21',
#    '9417 30',
#    '9417 34',
#    '9417 36',
#    '9417 40',
#    '9417 56',
#    '9417 60',
#    '9417 90',
#    '94171 10',
#    '94171 11',
#    '94171 14',
#    '94171 20',
#    '94171 21',
#    '94171 60',
#    '9418 10',
#    '9418 20',
#    '9418 22',
#    '94182 10',
#    '94182 20',
#    '94183 10',
#    '94183 11',
#    '94183 20',
#    '94183 30',
#    '94183 40',
#    '94183 50',
#    '94183 60',
#    '94183 72',
#    '94184 10',
#    '94184 17',
#    '94184 20',
#    '94184 30',
#    '94184 60',
#    '94185 60',
#    '94186 10',
#    '94186 60']},
#  'UAZ': {'name': 'UAZ',
#   'models': ['1288',
#    '2206',
#    '2360 CARGO',
#    '23632 PICKUP',
#    '3151',
#    '3152',
#    '3153',
#    '3159',
#    '3160',
#    '3162',
#    '3163 PATRIOT',
#    '3301',
#    '3303',
#    '3309',
#    '3741',
#    '3909',
#    '3960',
#    '3962',
#    '3969',
#    '452',
#    '469',
#    '4963',
#    'HUNTER',
#    'PROFI']},
#  'URAL': {'name': 'URAL',
#   'models': ['2',
#    '3255',
#    '3255 NEXT',
#    '32551',
#    '32551 NEXT',
#    '325512',
#    '32552',
#    '32552 NEXT',
#    '375',
#    '42112',
#    '4320',
#    '4320 NEXT',
#    '43202',
#    '43204',
#    '4322',
#    '4325',
#    '4344',
#    '4420',
#    '4420 NEXT',
#    '5323',
#    '5423',
#    '5522',
#    '5557',
#    '5557 NEXT',
#    '5831',
#    '6361',
#    '6368',
#    '63685',
#    '6370',
#    '6377',
#    '6470',
#    '6563',
#    '73945',
#    '7470',
#    '8,103',
#    'IMZ 8.1041',
#    'IVECO',
#    'OTHER',
#    'SOLO']},
#  'URALDORMASH': {'name': 'URALDORMASH',
#   'models': ['9013 10', '9922 10', '992202 10', '992204']},
#  'URALPROMTEHNIKA': {'name': 'URALPROMTEHNIKA',
#   'models': ['904701', '904702', '904703', '904711', '904712', '9047T']},
#  'URALSPETSTRANS': {'name': 'URALSPETSTRANS',
#   'models': ['946510',
#    '946511 000J311',
#    '946515 A1',
#    '946516 B1 03',
#    '946517 B1',
#    '946517 G1',
#    '94651G',
#    '94651J',
#    '94651K',
#    '94651K 000A3',
#    '94651K 000B3',
#    '94651K 000C3',
#    '94651K 000E3',
#    '94651K 000F3',
#    '94651K 000G3',
#    '94651K 000J3',
#    '94651K 000M3',
#    '94651K 000P3',
#    '94651L',
#    '94651X',
#    '94651Z',
#    '94652L',
#    '94653J',
#    '94654L',
#    '94656L',
#    'OTHER']},
#  'USP': {'name': 'USP', 'models': ['831311', 'PRL 902900']},
#  'VAN HOOL': {'name': 'VAN HOOL',
#   'models': ['3B0011',
#    '3B0040',
#    '3B0045',
#    '3B0049',
#    '3B0064',
#    '3B0070',
#    '3B1052',
#    '3B2001',
#    '3B2004',
#    '3B2007',
#    '3B2010',
#    'OTHER',
#    'S',
#    'S338/27',
#    'T815',
#    'VHL0 2012AA']},
#  'VARZ': {'name': 'VARZ', 'models': ['500', '500A', 'M2']},
#  'VENTO': {'name': 'VENTO',
#   'models': ['DF150',
#    'GLADIATOR',
#    'MOUNTRACK',
#    'PHANTERA',
#    'PHANTOM R4I',
#    'RANGER 2',
#    'VERSO',
#    'WORKMAN']},
#  'VESPA': {'name': 'VESPA', 'models': ['OTHER']},
#  'VIBERTI': {'name': 'VIBERTI', 'models': ['36S03AL']},
#  'VICTORY': {'name': 'VICTORY', 'models': ['HAMMER', 'VEGAS', 'VISION']},
#  'VIKING': {'name': 'VIKING',
#   'models': ['7161 00',
#    '7161 01',
#    '7161 02',
#    '7161 03',
#    '7161 04',
#    '7161 05',
#    '7161 10']},
#  'VIPER': {'name': 'VIPER', 'models': ['ZS 200']},
#  'VIS': {'name': 'VIS',
#   'models': ['1705', '2345', '2346', '2347', '2348', '2349', '2946']},
#  'VM': {'name': 'VM', 'models': ['912805', 'OTHER', 'YADISH VM 8357/912801']},
#  'VMZ': {'name': 'VMZ', 'models': ['8263', '8291', '9601']},
#  'VOLGABUS': {'name': 'VOLGABUS',
#   'models': ['3290',
#    '4298',
#    '5270',
#    '52701',
#    '52702',
#    '5270G',
#    '5285',
#    '6216',
#    '6270',
#    '6271']},
#  'VOLKSWAGEN': {'name': 'VOLKSWAGEN',
#   'models': ['AMAROK',
#    'ARTEON',
#    'BEETLE',
#    'BORA',
#    'CADDY VP',
#    'CADDY VU',
#    'CALIFORNIA',
#    'CARAVELLE',
#    'CORRADO',
#    'CRAFTER',
#    'DERBY',
#    'EOS',
#    'FOX',
#    'GOLF',
#    'JETTA',
#    'L80',
#    'LT',
#    'LUPO',
#    'MULTIVAN',
#    'NEW BEETLE',
#    'OTHER',
#    'PASSAT',
#    'PHAETON',
#    'POLO',
#    'RABBIT',
#    'SANTANA',
#    'SCIROCCO',
#    'SHARAN',
#    'SONATA',
#    'TARO',
#    'TERAMONT',
#    'TIGUAN',
#    'TOUAREG',
#    'TOURAN',
#    'TRANSPORTER',
#    'VENTO']},
#  'VOLOGODSKIIMZ': {'name': 'VOLOGODSKIIMZ',
#   'models': ['862011/G6 OPA 8.1/3', '963461/G6 OPA PS 24P']},
#  'VOLVO': {'name': 'VOLVO',
#   'models': ['200 SERIES',
#    '300 SERIES',
#    '400 SERIES',
#    '700 SERIES',
#    '800 SERIES',
#    '900 SERIES',
#    'BUSES',
#    'C30',
#    'C70',
#    'F10',
#    'F12',
#    'F16',
#    'FE',
#    'FH',
#    'FL',
#    'FM',
#    'NL',
#    'S40',
#    'S60',
#    'S70',
#    'S80',
#    'S90',
#    'V40',
#    'V50',
#    'V60',
#    'V70',
#    'V90',
#    'VN',
#    'XC40',
#    'XC60',
#    'XC70',
#    'XC90']},
#  'VORTEX': {'name': 'VORTEX', 'models': ['CORDA', 'ESTINA', 'TINGO']},
#  'WANGYE': {'name': 'WANGYE', 'models': ['MATADOR JET']},
#  'WIELTON': {'name': 'WIELTON',
#   'models': ['NJ4',
#    'NS3',
#    'NS34',
#    'NS34KT',
#    'NS34PT',
#    'NS34SB',
#    'NS34ST',
#    'NS34STM',
#    'NW',
#    'NW24SB',
#    'NW3',
#    'NW33ST',
#    'NW38AT',
#    'NW38SB',
#    'PC',
#    'PC16',
#    'PS16SB',
#    'PS3W']},
#  'WONJAN': {'name': 'WONJAN', 'models': ['ALPHA S']},
#  'WORLD MOTORS': {'name': 'WORLD MOTORS', 'models': ['ERMAK', 'OPTIMUS']},
#  'XCMG': {'name': 'XCMG', 'models': ['QY25K5S', 'QY30K5 1', 'XCT25L5 S']},
#  'XINLING': {'name': 'XINLING',
#   'models': ['APACHE', 'COBRA CROSSFIRE', 'GX R250', 'MATRIX', 'XL150ZH']},
#  'XMOTO': {'name': 'XMOTO', 'models': ['ZW250']},
#  'YAMAHA': {'name': 'YAMAHA',
#   'models': ['FAZER',
#    'FJ 1100',
#    'FJ 1200',
#    'FJR 1300',
#    'FZ',
#    'FZR',
#    'FZS',
#    'FZX',
#    'GTS 1000',
#    'MAJESTY',
#    'MT 01',
#    'MT 07',
#    'MT 09',
#    'MT 10',
#    'RD',
#    'SR',
#    'SRX',
#    'T MAX',
#    'TDM',
#    'TDR',
#    'TRX 850',
#    'TT250R',
#    'TW',
#    'VMAX',
#    'WR',
#    'XJ',
#    'XJ 600',
#    'XJ 700 MAXIM',
#    'XJ 750',
#    'XJ 900',
#    'XJR',
#    'XS',
#    'XSR',
#    'XT',
#    'XT 1200Z SUPER TENERE',
#    'XT 225',
#    'XT 250',
#    'XT 600',
#    'XTZ 750 SUPER TENERE',
#    'XV',
#    'XV1900',
#    'XVS',
#    'XVZ',
#    'YBR 125',
#    'YZ',
#    'YZF']},
#  'YINGANG': {'name': 'YINGANG', 'models': ['OTHER']},
#  'YOUYI': {'name': 'YOUYI', 'models': ['ZGT6710']},
#  'YUEJIN/NAVECO': {'name': 'YUEJIN/NAVECO',
#   'models': ['NJ1020', 'NJ1041', 'NJ1062', 'NJ1080', 'OTHER']},
#  'YUTONG': {'name': 'YUTONG',
#   'models': ['ZK6118HGA',
#    'ZK6119HA',
#    'ZK6121HQ',
#    'ZK6122H9',
#    'ZK6129H',
#    'ZK6737D',
#    'ZK6831H',
#    'ZK6852HG',
#    'ZK6899HA',
#    'ZK6938HB9']},
#  'ZASLAW': {'name': 'ZASLAW', 'models': ['D 651']},
#  'ZAZ': {'name': 'ZAZ',
#   'models': ['1102',
#    '1103',
#    '1105',
#    '1140',
#    '8101',
#    '968',
#    'CHANCE',
#    'LANOS',
#    'SENS',
#    'VIDA']},
#  'ZF-KY': {'name': 'ZF-KY', 'models': ['ZF150', 'ZF200', 'ZF250']},
#  'ZHWEKI': {'name': 'ZHWEKI', 'models': ['ZW110', 'ZW125', 'ZW150']},
#  'ZID': {'name': 'ZID', 'models': ['FERMER', 'SOVA', 'VOSHOD']},
#  'ZIL': {'name': 'ZIL',
#   'models': ['130',
#    '131',
#    '133',
#    '138',
#    '157',
#    '2502',
#    '3250',
#    '4314',
#    '4315',
#    '4316',
#    '4327',
#    '4329',
#    '4330',
#    '4331',
#    '4333',
#    '4334',
#    '4335',
#    '4341',
#    '4415',
#    '4421',
#    '4423',
#    '4502',
#    '4505',
#    '4506',
#    '4508',
#    '4514',
#    '4516',
#    '4520',
#    '4526',
#    '4545',
#    '4546',
#    '4741',
#    '4744',
#    '4763',
#    '4945',
#    '4952',
#    '4957',
#    '4974',
#    '5301',
#    '5302',
#    '5343',
#    '5417',
#    '554',
#    '555',
#    '5715',
#    'OTHER']},
#  'ZNEN': {'name': 'ZNEN',
#   'models': ['CLASSIC', 'FALCON', 'ROAR', 'ZN125', 'ZN150']},
#  'ZOTYE': {'name': 'ZOTYE', 'models': ['COUPA', 'T600']},
#  'ZTO SSM': {'name': 'ZTO SSM', 'models': ['845821']},
#  'ZVER': {'name': 'ZVER', 'models': ['DF150']},
#  'ZX': {'name': 'ZX', 'models': ['GRANDTIGER', 'LANDMARK']}}

# %%
dict = {
    'ABM': 'АБМ',
 'ACERBI': 'Акерби',
 'ACKERMANN': 'Аккерман',
 'ACURA': 'Акура',
 'ALASKA': 'Аляска',
 'ALFA': 'Альфа',
 'ALFA ROMEO': 'Альфа Ромео',
 'ALLOY': 'Аллой',
 'ALTAVIR': 'Альтавир',
 'AMS': 'АМС',
 'AMUR': 'АМУР',
 'ASIA': 'АЗИЯ',
 'ASP': 'АСП',
 'ASTAIS': 'АСТЕЙС',
 'ASTON MARTIN': 'АСТОН МАРТИН',
 'ATLANT': 'АТЛАНТ',
 'ATLETIC': 'АТЛЕТИК',
 'AUDI': 'АУДИ',
 'AVENTO': 'АВЕНТО',
 'AVIA': 'АВИА',
 'AVTOS': 'АВТОС',
 'AZHM': 'АЗХМ',
 'BAGEM': 'БАГЕМ',
 'BATYR': 'БАТЫР',
 'BAW': 'БАУ',
 'BAZ': 'БАЗ',
 'BECEMA': 'БАГЕМА',
 'BELAZ': 'БЕЛАЗ',
 'BENALU': 'БЕНАЛУ',
 'BENELLI': 'БЕНЕЛИ',
 'BENTLEY': 'БЕНТЛИ',
 'BEST': 'БЕСТ',
 'BMW': 'БМВ',
 'BODEX': 'БОДЕКС',
 'BOGDAN': 'БОГДАН',
 'BONUM': 'БОНУМ',
 'BOVA': 'БОВА',
 'BRILLIANCE': 'БРИЛИАНС',
 'BRP': 'БРП',
 'BUICK': 'БУИК',
 'BYD': 'БУД',
 'CADILLAC': 'КОДИЛАК',
 'CARSAN': 'КАРСАН',
 'CHANGAN': 'ЧАНГАН',
 'CHDM': 'ЧДМ',
 'CHEETA': 'ЧИТА',
 'CHERY': 'ЧЕРИ',
 'CHEVROLET': 'ШЕВРОЛЕТ',
 'CHITUMA': 'ЧИТУМА',
 'CHMZAP': 'ЧМЗАП',
 'CHRYSLER': 'КРАЙСЛЕР',
 'CITROEN': 'СИТРОЕН',
 'DACIA': 'ДАКИА',
 'DAEWOO': 'ДЕУ',
 'DAF': 'ДАФ',
 'DAIHATSU': 'ДАХАТСУ',
 'DATSUN': 'ДАТСУН',
 'DERBI': 'ДЕРБИ',
 'DERWAYS': 'ДЕРВЕЙС',
 'DIZEL-S': 'ДИЗЕЛЬ',
 'DNESTR': 'ДНЕСТР',
 'DODGE': 'ДОДЖ',
 'DONG FENG': 'ДОНГ ФЕНГ',
 'DUCATI': 'ДУКАТИ',
 'ELAZ': 'ЕЛАЗ',
 'ELIS': 'ЭЛИС',
 'EPK': 'ЕПК',
 'EUROTEX': 'ЕВРОТЕХ',
 'EXPEDICIYA': 'ЭКСПЕДИЦИЯ',
 'FEKON': 'ФЕКОН',
 'FERRARI': 'ФЕРРАРИ',
 'FIAT': 'ФИАТ',
 'FORD': 'ФОРД',
 'FORSAGE': 'ФОРСАЖ',
 'FORTUNE': 'ФОРТУН',
 'FOTON': 'ФОТОН',
 'FOXTANK': 'ФОКСТАНК',
 'GAZ': 'ГАЗ',
 'GEELY': 'ДЖИЛИ',
 'GENESIS': 'ГЕНЕЗИС',
 'GILERA': 'ГИЛЕРА',
 'GOLAZ': 'ГОЛАЗ',
 'HAFEI': 'ХАФЕЙ',
 'HAIMA': 'ХАИМА',
 'HARLEY-DAVIDSON': 'ХАРЛЕЙ ДЕВИДСОН',
 'HIGER': 'ХАЙГЕР',
 'HINO': 'ХИНО',
 'HONDA': 'ХОНДА',
 'HOWO': 'ХОВО',
 'HUMMER': 'ХАММЕР',
 'HYUNDAI': 'ХЕНДАЙ',
 'IKARUS': 'ИКАРУС',
 'INFINITI': 'ИНФИНИТИ',
 'IRBIS': 'ИРБИС',
 'ISUZU': 'ИСУЗУ',
 'IVECO': 'ИВЕКО',
 'IZH': 'ИЖ',
 'JAGUAR': 'ЯГУАР',
 'JEEP': 'ДЖИП',
 'KAMA': 'КАМА',
 'KAMAZ': 'КАМАЗ',
 'KANSAS': 'КАНСАЗ',
 'KAPRI': 'КАПРИ',
 'KAROSA': 'КАРОСА',
 'KARZ': 'КАРЦ',
 'KAWASAKI': 'КАВАСАКИ',
 'KIA': 'КИА',
 'KMZ': 'КМЗ',
 'KOEGEL': 'КОГЕЛЬ',
 'KRAKER': 'КРАКЕР',
 'KRAZ': 'КРАЗ',
 'LADA': 'ЛАДА',
 'LAMBORGHINI': 'ЛАМБОРДЖИНИ',
 'LANCIA': 'ЛАНСИЯ',
 'LAND ROVER': 'ЛЕНД РОВЕР',
 'LEXUS': 'ЛЕКСУС',
 'LIAZ': 'ЛИАЗ',
 'MAN': 'МАН',
 'MARCOPOLO': 'МАРКОПОЛО',
 'MARS': 'МАРС',
 'MASERATI': 'МАЗЕРАТИ',
 'MAZ': 'МАЗ',
 'MAZDA': 'МАЗДА',
 'MEGA': 'МЕГА',
 'MERCEDES-BENZ': 'МЕРСЕДЕС БЕНЦ',
 'MG': 'МГ',
 'MITSUBISHI': 'МИЦИБИСИ',
 'MOSKVICH': 'МОСКВИЧ',
 'NISSAN': 'НИССАН',
 'OKA': 'ОКА',
 'OPEL': 'ОПЕЛЬ',
 'PEUGEOT': 'ПЕЖО',
 'PIONEER': 'ПИОНЕР',
 'PONTIAC': 'ПОНТИАК',
 'PORSCHE': 'ПОРШ',
 'PROGRESS': 'ПРОГРЕСС',
 'PROTON': 'ПРОТОН',
 'RACER': 'РЕЙСЕР',
 'RAVON': 'РАВОН',
 'RENAULT': 'РЕНО',
 'SAAB': 'СААБ',
 'SAZ': 'САЗ',
 'SCANIA': 'СКАНИА',
 'SCHMITZ CARGOBULL': 'ШМИТЦ',
 'SHACMAN (SHAANXI)': 'ШАХМАН',
 'SHANYANG': 'САНЬОНГ',
 'SKAT': 'СКАТ',
 'SKIF': 'СКИФ',
 'SKODA': 'ШКОДА',
 'SMART': 'СМАРТ',
 'SPARK': 'СПАРК',
 'SSANGYONG': 'САНЬОНГ',
 'SUBARU': 'СУБАРУ',
 'SUZUKI': 'СЮЗЮКИ',
 'TAGAZ': 'ТАГАЗ',
 'TESLA': 'ТЕСЛА',
 'TOYOTA': 'ТОЙОТА',
 'UAZ': 'УАЗ',
 'URAL': 'УРАЛ',
 'VENTO': 'ВЕНТО',
 'VMZ': 'УМЗ',
 'VOLGABUS': 'ВОЛГАБАС',
 'VOLKSWAGEN': 'ФОЛЬЦВАГЕН',
 'VOLVO': 'ВОЛЬВО',
 'VORTEX': 'ВОРТЕКС',
 'YAMAHA': 'ЯМАХА',
'YINGANG':'ЯНГАНГ',
 'ZAZ': 'ЗАЗ',
    'BELARUS':'Беларус',
}

# %%
for item in dict.keys():
    print(f"{{\"label\": \"BRAND\", \"pattern\": [{{\"LOWER\": \"{item.lower()}\"}}], \"id\": \"{item}\"}}")
    print(f"{{\"label\": \"BRAND\", \"pattern\": [{{\"LOWER\": \"{dict[item].lower()}\"}}], \"id\": \"{item}\"}}")
# Out:
# {"label": "BRAND", "pattern": [{"LOWER": "abm"}], "id": "ABM"}
# {"label": "BRAND", "pattern": [{"LOWER": "абм"}], "id": "ABM"}
# {"label": "BRAND", "pattern": [{"LOWER": "acerbi"}], "id": "ACERBI"}
# {"label": "BRAND", "pattern": [{"LOWER": "акерби"}], "id": "ACERBI"}
# {"label": "BRAND", "pattern": [{"LOWER": "ackermann"}], "id": "ACKERMANN"}
# {"label": "BRAND", "pattern": [{"LOWER": "аккерман"}], "id": "ACKERMANN"}
# {"label": "BRAND", "pattern": [{"LOWER": "acura"}], "id": "ACURA"}
# {"label": "BRAND", "pattern": [{"LOWER": "акура"}], "id": "ACURA"}
# {"label": "BRAND", "pattern": [{"LOWER": "alaska"}], "id": "ALASKA"}
# {"label": "BRAND", "pattern": [{"LOWER": "аляска"}], "id": "ALASKA"}
# {"label": "BRAND", "pattern": [{"LOWER": "alfa"}], "id": "ALFA"}
# {"label": "BRAND", "pattern": [{"LOWER": "альфа"}], "id": "ALFA"}
# {"label": "BRAND", "pattern": [{"LOWER": "alfa romeo"}], "id": "ALFA ROMEO"}
# {"label": "BRAND", "pattern": [{"LOWER": "альфа ромео"}], "id": "ALFA ROMEO"}
# {"label": "BRAND", "pattern": [{"LOWER": "alloy"}], "id": "ALLOY"}
# {"label": "BRAND", "pattern": [{"LOWER": "аллой"}], "id": "ALLOY"}
# {"label": "BRAND", "pattern": [{"LOWER": "altavir"}], "id": "ALTAVIR"}
# {"label": "BRAND", "pattern": [{"LOWER": "альтавир"}], "id": "ALTAVIR"}
# {"label": "BRAND", "pattern": [{"LOWER": "ams"}], "id": "AMS"}
# {"label": "BRAND", "pattern": [{"LOWER": "амс"}], "id": "AMS"}
# {"label": "BRAND", "pattern": [{"LOWER": "amur"}], "id": "AMUR"}
# {"label": "BRAND", "pattern": [{"LOWER": "амур"}], "id": "AMUR"}
# {"label": "BRAND", "pattern": [{"LOWER": "asia"}], "id": "ASIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "азия"}], "id": "ASIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "asp"}], "id": "ASP"}
# {"label": "BRAND", "pattern": [{"LOWER": "асп"}], "id": "ASP"}
# {"label": "BRAND", "pattern": [{"LOWER": "astais"}], "id": "ASTAIS"}
# {"label": "BRAND", "pattern": [{"LOWER": "астейс"}], "id": "ASTAIS"}
# {"label": "BRAND", "pattern": [{"LOWER": "aston martin"}], "id": "ASTON MARTIN"}
# {"label": "BRAND", "pattern": [{"LOWER": "астон мартин"}], "id": "ASTON MARTIN"}
# {"label": "BRAND", "pattern": [{"LOWER": "atlant"}], "id": "ATLANT"}
# {"label": "BRAND", "pattern": [{"LOWER": "атлант"}], "id": "ATLANT"}
# {"label": "BRAND", "pattern": [{"LOWER": "atletic"}], "id": "ATLETIC"}
# {"label": "BRAND", "pattern": [{"LOWER": "атлетик"}], "id": "ATLETIC"}
# {"label": "BRAND", "pattern": [{"LOWER": "audi"}], "id": "AUDI"}
# {"label": "BRAND", "pattern": [{"LOWER": "ауди"}], "id": "AUDI"}
# {"label": "BRAND", "pattern": [{"LOWER": "avento"}], "id": "AVENTO"}
# {"label": "BRAND", "pattern": [{"LOWER": "авенто"}], "id": "AVENTO"}
# {"label": "BRAND", "pattern": [{"LOWER": "avia"}], "id": "AVIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "авиа"}], "id": "AVIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "avtos"}], "id": "AVTOS"}
# {"label": "BRAND", "pattern": [{"LOWER": "автос"}], "id": "AVTOS"}
# {"label": "BRAND", "pattern": [{"LOWER": "azhm"}], "id": "AZHM"}
# {"label": "BRAND", "pattern": [{"LOWER": "азхм"}], "id": "AZHM"}
# {"label": "BRAND", "pattern": [{"LOWER": "bagem"}], "id": "BAGEM"}
# {"label": "BRAND", "pattern": [{"LOWER": "багем"}], "id": "BAGEM"}
# {"label": "BRAND", "pattern": [{"LOWER": "batyr"}], "id": "BATYR"}
# {"label": "BRAND", "pattern": [{"LOWER": "батыр"}], "id": "BATYR"}
# {"label": "BRAND", "pattern": [{"LOWER": "baw"}], "id": "BAW"}
# {"label": "BRAND", "pattern": [{"LOWER": "бау"}], "id": "BAW"}
# {"label": "BRAND", "pattern": [{"LOWER": "baz"}], "id": "BAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "баз"}], "id": "BAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "becema"}], "id": "BECEMA"}
# {"label": "BRAND", "pattern": [{"LOWER": "багема"}], "id": "BECEMA"}
# {"label": "BRAND", "pattern": [{"LOWER": "belaz"}], "id": "BELAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "белаз"}], "id": "BELAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "benalu"}], "id": "BENALU"}
# {"label": "BRAND", "pattern": [{"LOWER": "беналу"}], "id": "BENALU"}
# {"label": "BRAND", "pattern": [{"LOWER": "benelli"}], "id": "BENELLI"}
# {"label": "BRAND", "pattern": [{"LOWER": "бенели"}], "id": "BENELLI"}
# {"label": "BRAND", "pattern": [{"LOWER": "bentley"}], "id": "BENTLEY"}
# {"label": "BRAND", "pattern": [{"LOWER": "бентли"}], "id": "BENTLEY"}
# {"label": "BRAND", "pattern": [{"LOWER": "best"}], "id": "BEST"}
# {"label": "BRAND", "pattern": [{"LOWER": "бест"}], "id": "BEST"}
# {"label": "BRAND", "pattern": [{"LOWER": "bmw"}], "id": "BMW"}
# {"label": "BRAND", "pattern": [{"LOWER": "бмв"}], "id": "BMW"}
# {"label": "BRAND", "pattern": [{"LOWER": "bodex"}], "id": "BODEX"}
# {"label": "BRAND", "pattern": [{"LOWER": "бодекс"}], "id": "BODEX"}
# {"label": "BRAND", "pattern": [{"LOWER": "bogdan"}], "id": "BOGDAN"}
# {"label": "BRAND", "pattern": [{"LOWER": "богдан"}], "id": "BOGDAN"}
# {"label": "BRAND", "pattern": [{"LOWER": "bonum"}], "id": "BONUM"}
# {"label": "BRAND", "pattern": [{"LOWER": "бонум"}], "id": "BONUM"}
# {"label": "BRAND", "pattern": [{"LOWER": "bova"}], "id": "BOVA"}
# {"label": "BRAND", "pattern": [{"LOWER": "бова"}], "id": "BOVA"}
# {"label": "BRAND", "pattern": [{"LOWER": "brilliance"}], "id": "BRILLIANCE"}
# {"label": "BRAND", "pattern": [{"LOWER": "брилианс"}], "id": "BRILLIANCE"}
# {"label": "BRAND", "pattern": [{"LOWER": "brp"}], "id": "BRP"}
# {"label": "BRAND", "pattern": [{"LOWER": "брп"}], "id": "BRP"}
# {"label": "BRAND", "pattern": [{"LOWER": "buick"}], "id": "BUICK"}
# {"label": "BRAND", "pattern": [{"LOWER": "буик"}], "id": "BUICK"}
# {"label": "BRAND", "pattern": [{"LOWER": "byd"}], "id": "BYD"}
# {"label": "BRAND", "pattern": [{"LOWER": "буд"}], "id": "BYD"}
# {"label": "BRAND", "pattern": [{"LOWER": "cadillac"}], "id": "CADILLAC"}
# {"label": "BRAND", "pattern": [{"LOWER": "кодилак"}], "id": "CADILLAC"}
# {"label": "BRAND", "pattern": [{"LOWER": "carsan"}], "id": "CARSAN"}
# {"label": "BRAND", "pattern": [{"LOWER": "карсан"}], "id": "CARSAN"}
# {"label": "BRAND", "pattern": [{"LOWER": "changan"}], "id": "CHANGAN"}
# {"label": "BRAND", "pattern": [{"LOWER": "чанган"}], "id": "CHANGAN"}
# {"label": "BRAND", "pattern": [{"LOWER": "chdm"}], "id": "CHDM"}
# {"label": "BRAND", "pattern": [{"LOWER": "чдм"}], "id": "CHDM"}
# {"label": "BRAND", "pattern": [{"LOWER": "cheeta"}], "id": "CHEETA"}
# {"label": "BRAND", "pattern": [{"LOWER": "чита"}], "id": "CHEETA"}
# {"label": "BRAND", "pattern": [{"LOWER": "chery"}], "id": "CHERY"}
# {"label": "BRAND", "pattern": [{"LOWER": "чери"}], "id": "CHERY"}
# {"label": "BRAND", "pattern": [{"LOWER": "chevrolet"}], "id": "CHEVROLET"}
# {"label": "BRAND", "pattern": [{"LOWER": "шевролет"}], "id": "CHEVROLET"}
# {"label": "BRAND", "pattern": [{"LOWER": "chituma"}], "id": "CHITUMA"}
# {"label": "BRAND", "pattern": [{"LOWER": "читума"}], "id": "CHITUMA"}
# {"label": "BRAND", "pattern": [{"LOWER": "chmzap"}], "id": "CHMZAP"}
# {"label": "BRAND", "pattern": [{"LOWER": "чмзап"}], "id": "CHMZAP"}
# {"label": "BRAND", "pattern": [{"LOWER": "chrysler"}], "id": "CHRYSLER"}
# {"label": "BRAND", "pattern": [{"LOWER": "крайслер"}], "id": "CHRYSLER"}
# {"label": "BRAND", "pattern": [{"LOWER": "citroen"}], "id": "CITROEN"}
# {"label": "BRAND", "pattern": [{"LOWER": "ситроен"}], "id": "CITROEN"}
# {"label": "BRAND", "pattern": [{"LOWER": "dacia"}], "id": "DACIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "дакиа"}], "id": "DACIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "daewoo"}], "id": "DAEWOO"}
# {"label": "BRAND", "pattern": [{"LOWER": "деу"}], "id": "DAEWOO"}
# {"label": "BRAND", "pattern": [{"LOWER": "daf"}], "id": "DAF"}
# {"label": "BRAND", "pattern": [{"LOWER": "даф"}], "id": "DAF"}
# {"label": "BRAND", "pattern": [{"LOWER": "daihatsu"}], "id": "DAIHATSU"}
# {"label": "BRAND", "pattern": [{"LOWER": "дахатсу"}], "id": "DAIHATSU"}
# {"label": "BRAND", "pattern": [{"LOWER": "datsun"}], "id": "DATSUN"}
# {"label": "BRAND", "pattern": [{"LOWER": "датсун"}], "id": "DATSUN"}
# {"label": "BRAND", "pattern": [{"LOWER": "derbi"}], "id": "DERBI"}
# {"label": "BRAND", "pattern": [{"LOWER": "дерби"}], "id": "DERBI"}
# {"label": "BRAND", "pattern": [{"LOWER": "derways"}], "id": "DERWAYS"}
# {"label": "BRAND", "pattern": [{"LOWER": "дервейс"}], "id": "DERWAYS"}
# {"label": "BRAND", "pattern": [{"LOWER": "dizel-s"}], "id": "DIZEL-S"}
# {"label": "BRAND", "pattern": [{"LOWER": "дизель"}], "id": "DIZEL-S"}
# {"label": "BRAND", "pattern": [{"LOWER": "dnestr"}], "id": "DNESTR"}
# {"label": "BRAND", "pattern": [{"LOWER": "днестр"}], "id": "DNESTR"}
# {"label": "BRAND", "pattern": [{"LOWER": "dodge"}], "id": "DODGE"}
# {"label": "BRAND", "pattern": [{"LOWER": "додж"}], "id": "DODGE"}
# {"label": "BRAND", "pattern": [{"LOWER": "dong feng"}], "id": "DONG FENG"}
# {"label": "BRAND", "pattern": [{"LOWER": "донг фенг"}], "id": "DONG FENG"}
# {"label": "BRAND", "pattern": [{"LOWER": "ducati"}], "id": "DUCATI"}
# {"label": "BRAND", "pattern": [{"LOWER": "дукати"}], "id": "DUCATI"}
# {"label": "BRAND", "pattern": [{"LOWER": "elaz"}], "id": "ELAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "елаз"}], "id": "ELAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "elis"}], "id": "ELIS"}
# {"label": "BRAND", "pattern": [{"LOWER": "элис"}], "id": "ELIS"}
# {"label": "BRAND", "pattern": [{"LOWER": "epk"}], "id": "EPK"}
# {"label": "BRAND", "pattern": [{"LOWER": "епк"}], "id": "EPK"}
# {"label": "BRAND", "pattern": [{"LOWER": "eurotex"}], "id": "EUROTEX"}
# {"label": "BRAND", "pattern": [{"LOWER": "евротех"}], "id": "EUROTEX"}
# {"label": "BRAND", "pattern": [{"LOWER": "expediciya"}], "id": "EXPEDICIYA"}
# {"label": "BRAND", "pattern": [{"LOWER": "экспедиция"}], "id": "EXPEDICIYA"}
# {"label": "BRAND", "pattern": [{"LOWER": "fekon"}], "id": "FEKON"}
# {"label": "BRAND", "pattern": [{"LOWER": "фекон"}], "id": "FEKON"}
# {"label": "BRAND", "pattern": [{"LOWER": "ferrari"}], "id": "FERRARI"}
# {"label": "BRAND", "pattern": [{"LOWER": "феррари"}], "id": "FERRARI"}
# {"label": "BRAND", "pattern": [{"LOWER": "fiat"}], "id": "FIAT"}
# {"label": "BRAND", "pattern": [{"LOWER": "фиат"}], "id": "FIAT"}
# {"label": "BRAND", "pattern": [{"LOWER": "ford"}], "id": "FORD"}
# {"label": "BRAND", "pattern": [{"LOWER": "форд"}], "id": "FORD"}
# {"label": "BRAND", "pattern": [{"LOWER": "forsage"}], "id": "FORSAGE"}
# {"label": "BRAND", "pattern": [{"LOWER": "форсаж"}], "id": "FORSAGE"}
# {"label": "BRAND", "pattern": [{"LOWER": "fortune"}], "id": "FORTUNE"}
# {"label": "BRAND", "pattern": [{"LOWER": "фортун"}], "id": "FORTUNE"}
# {"label": "BRAND", "pattern": [{"LOWER": "foton"}], "id": "FOTON"}
# {"label": "BRAND", "pattern": [{"LOWER": "фотон"}], "id": "FOTON"}
# {"label": "BRAND", "pattern": [{"LOWER": "foxtank"}], "id": "FOXTANK"}
# {"label": "BRAND", "pattern": [{"LOWER": "фокстанк"}], "id": "FOXTANK"}
# {"label": "BRAND", "pattern": [{"LOWER": "gaz"}], "id": "GAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "газ"}], "id": "GAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "geely"}], "id": "GEELY"}
# {"label": "BRAND", "pattern": [{"LOWER": "джили"}], "id": "GEELY"}
# {"label": "BRAND", "pattern": [{"LOWER": "genesis"}], "id": "GENESIS"}
# {"label": "BRAND", "pattern": [{"LOWER": "генезис"}], "id": "GENESIS"}
# {"label": "BRAND", "pattern": [{"LOWER": "gilera"}], "id": "GILERA"}
# {"label": "BRAND", "pattern": [{"LOWER": "гилера"}], "id": "GILERA"}
# {"label": "BRAND", "pattern": [{"LOWER": "golaz"}], "id": "GOLAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "голаз"}], "id": "GOLAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "hafei"}], "id": "HAFEI"}
# {"label": "BRAND", "pattern": [{"LOWER": "хафей"}], "id": "HAFEI"}
# {"label": "BRAND", "pattern": [{"LOWER": "haima"}], "id": "HAIMA"}
# {"label": "BRAND", "pattern": [{"LOWER": "хаима"}], "id": "HAIMA"}
# {"label": "BRAND", "pattern": [{"LOWER": "harley-davidson"}], "id": "HARLEY-DAVIDSON"}
# {"label": "BRAND", "pattern": [{"LOWER": "харлей девидсон"}], "id": "HARLEY-DAVIDSON"}
# {"label": "BRAND", "pattern": [{"LOWER": "higer"}], "id": "HIGER"}
# {"label": "BRAND", "pattern": [{"LOWER": "хайгер"}], "id": "HIGER"}
# {"label": "BRAND", "pattern": [{"LOWER": "hino"}], "id": "HINO"}
# {"label": "BRAND", "pattern": [{"LOWER": "хино"}], "id": "HINO"}
# {"label": "BRAND", "pattern": [{"LOWER": "honda"}], "id": "HONDA"}
# {"label": "BRAND", "pattern": [{"LOWER": "хонда"}], "id": "HONDA"}
# {"label": "BRAND", "pattern": [{"LOWER": "howo"}], "id": "HOWO"}
# {"label": "BRAND", "pattern": [{"LOWER": "хово"}], "id": "HOWO"}
# {"label": "BRAND", "pattern": [{"LOWER": "hummer"}], "id": "HUMMER"}
# {"label": "BRAND", "pattern": [{"LOWER": "хаммер"}], "id": "HUMMER"}
# {"label": "BRAND", "pattern": [{"LOWER": "hyundai"}], "id": "HYUNDAI"}
# {"label": "BRAND", "pattern": [{"LOWER": "хендай"}], "id": "HYUNDAI"}
# {"label": "BRAND", "pattern": [{"LOWER": "ikarus"}], "id": "IKARUS"}
# {"label": "BRAND", "pattern": [{"LOWER": "икарус"}], "id": "IKARUS"}
# {"label": "BRAND", "pattern": [{"LOWER": "infiniti"}], "id": "INFINITI"}
# {"label": "BRAND", "pattern": [{"LOWER": "инфинити"}], "id": "INFINITI"}
# {"label": "BRAND", "pattern": [{"LOWER": "irbis"}], "id": "IRBIS"}
# {"label": "BRAND", "pattern": [{"LOWER": "ирбис"}], "id": "IRBIS"}
# {"label": "BRAND", "pattern": [{"LOWER": "isuzu"}], "id": "ISUZU"}
# {"label": "BRAND", "pattern": [{"LOWER": "исузу"}], "id": "ISUZU"}
# {"label": "BRAND", "pattern": [{"LOWER": "iveco"}], "id": "IVECO"}
# {"label": "BRAND", "pattern": [{"LOWER": "ивеко"}], "id": "IVECO"}
# {"label": "BRAND", "pattern": [{"LOWER": "izh"}], "id": "IZH"}
# {"label": "BRAND", "pattern": [{"LOWER": "иж"}], "id": "IZH"}
# {"label": "BRAND", "pattern": [{"LOWER": "jaguar"}], "id": "JAGUAR"}
# {"label": "BRAND", "pattern": [{"LOWER": "ягуар"}], "id": "JAGUAR"}
# {"label": "BRAND", "pattern": [{"LOWER": "jeep"}], "id": "JEEP"}
# {"label": "BRAND", "pattern": [{"LOWER": "джип"}], "id": "JEEP"}
# {"label": "BRAND", "pattern": [{"LOWER": "kama"}], "id": "KAMA"}
# {"label": "BRAND", "pattern": [{"LOWER": "кама"}], "id": "KAMA"}
# {"label": "BRAND", "pattern": [{"LOWER": "kamaz"}], "id": "KAMAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "камаз"}], "id": "KAMAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "kansas"}], "id": "KANSAS"}
# {"label": "BRAND", "pattern": [{"LOWER": "кансаз"}], "id": "KANSAS"}
# {"label": "BRAND", "pattern": [{"LOWER": "kapri"}], "id": "KAPRI"}
# {"label": "BRAND", "pattern": [{"LOWER": "капри"}], "id": "KAPRI"}
# {"label": "BRAND", "pattern": [{"LOWER": "karosa"}], "id": "KAROSA"}
# {"label": "BRAND", "pattern": [{"LOWER": "кароса"}], "id": "KAROSA"}
# {"label": "BRAND", "pattern": [{"LOWER": "karz"}], "id": "KARZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "карц"}], "id": "KARZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "kawasaki"}], "id": "KAWASAKI"}
# {"label": "BRAND", "pattern": [{"LOWER": "кавасаки"}], "id": "KAWASAKI"}
# {"label": "BRAND", "pattern": [{"LOWER": "kia"}], "id": "KIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "киа"}], "id": "KIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "kmz"}], "id": "KMZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "кмз"}], "id": "KMZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "koegel"}], "id": "KOEGEL"}
# {"label": "BRAND", "pattern": [{"LOWER": "когель"}], "id": "KOEGEL"}
# {"label": "BRAND", "pattern": [{"LOWER": "kraker"}], "id": "KRAKER"}
# {"label": "BRAND", "pattern": [{"LOWER": "кракер"}], "id": "KRAKER"}
# {"label": "BRAND", "pattern": [{"LOWER": "kraz"}], "id": "KRAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "краз"}], "id": "KRAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "lada"}], "id": "LADA"}
# {"label": "BRAND", "pattern": [{"LOWER": "лада"}], "id": "LADA"}
# {"label": "BRAND", "pattern": [{"LOWER": "lamborghini"}], "id": "LAMBORGHINI"}
# {"label": "BRAND", "pattern": [{"LOWER": "ламборджини"}], "id": "LAMBORGHINI"}
# {"label": "BRAND", "pattern": [{"LOWER": "lancia"}], "id": "LANCIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "лансия"}], "id": "LANCIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "land rover"}], "id": "LAND ROVER"}
# {"label": "BRAND", "pattern": [{"LOWER": "ленд ровер"}], "id": "LAND ROVER"}
# {"label": "BRAND", "pattern": [{"LOWER": "lexus"}], "id": "LEXUS"}
# {"label": "BRAND", "pattern": [{"LOWER": "лексус"}], "id": "LEXUS"}
# {"label": "BRAND", "pattern": [{"LOWER": "liaz"}], "id": "LIAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "лиаз"}], "id": "LIAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "man"}], "id": "MAN"}
# {"label": "BRAND", "pattern": [{"LOWER": "ман"}], "id": "MAN"}
# {"label": "BRAND", "pattern": [{"LOWER": "marcopolo"}], "id": "MARCOPOLO"}
# {"label": "BRAND", "pattern": [{"LOWER": "маркополо"}], "id": "MARCOPOLO"}
# {"label": "BRAND", "pattern": [{"LOWER": "mars"}], "id": "MARS"}
# {"label": "BRAND", "pattern": [{"LOWER": "марс"}], "id": "MARS"}
# {"label": "BRAND", "pattern": [{"LOWER": "maserati"}], "id": "MASERATI"}
# {"label": "BRAND", "pattern": [{"LOWER": "мазерати"}], "id": "MASERATI"}
# {"label": "BRAND", "pattern": [{"LOWER": "maz"}], "id": "MAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "маз"}], "id": "MAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "mazda"}], "id": "MAZDA"}
# {"label": "BRAND", "pattern": [{"LOWER": "мазда"}], "id": "MAZDA"}
# {"label": "BRAND", "pattern": [{"LOWER": "mega"}], "id": "MEGA"}
# {"label": "BRAND", "pattern": [{"LOWER": "мега"}], "id": "MEGA"}
# {"label": "BRAND", "pattern": [{"LOWER": "mercedes-benz"}], "id": "MERCEDES-BENZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "мерседес бенц"}], "id": "MERCEDES-BENZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "mg"}], "id": "MG"}
# {"label": "BRAND", "pattern": [{"LOWER": "мг"}], "id": "MG"}
# {"label": "BRAND", "pattern": [{"LOWER": "mitsubishi"}], "id": "MITSUBISHI"}
# {"label": "BRAND", "pattern": [{"LOWER": "мицибиси"}], "id": "MITSUBISHI"}
# {"label": "BRAND", "pattern": [{"LOWER": "moskvich"}], "id": "MOSKVICH"}
# {"label": "BRAND", "pattern": [{"LOWER": "москвич"}], "id": "MOSKVICH"}
# {"label": "BRAND", "pattern": [{"LOWER": "nissan"}], "id": "NISSAN"}
# {"label": "BRAND", "pattern": [{"LOWER": "ниссан"}], "id": "NISSAN"}
# {"label": "BRAND", "pattern": [{"LOWER": "oka"}], "id": "OKA"}
# {"label": "BRAND", "pattern": [{"LOWER": "ока"}], "id": "OKA"}
# {"label": "BRAND", "pattern": [{"LOWER": "opel"}], "id": "OPEL"}
# {"label": "BRAND", "pattern": [{"LOWER": "опель"}], "id": "OPEL"}
# {"label": "BRAND", "pattern": [{"LOWER": "peugeot"}], "id": "PEUGEOT"}
# {"label": "BRAND", "pattern": [{"LOWER": "пежо"}], "id": "PEUGEOT"}
# {"label": "BRAND", "pattern": [{"LOWER": "pioneer"}], "id": "PIONEER"}
# {"label": "BRAND", "pattern": [{"LOWER": "пионер"}], "id": "PIONEER"}
# {"label": "BRAND", "pattern": [{"LOWER": "pontiac"}], "id": "PONTIAC"}
# {"label": "BRAND", "pattern": [{"LOWER": "понтиак"}], "id": "PONTIAC"}
# {"label": "BRAND", "pattern": [{"LOWER": "porsche"}], "id": "PORSCHE"}
# {"label": "BRAND", "pattern": [{"LOWER": "порш"}], "id": "PORSCHE"}
# {"label": "BRAND", "pattern": [{"LOWER": "progress"}], "id": "PROGRESS"}
# {"label": "BRAND", "pattern": [{"LOWER": "прогресс"}], "id": "PROGRESS"}
# {"label": "BRAND", "pattern": [{"LOWER": "proton"}], "id": "PROTON"}
# {"label": "BRAND", "pattern": [{"LOWER": "протон"}], "id": "PROTON"}
# {"label": "BRAND", "pattern": [{"LOWER": "racer"}], "id": "RACER"}
# {"label": "BRAND", "pattern": [{"LOWER": "рейсер"}], "id": "RACER"}
# {"label": "BRAND", "pattern": [{"LOWER": "ravon"}], "id": "RAVON"}
# {"label": "BRAND", "pattern": [{"LOWER": "равон"}], "id": "RAVON"}
# {"label": "BRAND", "pattern": [{"LOWER": "renault"}], "id": "RENAULT"}
# {"label": "BRAND", "pattern": [{"LOWER": "рено"}], "id": "RENAULT"}
# {"label": "BRAND", "pattern": [{"LOWER": "saab"}], "id": "SAAB"}
# {"label": "BRAND", "pattern": [{"LOWER": "сааб"}], "id": "SAAB"}
# {"label": "BRAND", "pattern": [{"LOWER": "saz"}], "id": "SAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "саз"}], "id": "SAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "scania"}], "id": "SCANIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "сканиа"}], "id": "SCANIA"}
# {"label": "BRAND", "pattern": [{"LOWER": "schmitz cargobull"}], "id": "SCHMITZ CARGOBULL"}
# {"label": "BRAND", "pattern": [{"LOWER": "шмитц"}], "id": "SCHMITZ CARGOBULL"}
# {"label": "BRAND", "pattern": [{"LOWER": "shacman (shaanxi)"}], "id": "SHACMAN (SHAANXI)"}
# {"label": "BRAND", "pattern": [{"LOWER": "шахман"}], "id": "SHACMAN (SHAANXI)"}
# {"label": "BRAND", "pattern": [{"LOWER": "shanyang"}], "id": "SHANYANG"}
# {"label": "BRAND", "pattern": [{"LOWER": "саньонг"}], "id": "SHANYANG"}
# {"label": "BRAND", "pattern": [{"LOWER": "skat"}], "id": "SKAT"}
# {"label": "BRAND", "pattern": [{"LOWER": "скат"}], "id": "SKAT"}
# {"label": "BRAND", "pattern": [{"LOWER": "skif"}], "id": "SKIF"}
# {"label": "BRAND", "pattern": [{"LOWER": "скиф"}], "id": "SKIF"}
# {"label": "BRAND", "pattern": [{"LOWER": "skoda"}], "id": "SKODA"}
# {"label": "BRAND", "pattern": [{"LOWER": "шкода"}], "id": "SKODA"}
# {"label": "BRAND", "pattern": [{"LOWER": "smart"}], "id": "SMART"}
# {"label": "BRAND", "pattern": [{"LOWER": "смарт"}], "id": "SMART"}
# {"label": "BRAND", "pattern": [{"LOWER": "spark"}], "id": "SPARK"}
# {"label": "BRAND", "pattern": [{"LOWER": "спарк"}], "id": "SPARK"}
# {"label": "BRAND", "pattern": [{"LOWER": "ssangyong"}], "id": "SSANGYONG"}
# {"label": "BRAND", "pattern": [{"LOWER": "саньонг"}], "id": "SSANGYONG"}
# {"label": "BRAND", "pattern": [{"LOWER": "subaru"}], "id": "SUBARU"}
# {"label": "BRAND", "pattern": [{"LOWER": "субару"}], "id": "SUBARU"}
# {"label": "BRAND", "pattern": [{"LOWER": "suzuki"}], "id": "SUZUKI"}
# {"label": "BRAND", "pattern": [{"LOWER": "сюзюки"}], "id": "SUZUKI"}
# {"label": "BRAND", "pattern": [{"LOWER": "tagaz"}], "id": "TAGAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "тагаз"}], "id": "TAGAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "tesla"}], "id": "TESLA"}
# {"label": "BRAND", "pattern": [{"LOWER": "тесла"}], "id": "TESLA"}
# {"label": "BRAND", "pattern": [{"LOWER": "toyota"}], "id": "TOYOTA"}
# {"label": "BRAND", "pattern": [{"LOWER": "тойота"}], "id": "TOYOTA"}
# {"label": "BRAND", "pattern": [{"LOWER": "uaz"}], "id": "UAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "уаз"}], "id": "UAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "ural"}], "id": "URAL"}
# {"label": "BRAND", "pattern": [{"LOWER": "урал"}], "id": "URAL"}
# {"label": "BRAND", "pattern": [{"LOWER": "vento"}], "id": "VENTO"}
# {"label": "BRAND", "pattern": [{"LOWER": "венто"}], "id": "VENTO"}
# {"label": "BRAND", "pattern": [{"LOWER": "vmz"}], "id": "VMZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "умз"}], "id": "VMZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "volgabus"}], "id": "VOLGABUS"}
# {"label": "BRAND", "pattern": [{"LOWER": "волгабас"}], "id": "VOLGABUS"}
# {"label": "BRAND", "pattern": [{"LOWER": "volkswagen"}], "id": "VOLKSWAGEN"}
# {"label": "BRAND", "pattern": [{"LOWER": "фольцваген"}], "id": "VOLKSWAGEN"}
# {"label": "BRAND", "pattern": [{"LOWER": "volvo"}], "id": "VOLVO"}
# {"label": "BRAND", "pattern": [{"LOWER": "вольво"}], "id": "VOLVO"}
# {"label": "BRAND", "pattern": [{"LOWER": "vortex"}], "id": "VORTEX"}
# {"label": "BRAND", "pattern": [{"LOWER": "вортекс"}], "id": "VORTEX"}
# {"label": "BRAND", "pattern": [{"LOWER": "yamaha"}], "id": "YAMAHA"}
# {"label": "BRAND", "pattern": [{"LOWER": "ямаха"}], "id": "YAMAHA"}
# {"label": "BRAND", "pattern": [{"LOWER": "yingang"}], "id": "YINGANG"}
# {"label": "BRAND", "pattern": [{"LOWER": "янганг"}], "id": "YINGANG"}
# {"label": "BRAND", "pattern": [{"LOWER": "zaz"}], "id": "ZAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "заз"}], "id": "ZAZ"}
# {"label": "BRAND", "pattern": [{"LOWER": "belarus"}], "id": "BELARUS"}
# {"label": "BRAND", "pattern": [{"LOWER": "беларус"}], "id": "BELARUS"}

# %%
df['Brand_RUS'] = df['Brand_AS'].apply(lambda x: dict.get(x))

# %%
def replace_rus_to_eng_char(sample_string):
    sample_string = sample_string.upper()
    char_to_replace = {'А': 'A',
                       'В': 'B',
                       'С': 'C',
                       'Е': 'E',
                       'Н': 'H',
                       'К': 'K',
                       'О': 'O',
                       'Р': 'P',
                       'Т': 'T',
                       'Х': 'X'}
    return sample_string.translate(str.maketrans(char_to_replace))

# %%
def leven(x): 
    words = x['text_brandmodel'].strip().split(' ')
    brand = x['Brand_AS']
    brand_ru = '' if x['Brand_RUS'] is None else x['Brand_RUS']
    for word in words:
        word = replace_rus_to_eng_char(word)
        brand = replace_rus_to_eng_char(brand)
        brand_ru = replace_rus_to_eng_char(brand_ru)
        
        jaro = Levenshtein.jaro_winkler(word, brand)
        levensh = Levenshtein.distance(word, brand)
        length = len(brand)
        if length > 3 and levensh < length and jaro > 0.5 and len(word) <= len(brand):
            return word
        
        jaro = Levenshtein.jaro_winkler(word, brand_ru)
        levensh = Levenshtein.distance(word, brand_ru)
        length = len(brand_ru)
        if length > 3 and levensh < length and jaro > 0.5 and len(word) <= len(brand_ru):
            return word
        
        return np.nan

# %%
df['l'] = df.apply(leven, axis=1)

# %%
sorted(list(set(df['l'].values)), key=lambda x: str(x).lower())
# Out:
# ['(AЦ',
#  '(HA',
#  '(БЦМ',
#  ',XУHДAЙ',
#  'A',
#  'A0',
#  'A1',
#  'A19',
#  'A20',
#  'A20М',
#  'A25',
#  'A3',
#  'A4',
#  'A41',
#  'A6',
#  'A6CR23',
#  'A7',
#  'A8',
#  'A8L',
#  'AA',
#  'AA-',
#  'AA-40',
#  'AA-8',
#  'AA8',
#  'AA8,5',
#  'AB',
#  'ABEO',
#  'ABT',
#  'ABTOБAУ',
#  'ABTOБУC',
#  'ABTOФУPГOH',
#  'ABД',
#  'ABИA',
#  'AC',
#  'AC-15',
#  'ACA',
#  'ACB',
#  'ACCERМAN',
#  'ACEPБИ',
#  'ACERBI',
#  'ACK',
#  'ACKEPМAH',
#  'ACKERМA',
#  'ACKERМAN',
#  'ACKERМANN',
#  'ACO',
#  'ACT',
#  'ACTOH',
#  'ACTУON',
#  'ACURA',
#  'ACЗC',
#  'ACИA',
#  'ACИЯ',
#  'ACМ',
#  'ACП',
#  'ACУPA',
#  'AD',
#  'ADA',
#  'AE385TI',
#  'AERO',
#  'AEWOO',
#  'AF',
#  'AF27',
#  'AF31',
#  'AF38',
#  'AFD',
#  'AHP',
#  'AHДAPE',
#  'AHДAPЭ',
#  'AHЦ',
#  'AIDI',
#  'AIDU',
#  'AKC',
#  'AKEPБИ',
#  'AKEPМAH',
#  'AKEPМAHH',
#  'AKH',
#  'AKKEPМAH',
#  'AKT',
#  'AKTИOH',
#  'AKU',
#  'AKU-TREILER',
#  'AKURA',
#  'AKЗC',
#  'AKП',
#  'AKУPA',
#  'AL',
#  'AL34',
#  'ALFA',
#  'ALFAROМEO',
#  'ALI',
#  'ALIRIZA',
#  'ALIRIZAUSTA',
#  'ALJ',
#  'ALLOУ',
#  'ALУ',
#  'AN',
#  'AND',
#  'ANDARE',
#  'AO',
#  'AP',
#  'APC',
#  'APМ-K',
#  'APМET',
#  'ARLEУ',
#  'AROCS',
#  'ARМET',
#  'ASCERМAN',
#  'ASIA',
#  'ASTON',
#  'ASTONМARTIN',
#  'AT',
#  'AT3',
#  'ATC',
#  'ATLAS',
#  'ATLAS-COPCO',
#  'ATSUN',
#  'ATЗ',
#  'ATЗ-',
#  'ATЛAC',
#  'ATЛACCOPCO',
#  'ATЛAHT',
#  'ATЛETИK',
#  'ATМЗ',
#  'ATПCO',
#  'AUDA',
#  'AUDI',
#  'AUDU',
#  'AVECO',
#  'AVEO',
#  'AVIA',
#  'AZIA',
#  'A|Б',
#  'A|М',
#  'AБ',
#  'AБ-',
#  'AБC',
#  'AБH',
#  'AБP',
#  'AБГ',
#  'AГ',
#  'AГDI',
#  'AГДЗC',
#  'AГП',
#  'AД',
#  'AДПМ',
#  'AЗ',
#  'AЗA-3',
#  'AЗИA',
#  'AЗИЯ',
#  'AЗЛK',
#  'AИC',
#  'AЙДИ',
#  'AЛ',
#  'AЛK',
#  'AЛKA',
#  'AЛИ',
#  'AЛИPИЗA',
#  'AЛИPИЗAУCTA',
#  'AЛЛOЙ',
#  'AЛЛOУ',
#  'AЛЬФA',
#  'AЛЬФA-POМEO',
#  'AЛЬФAPOМEO',
#  'AЛЬФAROМEO',
#  'AЛЯCKA',
#  'AМ',
#  'AМ-7',
#  'AМ520',
#  'AМAROK',
#  'AМE',
#  'AМЗ',
#  'AМУP',
#  'AП',
#  'AПA',
#  'AПC',
#  'AПEЛЬ',
#  'AПK',
#  'AПP',
#  'AПT',
#  'AУATS',
#  'AУDI',
#  'AУД',
#  'AУДA',
#  'AУДИ',
#  'AУЛИ',
#  'AФ',
#  'AФ-',
#  'AФC',
#  'AЦ',
#  'AЦ5',
#  'AЦB',
#  'AЦC',
#  'AЦH',
#  'AЦO',
#  'AЦT',
#  'AЦЛ',
#  'AЦП',
#  'AЭ',
#  'AЯTC',
#  'B',
#  'BA',
#  'BA3',
#  'BA6',
#  'BACER',
#  'BAH',
#  'BAH-XOOЛ',
#  'BAH-XOЛЛ',
#  'BAH-XУЛ',
#  'BAHXOOЛ',
#  'BAHXOЛ',
#  'BAHXOЛЛ',
#  'BAHXOЛЛ,',
#  'BAHXУЛ',
#  'BAHГE',
#  'BAJA',
#  'BAJAJ',
#  'BALT',
#  'BALTVOTORS',
#  'BALTМOTORC',
#  'BALTМOTORS',
#  'BALМOTORS',
#  'BARIN',
#  'BAX',
#  'BAЗ',
#  'BAЙЛTOH',
#  'BC',
#  'BCT',
#  'BEHTO',
#  'BEKOH',
#  'BEKTPA',
#  'BENALU',
#  'BENELLI',
#  'BENNI',
#  'BENTLEУ',
#  'BENTLУ',
#  'BEPHA',
#  'BEЙЛTOH',
#  'BEЛTOH',
#  'BEЛЬTOH',
#  'BHD',
#  'BHD82R-УUEJCI',
#  'BILLIANCE',
#  'BODEX',
#  'BOGDAN',
#  'BONUМ',
#  'BOPTECK',
#  'BOPTEKC',
#  'BOPTEX',
#  'BOPTЭKC',
#  'BOVA',
#  'BOXER',
#  'BOXSTER',
#  'BOЛBO',
#  'BOЛГA',
#  'BOЛГAБAC',
#  'BOЛЖAHИH',
#  'BOЛЬBA',
#  'BOЛЬBO',
#  'BOЛЬKO',
#  'BOЛЬЦBAГEH',
#  'BOЬBO',
#  'BOЯДЖEP',
#  'BRILIACE',
#  'BRILIANCE',
#  'BRILLANCE',
#  'BRILLIACE',
#  'BRILLIANCE',
#  'BRILLIANSE',
#  'BRILLINCE',
#  'BRILLLANCE',
#  'BSF',
#  'BUCHER',
#  'BUICK',
#  'BUROTEX',
#  'BWS',
#  'BX',
#  'BИ',
#  'BИC',
#  'BИEЛTOH',
#  'BИKTOPИ',
#  'BИБEPTИ',
#  'BИЛTOH',
#  'BЛ',
#  'BЛ11ГX',
#  'BЛB',
#  'BЛB1-B',
#  'BЛB6',
#  'BМ',
#  'BМK',
#  'BУЛKAH',
#  'BЭЛTOH',
#  'C',
#  'C1',
#  'C250D',
#  'C4',
#  'C5',
#  'C50',
#  'C50T',
#  'CAAB',
#  'CAAБ',
#  'CAB',
#  'CADILAC',
#  'CADILAG',
#  'CADILAK',
#  'CADILLA',
#  'CADILLAC',
#  'CADILLAK',
#  'CADJLLAC',
#  'CAHHИ',
#  'CAHTA',
#  'CAHГ',
#  'CAHГУONG',
#  'CAHГЮHГ',
#  'CAHЙOHГ',
#  'CAHЬEH',
#  'CAHЬEHГ',
#  'CAHЬOHГ',
#  'CAK',
#  'CAKOH',
#  'CANGAN',
#  'CANIA',
#  'CANTER',
#  'CAP',
#  'CAPTIVA',
#  'CAPМAT',
#  'CARSAN',
#  'CAДИЛЛAK',
#  'CAЗ',
#  'CAМPAT',
#  'CAМPO',
#  'CAМRO',
#  'CAМПO',
#  'CAУENNE',
#  'CB.',
#  'CC',
#  'CCAH',
#  'CCAHEH',
#  'CCAHГ',
#  'CCAЙOHГ',
#  'CCP-LF',
#  'CCT',
#  'CEAT',
#  'CEAЗ',
#  'CEELУ',
#  'CEEVROLET',
#  'CEHKE',
#  'CELLУ',
#  'CERУ',
#  'CETPA',
#  'CETRA',
#  'CEVROLEN',
#  'CEVROLET',
#  'CEБPИHГ',
#  'CH',
#  'CHACМAN',
#  'CHAHGAN',
#  'CHANGAN',
#  'CHATEAU',
#  'CHAVROLET',
#  'CHEBROLET',
#  'CHECROLET',
#  'CHEETA',
#  'CHEFROLET',
#  'CHENROLET',
#  'CHEREAU',
#  'CHERI',
#  'CHEROLET',
#  'CHERROLET',
#  'CHERU',
#  'CHERVOLET',
#  'CHERУ',
#  'CHEUROIET',
#  'CHEUROLET',
#  'CHEVEOLET',
#  'CHEVOLET',
#  'CHEVPOLET',
#  'CHEVR0LET',
#  'CHEVRALET',
#  'CHEVRILE',
#  'CHEVRILET',
#  'CHEVRJLET',
#  'CHEVRLET',
#  'CHEVROET',
#  'CHEVROIET',
#  'CHEVROL',
#  'CHEVROLAT',
#  'CHEVROLE',
#  'CHEVROLE,',
#  'CHEVROLEN',
#  'CHEVROLER',
#  'CHEVROLET',
#  'CHEVROLEУ',
#  'CHEVROLRT',
#  'CHEVROLT',
#  'CHEVROLTN',
#  'CHEVROLTT',
#  'CHEVROVET',
#  'CHEVRPLET',
#  'CHEVTOLET',
#  'CHEWROLE',
#  'CHEWROLET',
#  'CHEXROLET',
#  'CHITUVA',
#  'CHITUМA',
#  'CHRASLER',
#  'CHRVROLET',
#  'CHRУ',
#  'CHRУCLER',
#  'CHRУSLER',
#  'CHRУSLET',
#  'CHTVROLET',
#  'CHTVROLRT',
#  'CHVROLET',
#  'CHМITZ',
#  'CINROEN',
#  'CIRRUS',
#  'CITHOEN',
#  'CITREN',
#  'CITRIEN',
#  'CITROE',
#  'CITROEH',
#  'CITROEN',
#  'CITRORN',
#  'CITROTN',
#  'CK',
#  'CKAHTA',
#  'CKAHИA',
#  'CKAHИЯ',
#  'CKAHЬЯ',
#  'CKANIA',
#  'CKAT',
#  'CKB1',
#  'CKOДA',
#  'CKИOH',
#  'CKИФ',
#  'CNEVROLET',
#  'COBALT',
#  'COEGEL',
#  'COHATA',
#  'COHИK',
#  'COKOH',
#  'CORANDO',
#  'CORONDO',
#  'COTROEN',
#  'COUNTRУ',
#  'COЛЯPИC',
#  'COМIL',
#  'CPУKH',
#  'CPУМKЩДУE',
#  'CR',
#  'CRAISLER',
#  'CRAND',
#  'CRAУSLER',
#  'CREAT',
#  'CREATWALL',
#  'CRERУ',
#  'CRETA',
#  'CRONA',
#  'CRUZE',
#  'CRУPHON',
#  'CRУSLER',
#  'CS',
#  'CSHМITZ',
#  'CST',
#  'CST0A1',
#  'CST0E1',
#  'CST180',
#  'CSTJ82',
#  'CSTOE1',
#  'CTELS',
#  'CTEЛC',
#  'CTEЛЗ',
#  'CTPOEH',
#  'CTTROEN',
#  'CUV',
#  'CVEVROLET',
#  'CX4',
#  'CБ214',
#  'CБAPУ',
#  'CДA',
#  'CЗA',
#  'CЗМ',
#  'CЗУKИ',
#  'CИAT',
#  'CИB',
#  'CИKAP',
#  'CИPOEH',
#  'CИTOPEH',
#  'CИTPO',
#  'CИTPOEH',
#  'CИTPOЭH',
#  'CМ',
#  'CМA',
#  'CМAPT',
#  'CМД',
#  'CМИTC',
#  'CП',
#  'CПACA',
#  'CПEЦПPИЦEП',
#  'CПМ',
#  'CУ3УKИ',
#  'CУB',
#  'CУBT',
#  'CУBT11',
#  'CУEVROLET',
#  'CУEVROLTT',
#  'CУБAPA',
#  'CУБAPУ',
#  'CУБУPУ',
#  'CУЗУK',
#  'CУЗУKИ',
#  'CУЦУKИ',
#  'CЦИOH',
#  'DA',
#  'DACIA',
#  'DADУW',
#  'DAEBУ',
#  'DAEOO',
#  'DAEVOO',
#  'DAEW00',
#  'DAEWHO',
#  'DAEWO',
#  'DAEWOO',
#  'DAEWWO',
#  'DAFWOO',
#  'DAHATSU',
#  'DAIHA',
#  'DAIHATSU',
#  'DAIHATSУ',
#  'DAISUN',
#  'DAIWOO',
#  'DAIМLER',
#  'DAIМLER-BEHZ',
#  'DAIМLER-BENZ',
#  'DAIМLERBENZ',
#  'DANGFFN',
#  'DANSUN',
#  'DAOWOO',
#  'DASIA',
#  'DASTIN',
#  'DASTUN',
#  'DATCUN',
#  'DATDUN',
#  'DATHATSU',
#  'DATSON',
#  'DATSU',
#  'DATSUH',
#  'DATSUN',
#  'DATSUМ',
#  'DATZUN',
#  'DAWEOO',
#  'DAWOO',
#  'DAУHATSU',
#  'DEAWOO',
#  'DEEWOO',
#  'DERBI',
#  'DERVEIS',
#  'DERVEУS',
#  'DERWAУS',
#  'DERWEУS',
#  'DEU',
#  'DEWOO',
#  'DEМ',
#  'DEМAG',
#  'DKODA',
#  'DODG',
#  'DODGE',
#  'DODJE',
#  'DODZH',
#  'DOEWOO',
#  'DON',
#  'DONG',
#  'DONG_FENG',
#  'DONGFEN',
#  'DONGFENG',
#  'DONINVEST',
#  'DOOGE',
#  'DORD',
#  'DOVA',
#  'DSEWOO',
#  'DUCA',
#  'DUCATI',
#  'DUNFУEN',
#  'DUTSAN',
#  'DUTSUN',
#  'DМF',
#  'E',
#  'E-CLASS',
#  'EBPAKOМ',
#  'EELУ',
#  'ENAULT',
#  'EOS',
#  'EPICA',
#  'EQUINOX',
#  'ERCEDES',
#  'ERCEDES-BENZ',
#  'ESCALADE',
#  'ESPERO',
#  'EURO',
#  'EUROTEX',
#  'EVOQUE',
#  'EVRAKOМ',
#  'EXPERT',
#  'EXPRESS',
#  'F',
#  'F0RD',
#  'F1',
#  'F12',
#  'F150',
#  'F2',
#  'F22',
#  'F24S-A',
#  'F3',
#  'FAFGE',
#  'FARID',
#  'FATON',
#  'FB',
#  'FBJ',
#  'FCT',
#  'FE',
#  'FECON',
#  'FEKON',
#  'FERRARI',
#  'FGR',
#  'FIA',
#  'FIAN',
#  'FIAT',
#  'FILT',
#  'FIRD',
#  'FJRD',
#  'FL',
#  'FL6',
#  'FLAT',
#  'FLC-12064T',
#  'FLIEGL',
#  'FLL',
#  'FLUEHAUF',
#  'FOCA',
#  'FODR',
#  'FOFD',
#  'FOLKSVAGEN',
#  'FOLKSWAGEN',
#  'FOPD',
#  'FOR',
#  'FORA',
#  'FORD',
#  'FORF',
#  'FORO',
#  'FORS',
#  'FORSAGE',
#  'FORTUNE',
#  'FOTON',
#  'FPRD',
#  'FR',
#  'FRE1GHTLINER',
#  'FREDLAУNER',
#  'FREELANDER',
#  'FREGHTLINER',
#  'FREICHTLINER',
#  'FREIDHTLINER',
#  'FREIGHLINER',
#  'FREIGHNLINER',
#  'FREIGHT',
#  'FREIGHTL',
#  'FREIGHTLANER',
#  'FREIGHTLENEE',
#  'FREIGHTLINE',
#  'FREIGHTLINER',
#  'FREIGHTNER',
#  'FREIGNTLINER',
#  'FREIGTLINER',
#  'FREITLAINER',
#  'FREJGHTLINER',
#  'FRETGHTLINER',
#  'FREUGHLINER',
#  'FREUHAUF',
#  'FRFIGHTLINER',
#  'FRIEGHTLINER',
#  'FRIGHTLINER',
#  'FRIOF',
#  'FRRIGHTLINER',
#  'FRUEHA',
#  'FRUEHAF',
#  'FRUEHAUF',
#  'FRUEHAUR',
#  'FRUENA',
#  'FRUENAUF',
#  'FRUEМAVF',
#  'FRUNAUF',
#  'FRVEHAVF',
#  'FRУUOF',
#  'FS',
#  'FSO',
#  'FST',
#  'FST1',
#  'FT',
#  'FTB',
#  'FTS',
#  'FXFB',
#  'G-МAX',
#  'G80',
#  'GA',
#  'GAB',
#  'GAC',
#  'GC6',
#  'GEEIU',
#  'GEEIУ',
#  'GEEKУ',
#  'GEEL',
#  'GEELE',
#  'GEELI',
#  'GEELU',
#  'GEELV',
#  'GEELУ',
#  'GEEP',
#  'GEERУ',
#  'GEETУ',
#  'GEEУ',
#  'GELLI',
#  'GELLУ',
#  'GELУ',
#  'GENERAL',
#  'GENESIS',
#  'GEO',
#  'GEON',
#  'GGREATWALL',
#  'GHERУ',
#  'GHEVROLET',
#  'GHOST',
#  'GILERA',
#  'GOLDEN',
#  'GOLDENDRA',
#  'GOLF',
#  'GONOW',
#  'GP1',
#  'GP800',
#  'GR',
#  'GRAET',
#  'GRAND',
#  'GREA',
#  'GREAL',
#  'GREALT',
#  'GREAN',
#  'GREAT',
#  'GREAT-WALL',
#  'GREATT',
#  'GREATWALL',
#  'GREET',
#  'GRERT',
#  'GRET',
#  'GRETA',
#  'GRETT',
#  'GREУT',
#  'GRIPHON',
#  'GRUNWALD',
#  'GRW',
#  'GRУPHON',
#  'GRУPHQN',
#  'GTTLУ',
#  'GUTE',
#  'GWМ',
#  'GX',
#  'GМ',
#  'H',
#  'H-1',
#  'H-100',
#  'H1',
#  'H100',
#  'H10S12A',
#  'H12',
#  'H2',
#  'H250',
#  'H2501',
#  'H3',
#  'H5',
#  'H530',
#  'H6',
#  'H606',
#  'H6S-0',
#  'H6S-A',
#  'H701',
#  'H78S0UA',
#  'H7S',
#  'H7S-1',
#  'H7S-5',
#  'H7S-7',
#  'H7S-A',
#  'H7S-O',
#  'H7S1',
#  'H7SA',
#  'H8',
#  'H80',
#  'H9',
#  'HA',
#  'HABAPA',
#  'HACCAH',
#  'HAFE1',
#  'HAFEI',
#  'HAFFI',
#  'HAIGER',
#  'HAIМA',
#  'HAJМA',
#  'HAO',
#  'HAOBON',
#  'HAOJIN',
#  'HAPKO',
#  'HARCO',
#  'HARLEУ',
#  'HARLEУ-',
#  'HARLEУ-DA',
#  'HARLEУ-DAVIDS',
#  'HARLEУ-DAVIDSON',
#  'HARLEУ-DEVIDSON',
#  'HARLEУDAEVIDSON',
#  'HARTUNG',
#  'HAVAL',
#  'HAWAL',
#  'HAWNAI',
#  'HAWTAI',
#  'HAИМA',
#  'HAММEP',
#  'HAММER',
#  'HB',
#  'HD',
#  'HD-120',
#  'HD-65',
#  'HD-72',
#  'HD-74AA',
#  'HD-78',
#  'HD-78NO',
#  'HD120',
#  'HD120B',
#  'HD120C',
#  'HD120N',
#  'HD120P',
#  'HD121М',
#  'HD170',
#  'HD170C',
#  'HD170N',
#  'HD170P',
#  'HD250',
#  'HD250B',
#  'HD250D',
#  'HD260',
#  'HD270',
#  'HD450',
#  'HD65',
#  'HD65BO',
#  'HD65DO',
#  'HD65EO',
#  'HD65N0',
#  'HD65NO',
#  'HD65P0',
#  'HD65PA',
#  'HD65PO',
#  'HD65XO',
#  'HD72',
#  'HD72BO',
#  'HD72DO',
#  'HD72NO',
#  'HD72P0',
#  'HD72PO',
#  'HD73A1',
#  'HD73AC',
#  'HD73AD',
#  'HD73AH',
#  'HD74AA',
#  'HD74AC',
#  'HD74AD',
#  'HD74AH',
#  'HD78',
#  'HD78A6',
#  'HD78AA',
#  'HD78AC',
#  'HD78AD',
#  'HD78AH',
#  'HD78AL',
#  'HD78B0',
#  'HD78BA',
#  'HD78BO',
#  'HD78D0',
#  'HD78DO',
#  'HD78N0',
#  'HD78NO',
#  'HD78P0',
#  'HD78PA',
#  'HD78PO',
#  'HD78V0',
#  'HD78М0',
#  'HD78МO',
#  'HDPIC',
#  'HE',
#  'HEBPOЛE',
#  'HEHДЭ',
#  'HENDE',
#  'HEOПЛAH',
#  'HEPKO',
#  'HERITAGE',
#  'HERLEУ-DAVIDSON',
#  'HET',
#  'HETAМ',
#  'HEVROLE',
#  'HEVROLET',
#  'HEДЭ',
#  'HEМAH',
#  'HEФAC',
#  'HEФAЗ',
#  'HFJ',
#  'HHUNDAI',
#  'HIAМA',
#  'HICCAN',
#  'HIGER',
#  'HINDA',
#  'HINO',
#  'HISSAN',
#  'HIUNDAI',
#  'HIUNDAУ',
#  'HKA',
#  'HO',
#  'HODA',
#  'HOHDA',
#  'HOHДA',
#  'HONA',
#  'HONDA',
#  'HONDAI',
#  'HOTE',
#  'HOUNDAI',
#  'HOWA',
#  'HOWJ',
#  'HOWO',
#  'HOМDA',
#  'HOМO',
#  'HOУT',
#  'HT',
#  'HTUNDAI',
#  'HTМ',
#  'HUATIAN',
#  'HUINDAI',
#  'HUNDAI',
#  'HUNDAУ',
#  'HUSQVARNA',
#  'HUUNDAI',
#  'HUМBAUR',
#  'HUМER',
#  'HUММER',
#  'HUУNDAI',
#  'HUУNDAУ',
#  'HUУNFAI',
#  'HД',
#  'HДЖ',
#  'HЗA',
#  'HИCAAH',
#  'HИCAH',
#  'HИCCA',
#  'HИCCAH',
#  'HИCCH',
#  'HИHO',
#  'HИSSAH',
#  'HИИCAH',
#  'HП300',
#  'HУANDAI',
#  'HУHDAI',
#  'HУHДAЙ',
#  'HУINDAI',
#  'HУNDAI',
#  'HУNDAУ',
#  'HУNDAУI',
#  'HУNNDAI',
#  'HУOSUNG',
#  'HУUDAI',
#  'HУUHDAI',
#  'HУUN',
#  'HУUNADI',
#  'HУUNAI',
#  'HУUNDA',
#  'HУUNDAI',
#  'HУUNDAJ',
#  'HУUNDAL',
#  'HУUNDAO',
#  'HУUNDAU',
#  'HУUNDAУ',
#  'HУUNDI',
#  'HУUNDIA',
#  'HУUNFAI',
#  'HУUNGAI',
#  'HУUTDAI',
#  'HУXДAЙ',
#  'HУМER',
#  'HФ',
#  'HЯPKO',
#  'I',
#  'IAT',
#  'IELTON',
#  'IFINITI',
#  'II',
#  'IKARUS',
#  'INFANITI',
#  'INFINETI',
#  'INFININI',
#  ...]

# %%
df
# Out:
#             id                           text_brandmodel Brand_AS  \
# 0           11                            DАF ХF 105.460      DAF
# 1           12                             DАЕWОО ЕSРЕRО   DAEWOO
# 2           13                           DАЕWОО МАТIZ МХ   DAEWOO
# 3           14                              DАТSUN ОN-DО   DATSUN
# 4           15                               FIАТ DUСАТО     FIAT
# ...        ...                                       ...      ...
# 662548  745401           ЯНГАНГ РАТRОN-УINGАNG ТАКЕR 250   PATRON
# 662549  745402  ЯНГАНГ УG150-2FС РАТRОN-УINGАNG РАRТIZАN   PATRON
# 662550  745403  ЯНГАНГ УG150-2FС РАТRОN-УАNGАNG РАRТIZАN   PATRON
# 662551  745404                                      ЯРИС    OTHER
# 662552  745405                                      ЯРИС   TOYOTA
#
#                 Model_AS  Modelkey_AS       l Brand_RUS
# 0       TRUCKS XF SERIES         1880     NaN       ДАФ
# 1                 ESPERO          747  DAEWOO       ДЕУ
# 2                  MATIZ          756  DAEWOO       ДЕУ
# 3                  ON-DO         8731  DATSUN    ДАТСУН
# 4                 DUCATO         1620    FIAT      ФИАТ
# ...                  ...          ...     ...       ...
# 662548             TAKER        11917     NaN      None
# 662549          PARTIZAN        11912     NaN      None
# 662550          PARTIZAN        11912     NaN      None
# 662551             OTHER          122     NaN      None
# 662552             YARIS          457     NaN    ТОЙОТА
#
# [662553 rows x 7 columns]

# %%
import Levenshtein

# %%
brands = list(dict.values()) + list(dict.keys())

# %%
data
# Out:
#             id    text_brandmodel Brand_AS Model_AS  Modelkey_AS    l
# 1           12      DАЕWОО ЕSРЕRО   DAEWOO   ESPERO          747  NaN
# 2           13    DАЕWОО МАТIZ МХ   DAEWOO    MATIZ          756  NaN
# 124       3098       DАFWОО NЕХIА   DAEWOO    NEXIA          758  NaN
# 147       3121        DАWОО NЕХIА   DAEWOO    NEXIA          758  NaN
# 148       3122       DАЕW00 NЕХIА   DAEWOO    NEXIA          758  NaN
# ...        ...                ...      ...      ...          ...  ...
# 642772  725625       ШЕВРОЛЕ АВЕО   DAEWOO   GENTRA         6168  NaN
# 642773  725626       ШЕВРОЛЕ АВЕО   DAEWOO    MATIZ          756  NaN
# 646488  729341      ШЕВРОЛЕ ЛАНОС   DAEWOO    LANOS          752  NaN
# 658414  741267             ЭСПЕРО   DAEWOO   ESPERO          747  NaN
# 658415  741268         ЭСПЕРО ДЭУ   DAEWOO   ESPERO          747  NaN
#
# [5422 rows x 6 columns]

# %%
Levenshtein.jaro_winkler('ДАЕВУNUВIRА-СDХ', 'ДЕУ')
# Out:
# 0.76

# %%
df['l'] = df.apply(leven,axis=1)

# %%
df[17000:17050]
# Out:
#           id                       text_brandmodel Brand_AS Model_AS  \
# 17000  99853  FIАТ РUNТО LОUNGЕ ВZ1.4СС АТ199ВХВ11     FIAT    PUNTO
# 17001  99854  FIАТ РUNТО LОUNСЕ ВZ14СС АТ 199ВХВ11     FIAT    PUNTO
# 17002  99855            FIАТ РUNТО RАСING 199АХV1В     FIAT    PUNTO
# 17003  99856    FIАТ РUNТО RАСING ВZ1.4СС 199АХV1В     FIAT    PUNTO
# 17004  99857     FIАТ РUNТО RАСING ВZ1.4СС199АХV1В     FIAT    PUNTO
# 17005  99858                          FIАТ РUNТО S     FIAT    PUNTO
# 17006  99859                        FIАТ РUNТО S55     FIAT    PUNTO
# 17007  99860                    FIАТ РUNТО SЕLЕСТА     FIAT    PUNTO
# 17008  99861                 FIАТ РUNТО SЕLЕСТА 60     FIAT    PUNTO
# 17009  99862     FIАТ РUNТО SРОRТ ВZ1.4СС 199АХW1А     FIAT    PUNTO
# 17010  99863                         FIАТ РUNТО SХ     FIAT    PUNTO
# 17011  99864                     FIАТ РUNТО SХ1242     FIAT    PUNTO
# 17012  99865                      FIАТ РUNТО ВRАVО     FIAT    BRAVO
# 17013  99866                         FIАТ РUNТО ЕL     FIAT    PUNTO
# 17014  99867                        FIАТ РUNТО ЕLХ     FIAT    PUNTO
# 17015  99868                    FIАТ РUNТО ЕLХ 16V     FIAT    PUNTO
# 17016  99869                     FIАТ РUNТО ЕLХ16V     FIAT    PUNTO
# 17017  99870                    FIАТ РUNТО ЕVО 1.2     FIAT    PUNTO
# 17018  99871               FIАТ РUNТО ЕVО 1.3 МJТD     FIAT    PUNTO
# 17019  99872                       FIАТ РUNТО ЕАSУ     FIAT    PUNTO
# 17020  99873              FIАТ РUNТО ЕАSУ 199ВХВ1А     FIAT    PUNTO
# 17021  99874      FIАТ РUNТО ЕАSУ 199ВХВ1А ВZ1 4СС     FIAT    PUNTO
# 17022  99875      FIАТ РUNТО ЕАSУ 199ВХВ1А ВZ1.4СС     FIAT    PUNTO
# 17023  99876    FIАТ РUNТО ЕАSУ ВZ 1 4 СС 199ВХВIА     FIAT    PUNTO
# 17024  99877     FIАТ РUNТО ЕАSУ ВZ 1.4 С 199ВХВLА     FIAT    PUNTO
# 17025  99878     FIАТ РUNТО ЕАSУ ВZ 1.4СС 199ВХВ1А     FIAT    PUNTO
# 17026  99879     FIАТ РUNТО ЕАSУ ВZ1,4 СС 199ВХВ1А     FIAT    PUNTO
# 17027  99880               FIАТ РUNТО ЕАSУ ВZ1.4СС     FIAT    PUNTO
# 17028  99881    FIАТ РUNТО ЕАSУ ВZ1.4СС 199 ВХ В1А     FIAT    PUNTO
# 17029  99882      FIАТ РUNТО ЕАSУ ВZ1.4СС 199ВХВ1А     FIAT    PUNTO
# 17030  99883      FIАТ РUNТО ЕАSУ ВZ1.4СС 199ВХВIА     FIAT    PUNTO
# 17031  99884   FIАТ РUNТО ЕАSУ ВZ1.4СС АТ 199ВХВ11     FIAT    PUNTO
# 17032  99885                        FIАТ РUNТО НGТ     FIAT    PUNTO
# 17033  99886                        FIАТ РUNТО НLХ     FIAT    PUNTO
# 17034  99887                   FIАТ РUNТО НLХ 16 V     FIAT    PUNTO
# 17035  99888                    FIАТ РUNТО НLХ 16V     FIAT    PUNTO
# 17036  99889                            FIАТ РАLIО     FIAT    PUNTO
# 17037  99890                            FIАТ РАLIО     FIAT    PALIO
# 17038  99891                         FIАТ РАLIО 65     FIAT    PALIO
# 17039  99892                         FIАТ РАLIО SW     FIAT    PALIO
# 17040  99893                    FIАТ РАLIО WЕЕКЕND     FIAT    PALIO
# 17041  99894              FIАТ РАLIО WЕЕКЕND 1.7ТD     FIAT    PALIO
# 17042  99895            FIАТ РАLIО WЕЕКЕND 100 16V     FIAT    PALIO
# 17043  99896                FIАТ РАLIО WЕЕКЕND 16V     FIAT    PALIO
# 17044  99897                 FIАТ РАLIО WЕЕКЕND 75     FIAT    PALIO
# 17045  99898            FIАТ РАLIО WЕЕКЕND 75 1.2I     FIAT    PALIO
# 17046  99899      FIАТ РАLIО WЕЕКЕND 75 WЕЕКЕND 75     FIAT    PALIO
# 17047  99900                   FIАТ РАLIО WЕЕКЕNND     FIAT    PALIO
# 17048  99901                  FIАТ РАLО WЕЕКЕND 75     FIAT    PALIO
# 17049  99902                            FIАТ РАNDА     FIAT    PANDA
#
#        Modelkey_AS     l
# 17000          876  FIАТ
# 17001          876  FIАТ
# 17002          876  FIАТ
# 17003          876  FIАТ
# 17004          876  FIАТ
# 17005          876  FIАТ
# 17006          876  FIАТ
# 17007          876  FIАТ
# 17008          876  FIАТ
# 17009          876  FIАТ
# 17010          876  FIАТ
# 17011          876  FIАТ
# 17012          862  FIАТ
# 17013          876  FIАТ
# 17014          876  FIАТ
# 17015          876  FIАТ
# 17016          876  FIАТ
# 17017          876  FIАТ
# 17018          876  FIАТ
# 17019          876  FIАТ
# 17020          876  FIАТ
# 17021          876  FIАТ
# 17022          876  FIАТ
# 17023          876  FIАТ
# 17024          876  FIАТ
# 17025          876  FIАТ
# 17026          876  FIАТ
# 17027          876  FIАТ
# 17028          876  FIАТ
# 17029          876  FIАТ
# 17030          876  FIАТ
# 17031          876  FIАТ
# 17032          876  FIАТ
# 17033          876  FIАТ
# 17034          876  FIАТ
# 17035          876  FIАТ
# 17036          876  FIАТ
# 17037          874  FIАТ
# 17038          874  FIАТ
# 17039          874  FIАТ
# 17040          874  FIАТ
# 17041          874  FIАТ
# 17042          874  FIАТ
# 17043          874  FIАТ
# 17044          874  FIАТ
# 17045          874  FIАТ
# 17046          874  FIАТ
# 17047          874  FIАТ
# 17048          874  FIАТ
# 17049          875  FIАТ

# %%
set(df['l'].values)
# Out:
# {'IS',
#  'SНЕNDА',
#  'МЕRСЕDЕS-ВЕNZ-Е240',
#  'МIТSUВISНI-L200',
#  'МIТSUВISСНI',
#  'SСНМIТZSСS27',
#  'МЕRСЕDЕSВЕNZ1846',
#  'LАDА)',
#  'SSАNQУОNQ',
#  'FОRD-',
#  'КRDNЕ',
#  'RЕNАULТ-19',
#  'СНRУSLЕR',
#  'LАNDRОVЕRSРОRТ',
#  'ЫUZUКI',
#  'LIАZ',
#  'IАТ',
#  'ZНWЕКI',
#  'SСНМТZSК024|L',
#  'МIТSUВIВНI',
#  'МЕRСЕDЕR-ВЕNZ',
#  'СНЕVRОLЕТ,',
#  'RАSЕR',
#  'GОNОW',
#  'МЕRСЕDЕSВЕNZG63',
#  'VОLКSWААGЕN',
#  'GRУРНQN',
#  'LАND-RОVЕR',
#  'FОRSАGЕ',
#  'V2',
#  'SНЕVRОLЕ',
#  'МЕRСЕDЕS-ВЕNZ-308D',
#  'GНЕVRОLЕТ',
#  'FОRDКА',
#  'А4UDI',
#  'МЕRСЕDЕS-ВЕNZ-260',
#  'DЕWОО',
#  'МЕRСТDЕS-ВЕNZ',
#  'LАNGЕNDОRF-SКА',
#  'DАЕWОО',
#  'V6',
#  'МIТSUВIНIL200',
#  'МIТSUВISНIDIОN',
#  'SW240GRКR',
#  'NУNDАI',
#  'СIТRОЕ',
#  'INFINUТI',
#  'МЕRСЕDЕS-ВЕNZ-1733',
#  'МЕRСЕDЕS-ВЕNZ-200',
#  'FRUЕНАUR',
#  'МIТSUВISНI-СОLТ',
#  'МЕRСЕDЕS0ВЕNZ',
#  'INFINТIQХ50',
#  'RЕNАULТ',
#  'SНАСМАNSХ3316DТ366',
#  'INFINIТI-FХ35',
#  'МЕRСЕDRS-ВЕNZ',
#  'FLL',
#  'SНАСМАNSХ3255DR384',
#  'МЕRСЕDЕSВЕNZ250',
#  'INFININI',
#  'МЕRСЕDЕSВЕNZЕ210',
#  'DОDJЕ',
#  'МЕRСЕDЕSВЕNZУ230',
#  'ВRILLIАNСЕ-Н530',
#  'НУUNDАJ',
#  'КЕGЕL',
#  'LRХUS',
#  'КАSSВОНNЕR',
#  'RFЕNАULТ',
#  'ОRIОN',
#  'LАDА',
#  'КING',
#  'VL11',
#  'LS',
#  'МЕRСЕDЕS-310D',
#  'ТЕRЕХ-DЕМАG',
#  'INFINIТI-FХ45',
#  'DОDDGЕ',
#  'SНЕNL',
#  'МIIТSUВISНI',
#  'ВRILLIАНСЕV5',
#  'VОLКWАGЕN',
#  'МISUВISНI',
#  'FRЕIGНТLINЕRСL12006',
#  'RЕNАULR',
#  'FRЕDLАУNЕR',
#  'SUВАGU',
#  'NIISАN',
#  'МЕRСЕDЕSВЕNZ100D',
#  'DАНАТSU',
#  'ХUМВАUR',
#  'SКV',
#  'ВRILIАNСЕV5',
#  'ВЕNАLU',
#  'LFND',
#  'ТRАILОR',
#  'НУUNDАII20',
#  'НАRLЕУ-DАVIDSОN',
#  'LАNDRОVЕR46НSЕ',
#  'G-МАХ',
#  'VОLКSW.',
#  'МЕRСЕDЕSВЕNZА170',
#  'РЕUGЕТ',
#  'МЕRСЕDЕS-ВЕNZС250',
#  'РОRSСЕ',
#  'RЕНО',
#  'МЕRСЕDЕS-ВЕNА',
#  'МЕRСЕDЕS-ВЕNZМL350',
#  'SF33',
#  'LЕСUS',
#  'САDILLАС',
#  'RЕNАULТ?',
#  'МАSЕRАТI',
#  'FRЕIGНТLINЕRСSТ120',
#  'F12',
#  'RЕNАUIL',
#  'DОNINVЕSТ',
#  'МL',
#  'SUZUКU',
#  'SСНМIСZ',
#  'SСНWАRZМULLЕRКОSТ3Е',
#  'МЕRСЕDЕSВЕNZ210',
#  'SN',
#  'VОLКSWАGЕNRЕG',
#  'GRЕЕLУ',
#  'МЕRСЕDЕS-ВЕNZGLА',
#  'RЕNАULТ440',
#  'НУНUNDАI',
#  'RЕNАUТL',
#  'SСНWАRZМUЕLLЕRSРА',
#  'НУUNDАI35',
#  'НUNDАУ',
#  'FRЕIGНТLINЕR437',
#  'DАТSUN',
#  'FLD-12064SТ',
#  'КАЕSSВОNRЕR',
#  'НIUNDАУ',
#  'МЕRСЕDЕSS',
#  'GRЕЕТ',
#  'RАV',
#  'SНААNQI',
#  'NUISSАN',
#  'МIТSUВISNI',
#  'СУЕVRОLТТ',
#  'INFINIТIG37',
#  'МIТSUВISНIСОLТ',
#  'КRАISLЕR',
#  'SСНМIТZSСS24S01',
#  'SТЕЕLВЕАR',
#  'АUIDI',
#  'FЕКОN',
#  'VОLКSWАGЕNLТ28',
#  'РЕL',
#  'DОDG',
#  'МЕRСЕDЕS-ВЕNZ-180',
#  'МЕRСЕDЕS-ВЕNZ230',
#  'МЕRСЕDЕSВЕNZS280',
#  'МЕRСЕDЕSВЕNZ240',
#  'МIТSUВISНIАJЕRО',
#  'JКУI',
#  'МЕRСЕDЕNS-ВЕNZ',
#  'МЕRСЕDЕС-ВЕNZ',
#  'SНАNNУАNG',
#  'ЛЕНД-RОVЕR',
#  'МЕRСЕDЕSВЕNZSLК',
#  'FRЕIGНТLINЕRFLD',
#  'SUZU',
#  'SUZUКI',
#  'FRUЕNА',
#  'МЕRСЕDЕSВЕNZV250',
#  'RЕNО19',
#  'SСIОNХВ',
#  'FS',
#  'МЕRСЕDЕSВЕNZЕ270',
#  'RЕNUАLТ',
#  'МЕRСЕDЕS-ВЕVZ',
#  'VОLКSVАGЕNРОLО',
#  'VОLКSWGАN',
#  'DАТSUNОN',
#  'FАТОN',
#  'INFINIТII30',
#  'АUDIА5',
#  'INFINТI',
#  'RОLLS-RОУСЕ',
#  'SСНМIТZ-',
#  'GОLDЕN',
#  'INFINIТI-М35',
#  'SRАNIА',
#  'МЕRСЕDЕSВЕNZGLК',
#  'МЕRСЕDЕSВЕNZS430',
#  'МЕRСЕDЕS-ВЕNZ-МВ',
#  'НУUNDАII10',
#  'ТАСНILLА',
#  'VС',
#  'FIАТ',
#  'LАVD',
#  'ZVЕR',
#  'КN250GУ',
#  'LАNА',
#  'МЕRСЕDЕSВЕNZ412D',
#  'ХАРЛЕЙDАVIDSОNХL88',
#  'МЕRСЕDЕSВЕNZ220Е',
#  'МЕRСЕS-ВЕNZ',
#  'SСОDА',
#  'VWВЕНТОGL',
#  'МЕRСЕDЕSВЕNZGL',
#  'WОLКSWАGТN',
#  'SСНМIТZSКI24S8.2',
#  'МЕRСЕDЕSВЕNZЕ240',
#  'КЕОGЕL',
#  'LЕХUС',
#  'МЕRСЕDЕSВЕNZ220D',
#  'INFINIТIFХ',
#  'НIGЕR',
#  'INFINIТIЕХ37',
#  'INFINIТI-Q70',
#  'МЕRСЕDЕSВЕNZS320',
#  'SСNМIТZ',
#  'СRЕАТWАLL',
#  'VWТ5LS-0',
#  'GRЕТТ',
#  'VОLКSWА',
#  'VОLКSWАGЕВ',
#  'VОLОVО',
#  'DАСIАL',
#  'INFINIТУ-FХ35',
#  'МЕRСЕDЕSВЕNZ280',
#  'СОЕGЕL',
#  'МIТSUВISНIАSХLS',
#  'АUDIА4',
#  'VОLКSWАGЕN-GОLF',
#  'SХ4',
#  'ISТRАL',
#  'SМА',
#  'МIRSUВISНI',
#  'GR',
#  'DАFWОО',
#  'DUСАТI',
#  'ВLАDА',
#  'МЕRСЕDЕSВЕNZR320',
#  'РОNILАС',
#  'RЕZZАIОLI',
#  'МЕRСЕDЕS-ВЕNZ-815D',
#  'ТАGАZ',
#  'МЕRСЕDЕS-ВЕNZ-414',
#  'МЕRСЕDЕS-ВЕNZАХОR',
#  'NURSАN',
#  'КIА',
#  'SКV1',
#  'МЕRСЕDЕSВЕNZЕ250',
#  'SСНМIТZS01ТЕНТ',
#  'RАGЕR',
#  'SКОRА',
#  'INFINIТI-Q45',
#  'FRЕТGНТLINЕR',
#  'SСНМIТZSРR24',
#  'НUМЕR',
#  'МЕRСЕDЕSВЕNZА180',
#  'ВАLМОТОRS',
#  'ПGЕЕLУ',
#  'СНЕVRОLЕIVА',
#  'DЕRWАУS',
#  'RЕNАULТ|НR',
#  'FВJ',
#  'RN076S',
#  'RЕGАL',
#  'WIЕL',
#  'НУUNDА',
#  'GЕЕУ',
#  'SСНМIТZ-SСS',
#  'RЕNЕULТ',
#  'НIUNDАI',
#  'МЕRSСЕDЕS-ВЕNZ',
#  'FLАТ',
#  'WIЕLТОNМАН',
#  'FОRО',
#  'МЕRСЕDЕS-1628LS',
#  'НУUNDАIN',
#  'S',
#  'СIТRОУЕN',
#  'SАZUКI',
#  'WIЕLТОNNW',
#  'МЕRС.ВЕNZ',
#  'МЕRСЕDЕSВЕNZС200',
#  'FRЕIDНТLINЕR',
#  'VОLКSАGЕN',
#  'СНIТUVА',
#  'МЕRСЕDЕSВЕNZ1841',
#  'МЕRСЕDЕS-ВЕNZ-А140',
#  'GЕЕLУ',
#  'МЕRСЕDЕS-ВЕNZVIАNО',
#  'МЕRСЕDЕS-ВЕNZЕ230',
#  'SКОFА',
#  'INFINIТIQХ56',
#  'SСНМIТZКО24',
#  'ZF-КУ',
#  'RЕNО-SR',
#  'МЕRСЕDЕS-ВЕNZ-С240',
#  'СНЕVRОLОЕТ',
#  '(ISUZU',
#  'ВUIСК',
#  'АUDI-',
#  'VОLRSWАGЕN',
#  'МЕRСЕDЕSВЕNZ200Е',
#  'МЕRСЕDЕS-ВЕNZ8170',
#  'SНМIТZSКО24',
#  'VОLКSWАGЕNVЕNТО',
#  'АГDI',
#  'VОLКSWАGЕNJЕТТА',
#  'МЕRСЕDЕS-ВЕNZG',
#  'SSАНNG',
#  'FL6',
#  'VОLКSWАGЕNВОRА',
#  'VОLКVО',
#  'НУUNDАI-IХ',
#  'DUNFУЕN',
#  'АSТОN',
#  'GЕLУ',
#  'УUNDАI',
#  'FRЕIGНТLINЕ',
#  'МЕRСЕDЕSВЕNZ260Е',
#  'VОLКSWАGЕN2Н',
#  'СIТRЕN',
#  'VОLКSWАGЕN-6К',
#  'SКI24',
#  'LАNR',
#  'FGR',
#  'NISАSАN',
#  'МЕRСЕDЕS-ВТNZ',
#  'МЕRСЕDЕS-NЕNZ',
#  'LАDАС',
#  'МIТSUВIВISНI',
#  'SСIОNХА',
#  'МIТSUВISНISОLТ',
#  'FIА',
#  'RЕNАUIТSR',
#  'VОLКSWАGЕNТURАN',
#  'АLIRIZА',
#  'НУUNDАУI',
#  'SНМIТС',
#  'МЕRСЕDЕС-',
#  'LАND',
#  'WАNGУЕ',
#  'SМАRТ',
#  'FТ',
#  'СНЕVRОLЕN,',
#  'SСНМIТZSКО24',
#  'VОLКSWАGЕNLТ40',
#  'ГРЕАТWАLL',
#  'МIТSUВISНI',
#  'МЕRСЕDЕS-ВЕВZ',
#  'МРZ',
#  'СНRУSLЕR300',
#  'VОLКSWАGЕG',
#  'СНЕVRОLТ',
#  'МЕRSЕDЕS-ВЕNZ-0305',
#  'САDILLА',
#  'SСНIТZS',
#  'МЕRСЕDЕSВЕNZ407D',
#  'VОLКSWАGТN',
#  'VОLКSWАGЕN-СОLF',
#  'FRЕIGНТLINЕR-FLС',
#  'НFJ',
#  'МIТSUВISНIJЕRО',
#  'SОLIО',
#  'SКО',
#  'GRЕТ',
#  'FRЕIGНТLINЕR-АRGОSУ',
#  'VАNНООL',
#  'I',
#  'DАIWОО',
#  'МЕRСЕDЕS-БЕНЦ',
#  'МЕRСЕDЕS-ВЕNZ-S350',
#  'ВRILLIАNСЕ',
#  'МЕRСЕDЕS-ВЕNZА',
#  'LАDА|',
#  'FОТОN',
#  'DА',
#  'VОLКSVАGЕNLUРО',
#  'DАIНАТSУ',
#  'МIТS.GRАNDIS',
#  'DАЕWWО',
#  'SDR',
#  'RЕNАULIТ',
#  'SUZUКISХ4',
#  'СIТRОЕNС4',
#  'ZNЕN',
#  'LАD',
#  'SСНМIТZSК024|L',
#  'МЕRСЕDЕSВЕNZМL32',
#  'FРRD',
#  'МЕRСЕDЕSВЕNZА200',
#  'МЕRСЕDЕS-ВЕNZ-609D',
#  'VОLКSWАGЕN-Т4',
#  'SКV2',
#  'INFINIТIFХ50',
#  'ГРЕЙТWАLL',
#  'SНСМАN',
#  'NIССАN',
#  'СНЕVRОLЕТNТ',
#  'VОLХО',
#  'МЕRСЕDЕS-ВЕNZ-814',
#  'МIТSUВISНI-DIОN',
#  'VОRТЕХ',
#  'СНЕVRОLЕR',
#  'FОRDЕ',
#  'МЕNСI',
#  'ВRILIАNСЕ',
#  'FRUЕНАF',
#  'АDUDI',
#  'LЕХUSG',
#  'V+LЖSWLG+N',
#  'VОLКАWАGЕN',
#  'VIСТОRУ',
#  'САDILLLАС',
#  'NISSN',
#  'КЕNАULТ',
#  'DАIНАТSUУRV',
#  'МIFSUВISНI',
#  'МЕRСЕDЕSВЕNZ140D',
#  'МIТSUIВISНI',
#  'МЕRСЕDЕS350',
#  'RЕNULТ',
#  'RЕNАLUТ',
#  'МЕRСЕDЕS-ВЕNZ1844',
#  'РLIЕGL',
#  'LАNDRОVЕRRАNGЕ',
#  'VОLКZWАGЕN',
#  'RЕNАULУ',
#  'АUDI80',
#  'VОКLSWАGЕN',
#  'НИSSАН',
#  'МЕRСЕDЕS-ВЕNZ-230',
#  'МЕRSЕDЕС-ВЕNZ',
#  'LАNDRОVЕRLR3',
#  'МЕRСЕDЕS-ВЕNZ-Е250',
#  'FR',
#  'SСНМIТIZ',
#  'СНЕVRJLЕТ',
#  'LАМВОRНINI',
#  'NISSАNGТR',
#  'SАNGUСNG',
#  'ВRILLIАNСЕН230',
#  'КINFАN',
#  'F1',
#  'VОLКSWАGЕN',
#  'SСНМIТZСАRGОВULLSК024',
#  'ВRILLIАNСЕН530',
#  'SSАNQ',
#  'САNIА',
#  'SSАNNG',
#  'INFАNIТI',
#  'МЕRСЕDЕS-ВЕNZ-Е270',
#  'SКJDА',
#  'НУUNDАIО',
#  'INFINIТIG25',
#  'FRЕIОНТLINЕRFLС',
#  'SА',
#  'ISU85-0',
#  'МIТSUВISUВISНI',
#  'НUSQVАRNА',
#  'SНЕDА',
#  'VОLКSWАGЕNL',
#  'ЕRСЕDЕS-ВЕNZ',
#  'GЕLLУ',
#  'GRIРНОN',
#  'DАУНАТSU',
#  'ХINLING',
#  'СНЕRЕАU',
#  'FL',
#  'МЕRСЕDЕS-ВЕNZS400',
#  'FRЕGНТLINЕR',
#  'МЕRСЕDЕSВЕNZА190',
#  'LАDАА',
#  'FОRТUNЕR',
#  'IFINIТIQХ56',
#  'МZSА,',
#  'МЕRСЕDЕSВЕNZ814',
#  'SРАRК',
#  'МЕRСЕDЕS-ВЕNZ818',
#  'МЕRСЕDЕSВЕNZ200S',
#  'МЕRСЕDЕSВЕNZ320Е',
#  'SR334',
#  'SСНМIТZSО1SСS24',
#  'НUАТIАN',
#  'DАЕWОО-',
#  'АСКЕRМАNN',
#  'НУUNDАI,',
#  'МЕRСЕDЕСВЕNZ',
#  'GRЕАLТ',
#  'SНАСМАN',
#  'VWСТЕ2-0',
#  'VОLКSVАGЕNGОLF',
#  'GЕЕIU',
#  'МЕRSЕDЕSВЕNZ814',
#  'LЕХUХ',
#  'SSАNУОNG',
#  'VОLКSWАGЕNLТ35',
#  'СУЕVRОLЕТ',
#  'SНАNУАNG',
#  'ВЕNТLЕУ',
#  'LIFАNХ90',
#  'SUВURU',
#  'SХААNХI',
#  'МЕRСЕDЕS-ВЕNZЕ300',
#  'FLUЕНАUF',
#  'VWСТZ2-0',
#  'SSАNGУUNG',
#  'SХ',
#  'SААNGУОNG',
#  'МIТSUNISНI',
#  'СНЕVRОLТN',
#  'РОRСSНЕ',
#  'НАОJIN',
#  'СIТRТОЕN',
#  'SСНМIТZСАRGОВULLSКО24L',
#  'FХFВ',
#  'МЕRСЕDЕS-ВЕNZ-100D',
#  'DАSIА',
#  'SКIDА',
#  'МЕRСЕDЕS-ВЕNZ-600',
#  'RN166Z',
#  'АUDIQ7',
#  'ТRОТТЕR',
#  'МЕRСЕDЕSВЕNZЕ230',
#  'LЕNDRОVЕR',
#  'SКVВ',
#  'DЕМ',
#  'МЕRСRDЕS-ВЕNZ',
#  'МЕRСЕDЕS-ВЕNZЕ280',
#  'FRЕIGНТLINDЕR',
#  'МЕRСRDRS-ВЕNZ',
#  'МЕRСЕDЕS-ВЕNZS600L',
#  'ТОNАR',
#  'МАZDА,',
#  'SСНМIТZ-SРR24',
#  'МЕRSЕDЕS-ВЕNS',
#  'АLFА',
#  'INFINIТI',
#  'INFINIТI-FХ50S',
#  'RОLFО',
#  'МЕRСЕDЕS-ВЕNZS350',
#  'IVЕКО',
#  'АUDI90',
#  'SLОDА',
#  'F',
#  'ЕRСЕDЕS',
#  'SР-',
#  'GЕЕLV',
#  'НУUТDАI',
#  'ТЕLS',
#  'JАGUАRFХ',
#  'СINRОЕN',
#  'FRIЕGНТLINЕR',
#  'РЕUGЕОUТ',
#  'МIТSUВUSНI',
#  'UМС',
#  'RЕNАUNТ',
#  'МЕRСЕDЕSВЕNZ210D',
#  'МЕRСЕDЕS-Е230Т',
#  'LАМВОRGНINI',
#  'МЕRСЕDЕSВЕNZЕ290',
#  'SSАNGVОNGКУRОN',
#  'SСНМIТZСАRGОВULLSКО',
#  'МЕRСЕDЕSВЕNZV230',
#  'SSАНGУОНG',
#  'ВАLТМОРТОRS',
#  'NISАN',
#  'SСНМIТZSК024',
#  'FRЕIGНТLINЕR-СSТ120',
#  'NАЕRКО',
#  'LЕХUSRХ',
#  'FОRF',
#  'МЕRСЕDЕS-ВЕNZ-Е300',
#  'SСНМIТZSКО24L13.',
#  'МЕRСЕDЕSВЕNZ300D',
#  'РОNТIАС',
#  'SНААNХI',
#  'SСНМIТZ,SКО',
#  'U5Е',
#  'МЕRСЕDЕS-ВЕNZ280',
#  'СIТRОТN',
#  'ТUСSОN',
#  'VОLКSWАGЕNN',
#  'VJLКSWАGЕN',
#  'МЕRСЕDЕS-ВЕNZ-С250',
#  'FВ',
#  'LIFАNХ50',
#  'МТRСЕDЕS-ВЕNZ',
#  'WЕILТОN',
#  'НУUNDАL',
#  'МЕRСЕDЕSВЕNZ1835',
#  'LААDА',
#  'НОNDАI',
#  'АУDI',
#  'НУUNDАINF',
#  'DОЕWОО',
#  'VОLКSWАGЕ',
#  'ШМИТЦ-САRGОВULL',
#  'АСЕRВI.',
#  'VILVО',
#  'SIТRОЕN',
#  'FRЕIGНТLINЕR-FLD120',
#  'FТS',
#  'РОRSНСЕ',
#  'МЕRСЕDЕS-А170',
#  '(СНЕVRОLЕТ',
#  'VОLКSЕАGЕN',
#  'RЕNАULТ385',
#  'РОRSС',
#  'НОNDАV',
#  'МЕRСЕDЕSВЕNZ201',
#  'МЕRСЕDЕВЕNZ',
#  'VОLКSSWАGЕN',
#  'LАDАТ',
#  'VОLКSVАGЕNLТ35',
#  'SКАNIУ',
#  'SUDАRU',
#  'АDА',
#  'СIТRОЕNС8',
#  'SUZUКIХL-7',
#  'КАIТОNGМ',
#  'НУUNDАI-',
#  'INFINIТIFХ30D',
#  'GWМ',
#  'НОUNDАI',
#  'VОLКSWАGЕNGОLF3',
#  'DЕRВI',
#  'GЕЕLЕ',
#  'VОLКSWАGЕNLUРО',
#  'НISSАN',
#  'SСНМIТZ-SК0',
#  'SСНМIТZ-SРR27',
#  'SАМRО',
#  'УUЕJIN-NJ1080DА',
#  'МЕRСЕDЕSВЕNZ200',
#  'RОLFОS',
#  'СIТRОЕNС3',
#  'НУUNDDАI',
#  'GRУРНОN',
#  'НУUNDАIТВ',
#  'МЕRСЕDЕS-ВЕNZ1840',
#  'МЕRСЕDЕS220',
#  'FIАN',
#  'КОLUМАN',
#  'АТSUN',
#  'SНАСМАNSХ3316DR366',
#  'SSАND',
#  'FОRТUNЕ',
#  'SСQNIА',
#  'МЕRСЕDЕSВЕNZ300Е',
#  'НОNDА',
#  'МЕRСЕDЕS-190-Е',
#  'SSАNGGУОNG',
#  'VL',
#  'АКU-ТRЕILЕR',
#  'JСUАR',
#  'SААNG',
#  'НЕVRОLЕ',
#  'LАDАD',
#  'FRUЕНАUFТ34С',
#  'МЕRСЕDЕS-Е280',
#  'НУАNDАI',
#  'АRОСS',
#  'SНМIТS',
#  'SRЕМ',
#  'НАRLЕУ-DАVIDSОN-VRSСDХ',
#  'СIТRОЕNС1',
#  'СНЕVRОLЕТАN',
#  'JАGUАRХКS',
#  'SUZАКI',
#  'НАRLЕУ-DЕVIDSОN',
#  'Ж+RТ+D+S-Т+NZ',
#  'DЕRVЕУS',
#  'МТRСЕDЕS',
#  'INFINIТI.FХ35',
#  'SКОSА',
#  'МЕRСТDЕS',
#  'РОRSСНЕ',
#  'НАRLЕУDАЕVIDSОN',
#  'ISUZUЕLF',
#  'VОLКS',
#  'МЕILLЕR',
#  'SНЕNLОNG',
#  'RN',
#  'SНАНМАN',
#  'VОLКSWАGЕN-2КN',
#  'МIТSUВIАНI',
#  'МЕRСЕDЕS-190С',
#  'NАSSАN',
#  'NР300',
#  'АUDАI',
#  'DАЕWООО',
#  'СНЕVRОLЕRТ',
#  'VОLVОFМ',
#  'SОNIК',
#  'МЕRСЕDЕS.ВЕNZ',
#  'SF4В',
#  'РЕUGЕОN',
#  'VОLVО,',
#  'МЕRСЕDЕS-ВЕNZ-207D',
#  'МЕRСЕDЕSВЕNZ408',
#  'SСНМIIZ',
#  'РRЕSТIGЕ',
#  'АND',
#  'SSАNGУОUNG',
#  'АSТОNМАRТIN',
#  'АUDIG5',
#  'МIТSUВISНIL300',
#  'VОLКSWАGЕРОLО',
#  'МЕRСЕDЕS-250D',
#  'SР-240РR',
#  'НУUINDАI',
#  'RЕNАУLТ',
#  'NISSАН',
#  'МЕRСЕDЕS-208D',
#  'VОLСSWАGЕN',
#  'FОRА',
#  'VОLКSАWАGЕN',
#  'МЕRСЕDЕSВЕNZ2235',
#  'МЕRСЕDЕS-ВЕNZ-1835',
#  'VLV1-3',
#  'АUDIQ3',
#  nan,
#  'NIISSАN',
#  'МЕRСЕDЕS-ВЕNZ',
#  'NIОSSАN',
#  'МIТSUВIНSI',
#  'VLV6-1',
#  'СRАУSLЕR',
#  'СНЕVR0LЕТ',
#  'VАN-НООL',
#  'RЕNАUIТ',
#  'INFINIТIQХ70',
#  'VWСТ2-0',
#  'LЕХUSС',
#  'НУUNDАО',
#  'НУUNАDI',
#  'НАRLЕУ-DАVIDSОN-FLНRСI',
#  'VОLСКWАGЕN',
#  'VW50',
#  'SСНМIТZSК24L',
#  'VОLКSWАGЕNLТ46',
#  'NURSАN,',
#  'NISSАNН',
#  'FRЕIGНТLINЕRСЕNТURУ',
#  'FRЕIGНТLINЕRСSТ112',
#  'МIТSUВISНIСАNТЕR35',
#  'МЕRСЕDЕSВЕNZС180',
#  'SК1',
#  'РОNТIАК',
#  'ВАLТМОТОRS',
#  'SСНМIТZSК124',
#  'LЕКSUS',
#  'VОLКСWАGЕN',
#  'НАRLЕУDАVIDSОNХL1200S',
#  'SIАТ',
#  'LSDА',
#  'НУUNDАIХ35',
#  'VWРАSSАТ',
#  'САRSАN',
#  'ISТАNА',
#  'МIТSIВISНI',
#  'SIТRОУЕN',
#  'FRЕIGНТLINЕRFLD120',
#  'INFINIТIFХ45',
#  'NISSАN-Х',
#  'МЕRСЕDЕS',
#  'МЕRСЕDЕSВЕNZ180',
#  'МЕRСЕDЕS-ВRNZ',
#  'СНЕVRОLАТ',
#  'GRЕАL',
#  'МЕRСЕDЕS-ВЕNZАТЕGО',
#  'МЕRСЕDSЕ-ВЕNZ',
#  'INFINIТТI',
#  'SSАNGУОNGКURОN',
#  'МЕRСЕDЕSВЕNZ609D',
#  'JS',
#  'IRВIS',
#  'SСНМIТZSРR24L13.',
#  'INFINIТI-ЕХ35',
#  'FТВ',
#  'VОLКSWАGЕN-VW',
#  'АN',
#  'МЕRСЕDЕSВЕNZ250D',
#  'DАТСUN',
#  'LFDА,',
#  'NISSАNJUКЕ',
#  'SRЕМSСНМIТZ',
#  'МIТSUВISНIL200',
#  'МЕRСDЕS-ВЕNZ',
#  'RQNАULТ',
#  'SСНМТZ',
#  'SUZUКIХL7',
#  'МЕRСЕDЕSВЕNZ1324',
#  'МЕRСЕDЕS-ВЕNZ-320',
#  'SСВ',
#  'МЕRСЕDЕSВЕNZС320',
#  'NЕSSАN',
#  'МЕRСЕDЕS-ВЕNZМL320',
#  'РАТRОN',
#  'VОLКSWАGЕN2КN',
#  'RАРISСАN',
#  'VОLКS.GОLF',
#  'NISSLN',
#  'МЕRСЕDЕS-ВЕNZ-SLК',
#  'VОLVОVN',
#  'КАЕSSВОНRЕR',
#  'КRАУSLЕR',
#  'МЕRСЕDЕS-ВЕNZ-С200',
#  'DАЕW00',
#  'VW-GОLF-СL',
#  'VОLКSWАGЕN-LUРО',
#  'VIСТОRI',
#  'МIТSUВISНIАSХ18',
#  'INFINIТU',
#  'МЕRСЕDЕSВЕNZS550',
#  'СНRАУSLЕR',
#  'МЕRСЕDЕS-ВЕNZ-2541',
#  'VIRАGО',
#  'SСНWАRZМULLЕRSРА3Е',
#  'МЕRСЕDЕSВЕNZЕ280',
#  'МЕRСЕDЕS-ВЕNZМL270',
#  'IТSUВISНI',
#  'LINКОLN',
#  'INFINIТI-G25',
#  'НUSQVАRNАТЕ449',
#  'FRЕUЕНАUF',
#  'INFINIТТ',
#  'МЕRСЕDЕS-ВЕNZ-Е500',
#  'НINО',
#  'МIТSUВISНI-L300',
#  'SUZУКI',
#  'SНАСМАNSХ3251DR384',
#  'DМF',
#  'FRЕIGНТLINЕRАRGОSУ',
#  'SУАСМАN',
#  'ВАLТМОТОRS,',
#  'SUNLОNG',
#  'SСНМIТZSСS24L13.',
#  'DАWЕОО',
#  'LАDАS',
#  'SСНМIТZСАRGОВULLZК018',
#  'V3',
#  'L;АDА',
#  'LАDQА',
#  'КRАZ',
#  'WIТЕLТОN',
#  'NАRRО',
#  'FСТ',
#  'НУUNDАISМ',
#  'SСНМIТZСАRGОВULLSР',
#  'МЕRСЕDЕS-ВЕNZ-А150',
#  'LАDАБ',
#  'IVЕSО',
#  'DОNG',
#  'LАDF',
#  'SСНМIТZСАRGОВULS01',
#  'FОСА',
#  'FUSО784604SНFUSО',
#  'МЕRСЕDЕS-ВЕNZ-310',
#  'МIТSUВIНI',
#  'СНЕVRРLЕТ',
#  'КIАТОNG',
#  'МЕRСЕDЕS-ВЕNZС180',
#  'МЕRСЕDЕS-ВЕNZ-0404',
#  'МIТSUВВISНI',
#  'INFINIТIQ70',
#  'МЕRСЕDЕS-ВЕNZ-G500',
#  'INFINIТIQХ60',
#  'МЕRСЕDЕS-ВЕNZСLА',
#  'НУNNDАI',
#  'NУАRКО',
#  'VW-ГОЛЬФ',
#  'НУUNDАI-FХ',
#  'НУUNDАIVF',
#  'МЕRСЕDЕSВЕNZV200',
#  'МЕRСЕDЕSВЕNZ0325',
#  'АUDIА',
#  'FLIЕGL',
#  'МЕRСЕDЕS-ВЕNZЕ500',
#  'VОLКSWАGЕV',
#  'SНМIТZS01',
#  'INFINЕТI',
#  'F150',
#  'V',
#  'LАFА',
#  'RЕUGЕОТ',
#  'МЕRСЕDЕS-ВЕNZ-МL',
#  'КОGЕLN',
#  'SСНМIТZ.SРR',
#  'САDILАК',
#  'GЕЕКУ',
#  'ЛАНДRОVЕR',
#  'СНRУАSLЕR',
#  'НIССАN',
#  'ISUТSU',
#  'НАWТАI',
#  'RЕNАSULТ',
#  'МЕRSЕDЕSВЕNZ190',
#  'DАТSU',
#  'LЕGЕND',
#  'САDILLАССТS',
#  'НУUDАI',
#  'LЕХUSЕS',
#  'WIЕLТОN',
#  'SУВАRU',
#  'АLIRIZАUSТА',
#  'МUТSUВIНI',
#  'DАСIА',
#  'INFINIТIQ50',
#  'VWСТ1-1',
#  'НУUNАDАI',
#  'DАТDUN',
#  'МЕRСЕDЕS-ВЕNZ-Е',
#  'FRUЕNАUF',
#  'НАFFI',
#  'SUZUКI-SХ4',
#  'МЕRСЕDЕSВЕNZD250',
#  'РЕUGОТ',
#  'JОNWАУ',
#  'FRЕIGНТLINЕRFLD112',
#  'НАWNАI',
#  'ISSАN',
#  'VОLКSWАGЕЕN',
#  'АUDIА3',
#  'WV',
#  'НАRLЕУDАVIDSОNХL883L',
#  '(IVЕСО',
#  'LАDА,',
#  'GР800',
#  'МЕRСЕDЕSВЕNZ507D',
#  'МЕRСЕDЕSВЕNZ190',
#  'SUZUКIМ50',
#  'НУUNDАII40',
#  'VОLКSWАСТN',
#  'СНТVRОLRТ',
#  'DАIНАТSU',
#  'LЕХSUS',
#  'SUВАRО',
#  'МЕRСЕDЕS-ВЕNZS',
#  'НАRLЕУDАVIDSОNFХDВ',
#  'FОR',
#  'S1Р42',
#  'VОLVL',
#  'КАWАSАКI',
#  'ISUZU',
#  'GА',
#  'R',
#  'МIТZUВISНI',
#  'SР240РR',
#  'САDILАG',
#  'RС200',
#  'LF',
#  'SСНNIТZ',
#  'МЕRСЕDЕSВ',
#  'G80',
#  'RЕN.СLIО',
#  'МЕRСЕDЕSВЕNZС220',
#  'СIТНОЕN',
#  'УUЕJINNJ1080DА',
#  'FRЕIGНТLINЕR-FLD112',
#  'RЕNАULТ-SR',
#  'СНЕVRILЕТ',
#  'МЕRСЕDЕS-ВЕNZ-SL55',
#  'МЕRSDЕS-ВЕNZ',
#  'ХОNDА',
#  'LIЕКЕ',
#  'МЕRСЕDЕS-ВЕNС',
#  'RЕNFULТ',
#  'VNL',
#  'LАDDА',
#  'ННUNDАI',
#  'КОRIDА',
#  'INFINIТIQХ50',
#  'МRСЕDЕS',
#  'ВОGDАN',
#  'NАZDА3',
#  'LОNСIN',
#  'SСНМIТZSСF24Т',
#  'РЕUGТОТ',
#  'DООDGЕ',
#  'МIТSUВISНI-L400',
#  'МЕRСЕDЕS-ВЕNZVIТО',
#  'МЕRСЕDЕSВЕNZ320S',
#  'DЕМАG',
#  'ВЕNЕLLI',
#  'МЕRСЕDЕSВЕNZС230',
#  'МАZDА3',
#  'GRЕАТ',
#  'FRЕIGНТLЕNЕЕ',
#  'SР',
#  'КОЕGЕL',
#  'SСНМIТZ-S01',
#  'SV',
#  'DАSТUN',
#  'VОLКSWАGЕNVW',
#  'FRЕ1GНТLINЕR',
#  'МЕRСЕDЕS-ВЕNZS320',
#  ...}

# %%
import spacy
from spacy.language import Language

@Language.component("info_component")
def my_component(doc):
    best_result = 0.0
    for token in doc[0:5]:
        for brand in brands:
            word = replace_rus_to_eng_char(str(token))
            brand_en = replace_rus_to_eng_char(brand)
            jaro = Levenshtein.jaro_winkler(word, brand_en)
            levensh = Levenshtein.distance(word, brand)
            
            if jaro > best_result and jaro > 0.8 and levensh < len(word) and len(word) > 2:
                print(jaro, levensh, word, brand)
                best_result = jaro
                doc.user_data['model'] = brand
    return doc

nlp = spacy.blank("ru")
nlp.add_pipe("info_component", last=True)


test_list = [
    "автомобиль Honda CR-V2003 года выпуска№ двигателя K20A4 3003199шасси (рама), № - не установленкузов № SHSRD887040203152цвет кузова - белый (темно-серый)мощность двигателял.с. (кВт) - 150 л.с.110 кВтрабочий объем двигателякуб. см - 1998ПТС 39 ТР 405688 выдан 05.11.2008 г. Калининградской областной таможней",
"ДЖИП ГРАНД ЧИРОКИ2000 года выпуска.",
"HYUNDAI SM (Santa Fe classic) 2008 года выпуска",
"BMW 520D",
"Грузовой-тягач специальный2012 г.в.гос. номер С458РМ69марка 6796-03 на шасси VOLVO FНмодель № двиг. D13 023944шасси YV2ASW0A36B437889цвет желтыймощность двиг. 480 л.с.раб. V двиг. 12780 куб.см.разрешенная макс. масса 18000 кг.масса без нагрузки 7500 кг.страна Россия",
"Трактор Беларус  2022.32013 года выпуска регистрационный номер 30 АР 9375ПСМ - ТТ 452861 от 11 апреля 2014 года№ двигателя 119770 коробка передач № 062966основной ведущий мост № 4421  (11695) заводской номер машины  (рама)  20101226",
"Зерноуборочный комбайн  РСМ -10Б ДО Н-1 500Б2007 г.в.зав№ 097372 двигатель № 70322957мост 681-06 ПСМ ВВ 719264рег.знак 55 ОХ 9304 ; Зерноуборочный комбайн  РСМ -10Б ДО Н-1 500Б2006 г.в.зав.№ 094955 двигатель № 60285141мост 2781 ПСМ ВВ 530640рег.знак 55 ОХ 9315 ; Трактор Белаус-82.12008 г.в.зав.№ 80875955 двигатель № 395878мост 288538-04 ПСМ ТС 230329рег.знак 55 ОХ 9302 ; Трактор колесный NEW HOLLAND Т80402007 г.в.зав.№ Z7RW03713 двигатель № 46761566мост отсутствует ПС",
"Марка Модель  SKODA   OCTAVIA  Наименование  (тип ТС)  ЛЕГКОВОЙВ год выпуска 2012 тип№ двигателя БЕНЗИНОВЫЙ НА БЕНЗИНЕCDA 334858 кузовкабина XW8CK41Z0DK224749 цвет БЕЖЕВЫЙ Мощность двигателя л.с.  (кВт)  152  (112)  Рабочий объем двигателя куб.см 1798 Организация- изготовитель ТС  (страна)  ООО  ФОЛЬКСВАГЕН  ГРУП РУС  (РОССИЯ)  Серия№ТДТПО отсутствует ПТС 40 НО №350758 от 22.07.2012 г.",
"Марка Модель KIA  DE (JB/ Rio ) Наименование  (тип ТС)  ЛЕГКОВОЙВ год выпуска 2011 тип№ двигателя БЕНЗИНОВЫЙG4EE AH418313 кузовкабина XWEDH511BB0009986 цвет Серебристый Мощность двигателя л.с.  (кВт)  95  (699)  Рабочий объем двигателя куб.см 1399 Организация- изготовитель ТС  (страна)  ООО ЭЛ ЛАДА  ИНТЕРТРЕЙД  (Россия)  Серия№ТДТПО отсутствует ПТС 39 НЕ №251892 от 17.04.2011 г.",
"ЛЕГКОВОЙ  МЕРСЕДЕС  ПТС 77 УВ 872495 МАРКА МОДЕЛЬ-MERCTDES-BENZ ML 35D 4 MATIC Год выпуска-2012 Модель. № двигателя-27695530255333 Цвет- БЕЛЫЙ Св-во о регистрации ТС-72 КУ № 460414 Регистрационный знак-У 777 ВМ 72",
]

for item in test_list:
    doc = nlp(item)
    print(doc.user_data)
# Out:
# 1.0 0 HONDA HONDA
# {'model': 'HONDA'}
# 0.8483333333333334 2 ДЖИП ДЖИЛИ
# 1.0 0 ДЖИП ДЖИП
# {'model': 'ДЖИП'}
# 0.8114285714285714 3 HYUNDAI HONDA
# 1.0 0 HYUNDAI HYUNDAI
# {'model': 'HYUNDAI'}
# 1.0 0 BMW BMW
# {'model': 'BMW'}
# {}
# 0.8742857142857143 5 БEЛAPУC БЕЛАЗ
# 1.0 6 БEЛAPУC Беларус
# {'model': 'Беларус'}
# {}
# 0.8483333333333334 4 МAPKA МАРС
# 1.0 0 SKODA SKODA
# {'model': 'SKODA'}
# 0.8483333333333334 4 МAPKA МАРС
# 1.0 0 KIA KIA
# {'model': 'KIA'}
# {}

# %%
import spacy
from spacy.vocab import Vocab
vocab = Vocab(strings=["world"])

nlp = spacy.blank("en", vocab=vocab)
config = {"overwrite_ents": True }
ruler = nlp.add_pipe("entity_ruler", config=config)
rules = [{"label": "YEAR", "pattern": "ALFA ROMEO"}]
ruler.add_patterns(rules)
  
doc = nlp('ALFA ROMEO')
[x for x in doc.ents]
# Out:
# [ALFA ROMEO]

# %%
list(nlp.vocab.strings)
# Out:
# ['world',
#  '\t',
#  '\n',
#  ' ',
#  "'",
#  "''",
#  "'Cause",
#  'because',
#  'Cause',
#  "'Cos",
#  'Cos',
#  "'Coz",
#  'Coz',
#  "'Cuz",
#  'Cuz',
#  "'S",
#  "'s",
#  'S',
#  "'bout",
#  'about',
#  'bout',
#  "'cause",
#  'cause',
#  "'cos",
#  'cos',
#  "'coz",
#  'coz',
#  "'cuz",
#  'cuz',
#  "'d",
#  'd',
#  "'em",
#  'them',
#  'em',
#  "'ll",
#  'will',
#  'll',
#  "'nuff",
#  'enough',
#  'nuff',
#  "'re",
#  'are',
#  're',
#  's',
#  '(*_*)',
#  '(',
#  ')',
#  '*',
#  '(-8',
#  '-8',
#  '(-:',
#  ':',
#  '-',
#  '(-;',
#  ';',
#  '(-_-)',
#  '-_-',
#  '(._.)',
#  '.',
#  '(:',
#  '(;',
#  '(=',
#  '=',
#  '(>_<)',
#  '>',
#  '<',
#  '(^_^)',
#  '^_^',
#  '(o:',
#  'o',
#  '(¬_¬)',
#  '¬_¬',
#  '(ಠ_ಠ)',
#  'ಠ_ಠ',
#  '(╯°□°）╯︵┻━┻',
#  '┻',
#  '╯',
#  '━',
#  '°',
#  '□',
#  '）',
#  '︵',
#  ')-:',
#  '):',
#  '-__-',
#  '._.',
#  '0.0',
#  '0.o',
#  '0_0',
#  '0_o',
#  '10',
#  'a.m.',
#  '10a.m',
#  '10a.m.',
#  'am',
#  'p.m.',
#  '10p.m',
#  '10p.m.',
#  'pm',
#  '11',
#  '11a.m',
#  '11a.m.',
#  '11p.m',
#  '11p.m.',
#  '12',
#  '12a.m',
#  '12a.m.',
#  '12p.m',
#  '12p.m.',
#  '1',
#  '1a.m',
#  '1a.m.',
#  '1p.m',
#  '1p.m.',
#  '2',
#  '2a.m',
#  '2a.m.',
#  '2p.m',
#  '2p.m.',
#  '3',
#  '3a.m',
#  '3a.m.',
#  '3p.m',
#  '3p.m.',
#  '4',
#  '4a.m',
#  '4a.m.',
#  '4p.m',
#  '4p.m.',
#  '5',
#  '5a.m',
#  '5a.m.',
#  '5p.m',
#  '5p.m.',
#  '6',
#  '6a.m',
#  '6a.m.',
#  '6p.m',
#  '6p.m.',
#  '7',
#  '7a.m',
#  '7a.m.',
#  '7p.m',
#  '7p.m.',
#  '8)',
#  '8',
#  '8-)',
#  '8-',
#  '8-D',
#  'D',
#  '8D',
#  '8a.m',
#  '8a.m.',
#  '8p.m',
#  '8p.m.',
#  '9',
#  '9a.m',
#  '9a.m.',
#  '9p.m',
#  '9p.m.',
#  ":'(",
#  ":')",
#  ":'-(",
#  ":'-)",
#  ':(',
#  ':((',
#  ':(((',
#  ':()',
#  ':)',
#  ':))',
#  ':)))',
#  ':*',
#  ':-(',
#  ':-((',
#  ':-(((',
#  ':-)',
#  ':-))',
#  ':-)))',
#  ':-*',
#  ':-/',
#  '-/',
#  ':-0',
#  '-0',
#  ':-3',
#  '-3',
#  ':->',
#  ':-D',
#  '-D',
#  ':-O',
#  '-O',
#  ':-P',
#  '-P',
#  ':-X',
#  '-X',
#  ':-]',
#  ']',
#  ':-o',
#  '-o',
#  ':-p',
#  '-p',
#  ':-x',
#  '-x',
#  ':-|',
#  '-|',
#  ':-}',
#  '}',
#  ':/',
#  '/',
#  ':0',
#  '0',
#  ':1',
#  ':3',
#  ':>',
#  ':D',
#  ':O',
#  'O',
#  ':P',
#  'P',
#  ':X',
#  ':]',
#  ':o',
#  ':o)',
#  ':p',
#  'p',
#  ':x',
#  'x',
#  ':|',
#  '|',
#  ':}',
#  ':’(',
#  '’',
#  ':’)',
#  ':’-(',
#  ':’-)',
#  ';)',
#  ';-)',
#  ';-D',
#  ';D',
#  ';_;',
#  '<.<',
#  '</3',
#  '/3',
#  '<3',
#  '<33',
#  '33',
#  '<333',
#  '333',
#  '<space>',
#  'space',
#  '=(',
#  '=)',
#  '=/',
#  '=3',
#  '=D',
#  '=[',
#  '[',
#  '=]',
#  '=|',
#  '>.<',
#  '>.>',
#  '>:(',
#  '>:o',
#  '><(((*>',
#  '@_@',
#  'Adm.',
#  'Adm',
#  'Ai',
#  "n't",
#  'not',
#  'nt',
#  'n’t',
#  'Ak.',
#  'Alaska',
#  'Ak',
#  'Ala.',
#  'Alabama',
#  'Ala',
#  'Apr.',
#  'April',
#  'Apr',
#  'Are',
#  'Ariz.',
#  'Arizona',
#  'Ariz',
#  'Ark.',
#  'Arkansas',
#  'Ark',
#  'Aug.',
#  'August',
#  'Aug',
#  'Bros.',
#  'Bros',
#  "C'm",
#  'come',
#  'on',
#  'C++',
#  'Calif.',
#  'California',
#  'Calif',
#  'Ca',
#  'can',
#  "'ve",
#  'have',
#  'Can',
#  've',
#  '’ve',
#  'Co.',
#  'Co',
#  'Colo.',
#  'Colorado',
#  'Colo',
#  'Conn.',
#  'Connecticut',
#  'Conn',
#  'Corp.',
#  'Corp',
#  'Could',
#  'could',
#  'C’m',
#  'D.C.',
#  'Dare',
#  'dare',
#  'Dec.',
#  'December',
#  'Dec',
#  'Del.',
#  'Delaware',
#  'Del',
#  'Did',
#  'do',
#  'Does',
#  'does',
#  'Doin',
#  'doing',
#  "Doin'",
#  'Doin’',
#  'Do',
#  'Dr.',
#  'Dr',
#  'E.G.',
#  'E.g.',
#  'E.g',
#  'Feb.',
#  'February',
#  'Feb',
#  'Fla.',
#  'Florida',
#  'Fla',
#  'Ga.',
#  'Georgia',
#  'Ga',
#  'Gen.',
#  'Gen',
#  'Goin',
#  'going',
#  "Goin'",
#  'Goin’',
#  'Gon',
#  'na',
#  'to',
#  'Got',
#  'got',
#  'ta',
#  'Gov.',
#  'Gov',
#  'Had',
#  'Has',
#  'has',
#  'Have',
#  'Havin',
#  'having',
#  "Havin'",
#  'Havin’',
#  'He',
#  'he',
#  'would',
#  "He's",
#  '’d',
#  '’ll',
#  '’s',
#  'He’s',
#  'How',
#  'how',
#  "'y",
#  'you',
#  "How's",
#  '’y',
#  '’re',
#  'How’s',
#  'I',
#  'i',
#  "'m",
#  'a',
#  'gonna',
#  'I.E.',
#  'I.e.',
#  'I.e',
#  'Ia.',
#  'Iowa',
#  'Ia',
#  'Id.',
#  'Idaho',
#  'Id',
#  'Ill.',
#  'Illinois',
#  'Ill',
#  'm',
#  'Inc.',
#  'Inc',
#  'Ind.',
#  'Indiana',
#  'Ind',
#  'Is',
#  'is',
#  'It',
#  'it',
#  "It's",
#  'It’s',
#  '’m',
#  'Jan.',
#  'January',
#  'Jan',
#  'Jr.',
#  'Jr',
#  'Jul.',
#  'July',
#  'Jul',
#  'Jun.',
#  'June',
#  'Jun',
#  'Kan.',
#  'Kansas',
#  'Kan',
#  'Kans.',
#  'Kans',
#  'Ky.',
#  'Kentucky',
#  'Ky',
#  'La.',
#  'Louisiana',
#  'La',
#  'Let',
#  'let',
#  'us',
#  "Let's",
#  'Let’s',
#  'Lovin',
#  'loving',
#  "Lovin'",
#  'Lovin’',
#  'Ltd.',
#  'Ltd',
#  "Ma'am",
#  'madam',
#  'Mar.',
#  'March',
#  'Mar',
#  'Mass.',
#  'Massachusetts',
#  'Mass',
#  'May.',
#  'May',
#  'may',
#  'Ma’am',
#  'Md.',
#  'Md',
#  'Messrs.',
#  'Messrs',
#  'Mich.',
#  'Michigan',
#  'Mich',
#  'Might',
#  'might',
#  'Minn.',
#  'Minnesota',
#  'Minn',
#  'Miss.',
#  'Mississippi',
#  'Miss',
#  'Mo.',
#  'Mo',
#  'Mont.',
#  'Mont',
#  'Mr.',
#  'Mr',
#  'Mrs.',
#  'Mrs',
#  'Ms.',
#  'Ms',
#  'Mt.',
#  'Mount',
#  'Mt',
#  'Must',
#  'must',
#  'N.C.',
#  'North Carolina',
#  'N.D.',
#  'North Dakota',
#  'N.H.',
#  'New Hampshire',
#  'N.J.',
#  'New Jersey',
#  'N.M.',
#  'New Mexico',
#  'N.Y.',
#  'New York',
#  'Neb.',
#  'Nebraska',
#  'Neb',
#  'Nebr.',
#  'Nebr',
#  'Need',
#  'need',
#  'Nev.',
#  'Nevada',
#  'Nev',
#  'Not',
#  'Nothin',
#  'nothing',
#  "Nothin'",
#  'Nothin’',
#  'Nov.',
#  'November',
#  'Nov',
#  'Nuthin',
#  "Nuthin'",
#  'Nuthin’',
#  "O'clock",
#  "o'clock",
#  'O.O',
#  'O.o',
#  'O_O',
#  'O_o',
#  'Oct.',
#  'October',
#  'Oct',
#  'Okla.',
#  'Oklahoma',
#  'Okla',
#  'Ol',
#  'old',
#  "Ol'",
#  'Ol’',
#  'Ore.',
#  'Oregon',
#  'Ore',
#  'Ought',
#  'ought',
#  'O’clock',
#  'Pa.',
#  'Pennsylvania',
#  'Pa',
#  'Ph.D.',
#  'Ph',
#  'D.',
#  'Prof.',
#  'Prof',
#  'Rep.',
#  'Rep',
#  'Rev.',
#  'Rev',
#  'S.C.',
#  'South Carolina',
#  'Sen.',
#  'Sen',
#  'Sep.',
#  'September',
#  'Sep',
#  'Sept.',
#  'Sept',
#  'Sha',
#  'shall',
#  'She',
#  'she',
#  "She's",
#  'She’s',
#  'Should',
#  'should',
#  'Somethin',
#  'something',
#  "Somethin'",
#  'Somethin’',
#  'St.',
#  'St',
#  'Tenn.',
#  'Tennessee',
#  'Tenn',
#  'That',
#  'that',
#  "That's",
#  'That’s',
#  'There',
#  'there',
#  "There's",
#  'There’s',
#  'These',
#  'these',
#  "These's",
#  'These’s',
#  'They',
#  'they',
#  'This',
#  'this',
#  "This's",
#  'This’s',
#  'Those',
#  'those',
#  "Those's",
#  'Those’s',
#  'V.V',
#  'V_V',
#  'Va.',
#  'Virginia',
#  'Va',
#  'Wash.',
#  'Washington',
#  'Wash',
#  'Was',
#  'was',
#  'We',
#  'we',
#  'Were',
#  'were',
#  'What',
#  'what',
#  "What's",
#  'What’s',
#  'When',
#  'when',
#  "When's",
#  'When’s',
#  'Where',
#  'where',
#  "Where's",
#  'Where’s',
#  'Who',
#  'who',
#  "Who's",
#  'Who’s',
#  'Why',
#  'why',
#  "Why's",
#  'Why’s',
#  'Wis.',
#  'Wisconsin',
#  'Wis',
#  'Wo',
#  'Would',
#  'XD',
#  'XDD',
#  'You',
#  '[-:',
#  '[:',
#  '[=',
#  '\\")',
#  '"',
#  '\\',
#  '\\n',
#  '\\t',
#  ']=',
#  '^__^',
#  '^___^',
#  'a.',
#  'a.m',
#  'ai',
#  'and/or',
#  'and',
#  'or',
#  'b.',
#  'b',
#  "c'm",
#  'c.',
#  'c',
#  'ca',
#  'co.',
#  'co',
#  'c’m',
#  'd.',
#  'did',
#  'doin',
#  "doin'",
#  'doin’',
#  'e.',
#  'e',
#  'e.g.',
#  'e.g',
#  'f.',
#  'f',
#  'g.',
#  'g',
#  'goin',
#  "goin'",
#  'goin’',
#  'gon',
#  'h.',
#  'h',
#  'had',
#  'havin',
#  "havin'",
#  'havin’',
#  "he's",
#  'he’s',
#  "how's",
#  'how’s',
#  'i.',
#  'i.e.',
#  'i.e',
#  "it's",
#  'it’s',
#  'j.',
#  'j',
#  'k.',
#  'k',
#  'l.',
#  'l',
#  "let's",
#  'let’s',
#  'lovin',
#  "lovin'",
#  'lovin’',
#  'm.',
#  "ma'am",
#  'ma’am',
#  'n.',
#  'n',
#  'nothin',
#  "nothin'",
#  'nothin’',
#  'nuthin',
#  "nuthin'",
#  'nuthin’',
#  'o.',
#  'o.0',
#  'o.O',
#  'o.o',
#  'o_0',
#  'o_O',
#  'o_o',
#  'ol',
#  "ol'",
#  'ol’',
#  'o’clock',
#  'p.',
#  'p.m',
#  'q.',
#  'q',
#  'r.',
#  'r',
#  's.',
#  'sha',
#  "she's",
#  'she’s',
#  'somethin',
#  "somethin'",
#  'somethin’',
#  't.',
#  't',
#  "that's",
#  'that’s',
#  "there's",
#  'there’s',
#  "these's",
#  'these’s',
#  "this's",
#  'this’s',
#  "those's",
#  'those’s',
#  'u.',
#  'u',
#  'v.',
#  'v',
#  'v.s.',
#  'v.s',
#  'v.v',
#  'v_v',
#  'vs.',
#  'vs',
#  'w.',
#  'w',
#  'w/o',
#  'without',
#  "what's",
#  'what’s',
#  "when's",
#  'when’s',
#  "where's",
#  'where’s',
#  "who's",
#  'who’s',
#  "why's",
#  'why’s',
#  'wo',
#  'x.',
#  'xD',
#  'xDD',
#  "y'",
#  'all',
#  'y.',
#  'y',
#  'y’',
#  'z.',
#  'z',
#  '\xa0',
#  '  ',
#  '¯\\(ツ)/¯',
#  'C',
#  'C.',
#  '°C.',
#  'F',
#  'F.',
#  '°F.',
#  'K',
#  'K.',
#  '°K.',
#  '°c.',
#  '°f.',
#  '°k.',
#  'ä.',
#  'ä',
#  'ö.',
#  'ö',
#  'ü.',
#  'ü',
#  'ಠ︵ಠ',
#  '—',
#  '‘S',
#  '‘',
#  '‘s',
#  '’Cause',
#  '’Cos',
#  '’Coz',
#  '’Cuz',
#  '’S',
#  '’bout',
#  '’cause',
#  '’cos',
#  '’coz',
#  '’cuz',
#  '’em',
#  '’nuff',
#  '’’',
#  'ALFA',
#  'ROMEO',
#  'YEAR']

# %%
import spacy
nlp_model = spacy.blank("en")
doc = nlp_model("This is Tutorialspoint.com!")
print([x for x in doc])
with doc.retokenize() as retokenizer:
   attrs = {"LEMMA": "Tutorialspoint.com"}
   retokenizer.merge(doc[2:4], attrs=attrs)
[x for x in doc]
# Out:
# [This, is, Tutorialspoint.com, !]
# [This, is, Tutorialspoint.com!]

# %%
list(nlp.vocab.strings)
